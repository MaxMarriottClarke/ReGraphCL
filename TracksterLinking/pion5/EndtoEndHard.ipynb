# %% [markdown]
# # Loading Training Data

# %%
import glob
import os.path as osp
import uproot
import awkward as ak
import torch
import numpy as np
import random
import tqdm
from torch_geometric.data import Data, Dataset

import numpy as np
import subprocess
import tqdm
from tqdm import tqdm
import pandas as pd

import os
import os.path as osp

import glob

import h5py
import uproot

import torch
from torch import nn
from torch_geometric.data import Data
from torch_geometric.data import Dataset
from torch_geometric.data import DataLoader

import awkward as ak
import random
from torch_geometric.nn import knn_graph
import torch.nn.functional as F

# %%
def find_highest_branch(path, base_name):
    with uproot.open(path) as f:
        # Find keys that exactly match the base_name (not containing other variations)
        branches = [k for k in f.keys() if k.startswith(base_name + ';')]
        
        # Sort and select the highest-numbered branch
        sorted_branches = sorted(branches, key=lambda x: int(x.split(';')[-1]))
        return sorted_branches[-1] if sorted_branches else None

class CCV1(Dataset):
    r'''
    Loads trackster-level features and associations for positive/negative edge creation.
    '''

    url = '/dummy/'

    def __init__(self, root, transform=None, max_events=1e8, inp='train'):
        super(CCV1, self).__init__(root, transform)
        self.inp = inp
        self.max_events = max_events
        self.fill_data(max_events)

    def fill_data(self, max_events):
        counter = 0
        print("### Loading tracksters data")


        for path in tqdm(self.raw_paths):
            print(path)
            
            tracksters_path = find_highest_branch(path, 'tracksters')
            associations_path = find_highest_branch(path, 'associations')
            simtrack = find_highest_branch(path, 'simtrackstersCP')
            # Load tracksters features in chunks
            for array in uproot.iterate(
                f"{path}:{tracksters_path}",
                [
                    "time", "raw_energy",
                    "barycenter_x", "barycenter_y", "barycenter_z", 
                    "barycenter_eta", "barycenter_phi",
                    "EV1", "EV2", "EV3",
                    "eVector0_x", "eVector0_y", "eVector0_z",
                    "sigmaPCA1", "sigmaPCA2", "sigmaPCA3"
                ],
            ):

                tmp_time = array["time"]
                tmp_raw_energy = array["raw_energy"]
                tmp_bx = array["barycenter_x"]
                tmp_by = array["barycenter_y"]
                tmp_bz = array["barycenter_z"]
                tmp_beta = array["barycenter_eta"]
                tmp_bphi = array["barycenter_phi"]
                tmp_EV1 = array["EV1"]
                tmp_EV2 = array["EV2"]
                tmp_EV3 = array["EV3"]
                tmp_eV0x = array["eVector0_x"]
                tmp_eV0y = array["eVector0_y"]
                tmp_eV0z = array["eVector0_z"]
                tmp_sigma1 = array["sigmaPCA1"]
                tmp_sigma2 = array["sigmaPCA2"]
                tmp_sigma3 = array["sigmaPCA3"]
                
                
                vert_array = []
                for vert_chunk in uproot.iterate(
                    f"{path}:{simtrack}",
                    ["barycenter_x"],
                ):
                    vert_array = vert_chunk["barycenter_x"]
                    break  # Since we have a matching chunk, no need to continue
                

                # Now load the associations for the same events/chunk
                # 'tsCLUE3D_recoToSim_CP' gives association arrays like [[1,0],[0,1],...]
                # Make sure we read from the same events
                tmp_array = []
                for assoc_chunk in uproot.iterate(
                    f"{path}:{associations_path}",
                    ["tsCLUE3D_recoToSim_CP"],
                ):
                    tmp_array = assoc_chunk["tsCLUE3D_recoToSim_CP"]
                    break  # Since we have a matching chunk, no need to continue
                
                
                skim_mask = []
                for e in vert_array:
                    if 1 <=len(e) <= 5:
                        skim_mask.append(True)
                    elif len(e) == 0:
                        skim_mask.append(False)

                    else:
                        skim_mask.append(False)



                tmp_time = tmp_time[skim_mask]
                tmp_raw_energy = tmp_raw_energy[skim_mask]
                tmp_bx = tmp_bx[skim_mask]
                tmp_by = tmp_by[skim_mask]
                tmp_bz = tmp_bz[skim_mask]
                tmp_beta = tmp_beta[skim_mask]
                tmp_bphi = tmp_bphi[skim_mask]
                tmp_EV1 = tmp_EV1[skim_mask]
                tmp_EV2 = tmp_EV2[skim_mask]
                tmp_EV3 = tmp_EV3[skim_mask]
                tmp_eV0x = tmp_eV0x[skim_mask]
                tmp_eV0y = tmp_eV0y[skim_mask]
                tmp_eV0z = tmp_eV0z[skim_mask]
                tmp_sigma1 = tmp_sigma1[skim_mask]
                tmp_sigma2 = tmp_sigma2[skim_mask]
                tmp_sigma3 = tmp_sigma3[skim_mask]
                tmp_array = tmp_array[skim_mask]
                
                skim_mask = []
                for e in tmp_array:
                    if 2 <= len(e):
                        skim_mask.append(True)

                    elif len(e) == 0:
                        skim_mask.append(False)

                    else:
                        skim_mask.append(False)

                        
                tmp_time = tmp_time[skim_mask]
                tmp_raw_energy = tmp_raw_energy[skim_mask]
                tmp_bx = tmp_bx[skim_mask]
                tmp_by = tmp_by[skim_mask]
                tmp_bz = tmp_bz[skim_mask]
                tmp_beta = tmp_beta[skim_mask]
                tmp_bphi = tmp_bphi[skim_mask]
                tmp_EV1 = tmp_EV1[skim_mask]
                tmp_EV2 = tmp_EV2[skim_mask]
                tmp_EV3 = tmp_EV3[skim_mask]
                tmp_eV0x = tmp_eV0x[skim_mask]
                tmp_eV0y = tmp_eV0y[skim_mask]
                tmp_eV0z = tmp_eV0z[skim_mask]
                tmp_sigma1 = tmp_sigma1[skim_mask]
                tmp_sigma2 = tmp_sigma2[skim_mask]
                tmp_sigma3 = tmp_sigma3[skim_mask]
                tmp_array = tmp_array[skim_mask]

                
                # Concatenate or initialize storage
                if counter == 0:
                    self.time = tmp_time
                    self.raw_energy = tmp_raw_energy
                    self.bx = tmp_bx
                    self.by = tmp_by
                    self.bz = tmp_bz
                    self.beta = tmp_beta
                    self.bphi = tmp_bphi
                    self.EV1 = tmp_EV1
                    self.EV2 = tmp_EV2
                    self.EV3 = tmp_EV3
                    self.eV0x = tmp_eV0x
                    self.eV0y = tmp_eV0y
                    self.eV0z = tmp_eV0z
                    self.sigma1 = tmp_sigma1
                    self.sigma2 = tmp_sigma2
                    self.sigma3 = tmp_sigma3
                    self.assoc = tmp_array
                else:
                    self.time = ak.concatenate((self.time, tmp_time))
                    self.raw_energy = ak.concatenate((self.raw_energy, tmp_raw_energy))
                    self.bx = ak.concatenate((self.bx, tmp_bx))
                    self.by = ak.concatenate((self.by, tmp_by))
                    self.bz = ak.concatenate((self.bz, tmp_bz))
                    self.beta = ak.concatenate((self.beta, tmp_beta))
                    self.bphi = ak.concatenate((self.bphi, tmp_bphi))
                    self.EV1 = ak.concatenate((self.EV1, tmp_EV1))
                    self.EV2 = ak.concatenate((self.EV2, tmp_EV2))
                    self.EV3 = ak.concatenate((self.EV3, tmp_EV3))
                    self.eV0x = ak.concatenate((self.eV0x, tmp_eV0x))
                    self.eV0y = ak.concatenate((self.eV0y, tmp_eV0y))
                    self.eV0z = ak.concatenate((self.eV0z, tmp_eV0z))
                    self.sigma1 = ak.concatenate((self.sigma1, tmp_sigma1))
                    self.sigma2 = ak.concatenate((self.sigma2, tmp_sigma2))
                    self.sigma3 = ak.concatenate((self.sigma3, tmp_sigma3))
                    self.assoc = ak.concatenate((self.assoc, tmp_array))

                counter += len(tmp_bx)
                if counter >= max_events:
                    print(f"Reached {max_events} events!")
                    break
            if counter >= max_events:
                break

    def download(self):
        raise RuntimeError(
            f'Dataset not found. Please download it from {self.url} and move all '
            f'*.root files to {self.raw_dir}')

    def len(self):
        return len(self.time)

    @property
    def raw_file_names(self):
        raw_files = sorted(glob.glob(osp.join(self.raw_dir, '*.root')))
        return raw_files

    @property
    def processed_file_names(self):
        return []



    def get(self, idx):
        
        def reconstruct_array(grouped_indices):
            # Find the maximum index to determine the array length
            max_index = max(max(indices) for indices in grouped_indices.values())

            # Initialize an array with the correct size, filled with a placeholder (e.g., -1)
            reconstructed = [-1] * (max_index + 1)

            # Populate the array based on the dictionary
            for value, indices in grouped_indices.items():
                for idx in indices:
                    reconstructed[idx] = value

            return reconstructed
        # Extract per-event arrays
        event_time = self.time[idx]
        event_raw_energy = self.raw_energy[idx]
        event_bx = self.bx[idx]
        event_by = self.by[idx]
        event_bz = self.bz[idx]
        event_beta = self.beta[idx]
        event_bphi = self.bphi[idx]
        event_EV1 = self.EV1[idx]
        event_EV2 = self.EV2[idx]
        event_EV3 = self.EV3[idx]
        event_eV0x = self.eV0x[idx]
        event_eV0y = self.eV0y[idx]
        event_eV0z = self.eV0z[idx]
        event_sigma1 = self.sigma1[idx]
        event_sigma2 = self.sigma2[idx]
        event_sigma3 = self.sigma3[idx]
        event_assoc = self.assoc[idx]  # Each is now an array (e.g., [0, 1, 2]) indicating the pion group

        # Convert each to numpy arrays if needed
        event_time = np.array(event_time)
        event_raw_energy = np.array(event_raw_energy)
        event_bx = np.array(event_bx)
        event_by = np.array(event_by)
        event_bz = np.array(event_bz)
        event_beta = np.array(event_beta)
        event_bphi = np.array(event_bphi)
        event_EV1 = np.array(event_EV1)
        event_EV2 = np.array(event_EV2)
        event_EV3 = np.array(event_EV3)
        event_eV0x = np.array(event_eV0x)
        event_eV0y = np.array(event_eV0y)
        event_eV0z = np.array(event_eV0z)
        event_sigma1 = np.array(event_sigma1)
        event_sigma2 = np.array(event_sigma2)
        event_sigma3 = np.array(event_sigma3)
        event_assoc = np.array(event_assoc)  # e.g. [[0,1,2], [2,0,1], [1,0,2], ...]

        # Combine features
        flat_feats = np.column_stack((
            event_bx, event_by, event_bz, event_raw_energy,
            event_beta, event_bphi,
            event_EV1, event_EV2, event_EV3,
            event_eV0x, event_eV0y, event_eV0z,
            event_sigma1, event_sigma2, event_sigma3
        ))
        x = torch.from_numpy(flat_feats).float()
        assoc = event_assoc

        total_tracksters = len(event_time)

        # --------------------------------------------------------------------
        # Group tracksters by their association tuple. Two tracksters belong
        # to the same pion group if their association arrays (converted to tuples)
        # match.
        # --------------------------------------------------------------------
        # Group tracksters by their association tuple
         # Group tracksters by the first element of event_assoc
        assoc_groups = {}
        for i, assoc in enumerate(event_assoc):
            key = assoc[0]  # Only use the first element as the key
            if key not in assoc_groups:
                assoc_groups[key] = []
            assoc_groups[key].append(i)
        assoc_array = reconstruct_array(assoc_groups)
        pos_edges = []
        neg_edges = []
        # Ensure positive edges always connect to another trackster in the same group if possible
        for i in range(total_tracksters):
            key = event_assoc[i][0]  # Get first element as group identifier
            same_group = assoc_groups[key]

            # --- Positive edge ---
            if len(same_group) > 1:
                # Always select another trackster from the same group
                pos_target = random.choice([j for j in same_group if j != i])
            else:
                # No other trackster in the group, form a self-loop
                pos_target = i
            pos_edges.append([i, pos_target])

            # --- Negative edge ---
            neg_candidates = [j for j in range(total_tracksters) if event_assoc[j][0] != key]
            if neg_candidates:
                neg_target = random.choice(neg_candidates)
            else:
                neg_target = i
            neg_edges.append([i, neg_target])

        x_pos_edge = torch.tensor(pos_edges, dtype=torch.long)
        x_neg_edge = torch.tensor(neg_edges, dtype=torch.long)

        return Data(x=x, x_pe=x_pos_edge, x_ne=x_neg_edge, assoc = assoc_array)

# %%
# Load datasets
ipath = "/vols/cms/mm1221/Data/100k/5pi/train/"
vpath = "/vols/cms/mm1221/Data/100k/5pi/val/"

data_train = CCV1(ipath, max_events=80000, inp = 'train')
data_val = CCV1(vpath, max_events=10000, inp='val')
# Out:
# ### Loading tracksters data
#   0%|                                                                                                                                                                                 | 0/1 [00:00<?, ?it/s]
# /vols/cms/mm1221/Data/100k/5pi/train/raw/train.root
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:42<00:00, 42.93s/it]
# ### Loading tracksters data
#   0%|                                                                                                                                                                                 | 0/2 [00:00<?, ?it/s]
# /vols/cms/mm1221/Data/100k/5pi/val/raw/2k5pi.root
#  50%|████████████████████████████████████████████████████████████████████████████████████▌                                                                                    | 1/2 [00:01<00:01,  1.20s/it]
# /vols/cms/mm1221/Data/100k/5pi/val/raw/8k5pi.root
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:05<00:00,  2.89s/it]

# %%
# Also load explicitely, used for analysis and plots
data_path = '/vols/cms/mm1221/Data/100k/5pi/test/raw/test.root'
data_file = uproot.open(data_path)

Track_ind = data_file['tracksters;2']['vertices_indexes'].array()
GT_ind = data_file['simtrackstersCP;3']['vertices_indexes'].array()
GT_mult = data_file['simtrackstersCP;3']['vertices_multiplicity'].array()
GT_bc = data_file['simtrackstersCP;3']['barycenter_x'].array()
energies = data_file['clusters;4']['energy'].array()
LC_x = data_file['clusters;4']['position_x'].array()
LC_y = data_file['clusters;4']['position_y'].array()
LC_z = data_file['clusters;4']['position_z'].array()
LC_eta = data_file['clusters;4']['position_eta'].array()
MT_ind = data_file['trackstersMerged;2']['vertices_indexes'].array()

#1.3 Filter so get rid of events with 0 calo particles
skim_mask = []
for e in GT_bc:
    if 1 <= len(e) <=5 :
        skim_mask.append(True)
    else:
        skim_mask.append(False)

Track_ind = Track_ind[skim_mask]
GT_ind = GT_ind[skim_mask]
GT_mult = GT_mult[skim_mask]
energies = energies[skim_mask]
LC_x = LC_x[skim_mask]
LC_y = LC_y[skim_mask]
LC_z = LC_z[skim_mask]
LC_eta = LC_eta[skim_mask]
MT_ind = MT_ind[skim_mask]

# %% [markdown]
# # Initialise the Network

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class CustomStaticEdgeConv(nn.Module):
    def __init__(self, nn_module):
        super(CustomStaticEdgeConv, self).__init__()
        self.nn_module = nn_module

    def forward(self, x, edge_index):
        """
        Args:
            x (torch.Tensor): Node features of shape (N, F).
            edge_index (torch.Tensor): Predefined edges [2, E], where E is the number of edges.

        Returns:
            torch.Tensor: Node features after static edge aggregation.
        """
        row, col = edge_index  # Extract row (source) and col (target) nodes
        x_center = x[row]
        x_neighbor = x[col]

        # Compute edge features (relative)
        edge_features = torch.cat([x_center, x_neighbor - x_center], dim=-1)
        edge_features = self.nn_module(edge_features)

        # Aggregate features back to nodes
        num_nodes = x.size(0)
        node_features = torch.zeros(num_nodes, edge_features.size(-1), device=x.device)
        node_features.index_add_(0, row, edge_features)

        # Normalization (Divide by node degrees)
        counts = torch.bincount(row, minlength=num_nodes).clamp(min=1).view(-1, 1)
        node_features = node_features / counts

        return node_features


class CustomGATLayer(nn.Module):
    def __init__(self, in_dim, out_dim, heads=1, concat=True, dropout=0.6, alpha=0.4):
        """
        Initializes the Custom GAT Layer.

        Args:
            in_dim (int): Input feature dimension.
            out_dim (int): Output feature dimension per head.
            heads (int): Number of attention heads.
            concat (bool): Whether to concatenate the heads' output or average them.
            dropout (float): Dropout rate on attention coefficients.
            alpha (float): Negative slope for LeakyReLU.
        """
        super(CustomGATLayer, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.heads = heads
        self.concat = concat

        # Linear transformation for node features
        self.W = nn.Linear(in_dim, heads * out_dim, bias=False)

        # Attention mechanism: a vector for each head
        self.a_src = nn.Parameter(torch.zeros(heads, out_dim))
        self.a_tgt = nn.Parameter(torch.zeros(heads, out_dim))
        nn.init.xavier_uniform_(self.a_src.data, gain=1.414)
        nn.init.xavier_uniform_(self.a_tgt.data, gain=1.414)

        self.leakyrelu = nn.LeakyReLU(alpha)
        self.dropout = nn.Dropout(dropout)

        # Optional batch normalization
        self.batch_norm = nn.BatchNorm1d(heads * out_dim) if concat else nn.BatchNorm1d(out_dim)

    def forward(self, x, edge_index):
        """
        Forward pass of the GAT layer.

        Args:
            x (torch.Tensor): Node features of shape (N, in_dim).
            edge_index (torch.Tensor): Edge indices of shape (2, E).

        Returns:
            torch.Tensor: Updated node features after attention-based aggregation.
        """
        src, tgt = edge_index  # Source and target node indices
        N = x.size(0)

        # Apply linear transformation and reshape for multi-head attention
        h = self.W(x)  # Shape: (N, heads * out_dim)
        h = h.view(N, self.heads, self.out_dim)  # Shape: (N, heads, out_dim)

        # Gather node features for each edge
        h_src = h[src]  # Shape: (E, heads, out_dim)
        h_tgt = h[tgt]  # Shape: (E, heads, out_dim)

        # Compute attention coefficients using separate vectors for source and target
        e_src = (h_src * self.a_src).sum(dim=-1)  # Shape: (E, heads)
        e_tgt = (h_tgt * self.a_tgt).sum(dim=-1)  # Shape: (E, heads)
        e = self.leakyrelu(e_src + e_tgt)  # Shape: (E, heads)

        # Compute softmax normalization for attention coefficients
        # To ensure numerical stability
        e = e - e.max(dim=0, keepdim=True)[0]
        alpha = torch.exp(e)  # Shape: (E, heads)

        # Sum of attention coefficients for each target node and head
        alpha_sum = torch.zeros(N, self.heads, device=x.device).scatter_add_(0, tgt.unsqueeze(-1).expand(-1, self.heads), alpha)

        # Avoid division by zero
        alpha_sum = alpha_sum + 1e-16

        # Normalize attention coefficients
        alpha = alpha / alpha_sum[tgt]  # Shape: (E, heads)
        alpha = self.dropout(alpha)

        # Weighted aggregation of source node features
        h_prime = h_src * alpha.unsqueeze(-1)  # Shape: (E, heads, out_dim)

        # Initialize output tensor and aggregate
        out = torch.zeros(N, self.heads, self.out_dim, device=x.device)
        out.scatter_add_(0, tgt.unsqueeze(-1).unsqueeze(-1).expand(-1, self.heads, self.out_dim), h_prime)  # Shape: (N, heads, out_dim)

        # Concatenate or average the heads
        if self.concat:
            out = out.view(N, self.heads * self.out_dim)  # Shape: (N, heads*out_dim)
        else:
            out = out.mean(dim=1)  # Shape: (N, out_dim)

        # Apply batch normalization
        out = self.batch_norm(out)

        return out

class Net(nn.Module):
    def __init__(self, hidden_dim=64, num_layers=4, dropout=0.3, contrastive_dim=8, heads=4):
        """
        Initializes the neural network with alternating StaticEdgeConv and GAT layers.

        Args:
            hidden_dim (int): Dimension of hidden layers.
            num_layers (int): Total number of convolutional layers (both StaticEdgeConv and GAT).
            dropout (float): Dropout rate.
            contrastive_dim (int): Dimension of the contrastive output.
            heads (int): Number of attention heads in GAT layers.
        """
        super(Net, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.dropout = dropout
        self.contrastive_dim = contrastive_dim
        self.heads = heads

        # Input encoder
        self.lc_encode = nn.Sequential(
            nn.Linear(15, hidden_dim),
            nn.ELU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ELU()
        )

        # Define the network's convolutional layers, alternating between StaticEdgeConv and GAT
        self.convs = nn.ModuleList()
        for layer_idx in range(num_layers):
            if layer_idx % 2 == 0:
                # Even-indexed layers: StaticEdgeConv
                conv = CustomStaticEdgeConv(
                    nn.Sequential(
                        nn.Linear(2 * hidden_dim, hidden_dim),
                        nn.ELU(),
                        nn.BatchNorm1d(hidden_dim),
                        nn.Dropout(p=dropout)
                    )
                )
                self.convs.append(conv)
            else:
                # Odd-indexed layers: GAT
                gat = CustomGATLayer(
                    in_dim=hidden_dim,
                    out_dim=hidden_dim // heads if heads > 1 else hidden_dim,
                    heads=heads,
                    concat=True,
                    dropout=0.6,
                    alpha=0.4
                )
                self.convs.append(gat)

        # Output layer
        self.output = nn.Sequential(
            nn.Linear(hidden_dim, 32),
            nn.ELU(),
            nn.Dropout(p=dropout),
            nn.Linear(32, 16),
            nn.ELU(),
            nn.Dropout(p=dropout),
            nn.Linear(16, contrastive_dim)
        )

    def forward(self, x, edge_index, batch):
        """
        Forward pass of the network.

        Args:
            x (torch.Tensor): Input node features of shape (N, 15).
            edge_index (torch.Tensor): Edge indices of shape (2, E).
            batch (torch.Tensor): Batch vector.

        Returns:
            torch.Tensor: Output features after processing.
            torch.Tensor: Batch vector.
        """
        # Input encoding
        x_lc_enc = self.lc_encode(x)  # Shape: (N, hidden_dim)

        # Apply convolutional layers with residual connections
        feats = x_lc_enc
        for idx, conv in enumerate(self.convs):
            feats = conv(feats, edge_index) + feats  # Residual connection

        # Final output
        out = self.output(feats)
        return out, batch

# %%
# Initialize model with passed hyperparameters
model = Net(
    hidden_dim=128,
    num_layers=4,
    dropout=0.3,
    contrastive_dim=64,
    heads=16
)

k = 16
BS = 64

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)

# %% [markdown]
# # Define The Loss term and the Training + Val Setup

# %%
import torch
import torch.nn.functional as F
import random

def contrastive_loss_random(embeddings, pos_indices, group_ids, temperature=0.3):
    """
    Contrastive loss using a randomly selected negative.
    """
    loss_sum = 0.0
    count = 0
    group_ids = group_ids.long()
    
    for i in range(len(embeddings)):
        anchor = embeddings[i]
        positive = embeddings[pos_indices[i]]
        neg_mask = (group_ids != group_ids[i])
        if neg_mask.sum() == 0:
            continue
        negatives = embeddings[neg_mask]
        # Randomly sample one negative from the candidates.
        rand_idx = torch.randint(0, negatives.size(0), (1,)).item()
        neg_sample = negatives[rand_idx]
        
        pos_sim = F.cosine_similarity(anchor.unsqueeze(0), positive.unsqueeze(0))
        neg_sim = F.cosine_similarity(anchor.unsqueeze(0), neg_sample.unsqueeze(0))
        
        loss = -torch.log(
            torch.exp(pos_sim/temperature) / (torch.exp(pos_sim/temperature) + torch.exp(neg_sim/temperature))
        )
        loss_sum += loss
        count += 1
    return loss_sum / count if count > 0 else torch.tensor(0.0, device=embeddings.device)

def contrastive_loss_hard(embeddings, pos_indices, group_ids, temperature=0.3):
    """
    Contrastive loss using hard negative mining.
    """
    loss_sum = 0.0
    count = 0
    group_ids = group_ids.long()
    
    for i in range(len(embeddings)):
        anchor = embeddings[i]
        positive = embeddings[pos_indices[i]]
        neg_mask = (group_ids != group_ids[i])
        if neg_mask.sum() == 0:
            continue
        negatives = embeddings[neg_mask]
        # Hard negative: the candidate with maximum cosine similarity.
        cos_sim = F.cosine_similarity(anchor.unsqueeze(0), negatives)
        hard_neg_sim = cos_sim.max()
        
        pos_sim = F.cosine_similarity(anchor.unsqueeze(0), positive.unsqueeze(0))
        
        loss = -torch.log(
            torch.exp(pos_sim/temperature) / (torch.exp(pos_sim/temperature) + torch.exp(hard_neg_sim/temperature))
        )
        loss_sum += loss
        count += 1
    return loss_sum / count if count > 0 else torch.tensor(0.0, device=embeddings.device)

def contrastive_loss_curriculum(embeddings, pos_indices, group_ids, temperature=0.3, alpha=1.0):
    """
    Blends the random-negative loss and the hard-negative loss.
    When alpha=0, uses only random negatives (easy scenario);
    When alpha=1, uses only hard negatives.
    """
    loss_random = contrastive_loss_random(embeddings, pos_indices, group_ids, temperature)
    loss_hard = contrastive_loss_hard(embeddings, pos_indices, group_ids, temperature)
    return (1 - alpha) * loss_random + alpha * loss_hard

# %%
##############################################
# OLD CONTRASTIVE LOSS & TRAIN/TEST FUNCTIONS
##############################################

def contrastive_loss(start_all, end_all, temperature=0.1):
    # Normalize the start and end embeddings
    z_start = F.normalize(start_all, dim=1)
    z_end = F.normalize(end_all, dim=1)
    # Split into positive and negative halves
    half = int(len(z_start) / 2)
    positives = torch.exp(F.cosine_similarity(z_start[:half], z_end[:half], dim=1))
    negatives = torch.exp(F.cosine_similarity(z_start[half:], z_end[half:], dim=1))
    nominator = positives / temperature
    denominator = negatives
    loss = torch.exp(-nominator.sum() / denominator.sum())
    return loss

def train_old(train_loader, model, optimizer, device, k_value):
    model.train()
    total_loss = 0.0
    for data in tqdm.tqdm(train_loader):
        data = data.to(device)
        optimizer.zero_grad()

        edge_index = knn_graph(data.x[:, :3], k=k_value, batch=data.x_batch)
        out = model(data.x, edge_index, data.x_batch)

        # Get event partitioning information.
        values, counts = np.unique(data.x_batch.detach().cpu().numpy(), return_counts=True)
        losses = []
        for e in range(len(counts)):
            lower_edge = 0 if e == 0 else np.sum(counts[:e])
            upper_edge = lower_edge + counts[e]

            start_pos = out[0][lower_edge:upper_edge][data.x_pe[lower_edge:upper_edge, 0]]
            end_pos   = out[0][lower_edge:upper_edge][data.x_pe[lower_edge:upper_edge, 1]]
            start_neg = out[0][lower_edge:upper_edge][data.x_ne[lower_edge:upper_edge, 0]]
            end_neg   = out[0][lower_edge:upper_edge][data.x_ne[lower_edge:upper_edge, 1]]

            start_all = torch.cat((start_pos, start_neg), 0)
            end_all   = torch.cat((end_pos, end_neg), 0)

            if len(losses) == 0:
                losses.append(contrastive_loss(start_all, end_all, 0.3))
            else:
                losses.append(losses[-1] + contrastive_loss(start_all, end_all, 0.3))

        loss = losses[-1]
        loss.backward()
        total_loss += loss.item()
        optimizer.step()
    return total_loss / len(train_loader.dataset)

@torch.no_grad()
def test_old(test_loader, model, device, k_value):
    model.eval()
    total_loss = 0.0
    for data in tqdm.tqdm(test_loader):
        data = data.to(device)
        edge_index = knn_graph(data.x[:, :3], k=k_value, batch=data.x_batch)
        out = model(data.x, edge_index, data.x_batch)
        values, counts = np.unique(data.x_batch.detach().cpu().numpy(), return_counts=True)
        losses = []
        for e in range(len(counts)):
            lower_edge = 0 if e == 0 else np.sum(counts[:e])
            upper_edge = lower_edge + counts[e]

            start_pos = out[0][lower_edge:upper_edge][data.x_pe[lower_edge:upper_edge, 0]]
            end_pos   = out[0][lower_edge:upper_edge][data.x_pe[lower_edge:upper_edge, 1]]
            start_neg = out[0][lower_edge:upper_edge][data.x_ne[lower_edge:upper_edge, 0]]
            end_neg   = out[0][lower_edge:upper_edge][data.x_ne[lower_edge:upper_edge, 1]]

            start_all = torch.cat((start_pos, start_neg), 0)
            end_all   = torch.cat((end_pos, end_neg), 0)

            if len(losses) == 0:
                losses.append(contrastive_loss(start_all, end_all, 0.3))
            else:
                losses.append(losses[-1] + contrastive_loss(start_all, end_all, 0.3))
        loss = losses[-1]
        total_loss += loss.item()
    return total_loss / len(test_loader.dataset)

##############################################
# NEW (Curriculum) Loss & TRAIN/TEST FUNCTIONS
##############################################

def contrastive_loss_random(embeddings, pos_indices, group_ids, temperature=0.3):
    """
    Contrastive loss using a randomly selected negative.
    """
    loss_sum = 0.0
    count = 0
    group_ids = group_ids.long()
    
    for i in range(len(embeddings)):
        anchor = embeddings[i]
        positive = embeddings[pos_indices[i]]
        neg_mask = (group_ids != group_ids[i])
        if neg_mask.sum() == 0:
            continue
        negatives = embeddings[neg_mask]
        # Randomly sample one negative.
        rand_idx = torch.randint(0, negatives.size(0), (1,)).item()
        neg_sample = negatives[rand_idx]
        pos_sim = F.cosine_similarity(anchor.unsqueeze(0), positive.unsqueeze(0))
        neg_sim = F.cosine_similarity(anchor.unsqueeze(0), neg_sample.unsqueeze(0))
        loss = -torch.log(
            torch.exp(pos_sim/temperature) / (torch.exp(pos_sim/temperature) + torch.exp(neg_sim/temperature))
        )
        loss_sum += loss
        count += 1
    return loss_sum / count if count > 0 else torch.tensor(0.0, device=embeddings.device)

def contrastive_loss_hard(embeddings, pos_indices, group_ids, temperature=0.3):
    """
    Contrastive loss using hard negative mining (loop version).
    """
    loss_sum = 0.0
    count = 0
    group_ids = group_ids.long()
    
    for i in range(len(embeddings)):
        anchor = embeddings[i]
        positive = embeddings[pos_indices[i]]
        neg_mask = (group_ids != group_ids[i])
        if neg_mask.sum() == 0:
            continue
        negatives = embeddings[neg_mask]
        cos_sim = F.cosine_similarity(anchor.unsqueeze(0), negatives)
        hard_neg_sim = cos_sim.max()
        pos_sim = F.cosine_similarity(anchor.unsqueeze(0), positive.unsqueeze(0))
        loss = -torch.log(
            torch.exp(pos_sim/temperature) / (torch.exp(pos_sim/temperature) + torch.exp(hard_neg_sim/temperature))
        )
        loss_sum += loss
        count += 1
    return loss_sum / count if count > 0 else torch.tensor(0.0, device=embeddings.device)

def contrastive_loss_curriculum(embeddings, pos_indices, group_ids, temperature=0.3, alpha=1.0):
    """
    Blends the random-negative loss and the hard-negative loss.
    When alpha=0: only random negatives; when alpha=1: only hard negatives.
    """
    loss_random = contrastive_loss_random(embeddings, pos_indices, group_ids, temperature)
    loss_hard = contrastive_loss_hard(embeddings, pos_indices, group_ids, temperature)
    return (1 - alpha) * loss_random + alpha * loss_hard

def train_new(train_loader, model, optimizer, device, k_value, alpha):
    model.train()
    total_loss = 0.0
    for data in tqdm.tqdm(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        
        # Convert data.assoc to tensor if needed.
        if isinstance(data.assoc, list):
            if isinstance(data.assoc[0], list):
                assoc_tensor = torch.cat([torch.tensor(a, dtype=torch.int64, device=data.x.device)
                                          for a in data.assoc])
            else:
                assoc_tensor = torch.tensor(data.assoc, device=data.x.device)
        else:
            assoc_tensor = data.assoc

        edge_index = knn_graph(data.x[:, :3], k=k_value, batch=data.x_batch)
        embeddings, _ = model(data.x, edge_index, data.x_batch)
        
        # Partition batch by event.
        batch_np = data.x_batch.detach().cpu().numpy()
        _, counts = np.unique(batch_np, return_counts=True)
        
        loss_event_total = 0.0
        start_idx = 0
        for count in counts:
            end_idx = start_idx + count
            event_embeddings = embeddings[start_idx:end_idx]
            event_group_ids = assoc_tensor[start_idx:end_idx]
            event_pos_indices = data.x_pe[start_idx:end_idx, 1].view(-1)
            loss_event = contrastive_loss_curriculum(event_embeddings, event_pos_indices, event_group_ids,
                                                     temperature=0.3, alpha=alpha)
            loss_event_total += loss_event
            start_idx = end_idx
        
        loss = loss_event_total / len(counts)
        loss.backward()
        total_loss += loss.item()
        optimizer.step()
    return total_loss / len(train_loader.dataset)

@torch.no_grad()
def test_new(test_loader, model, device, k_value):
    model.eval()
    total_loss = 0.0
    for data in tqdm.tqdm(test_loader):
        data = data.to(device)
        
        if isinstance(data.assoc, list):
            if isinstance(data.assoc[0], list):
                assoc_tensor = torch.cat([torch.tensor(a, dtype=torch.int64, device=data.x.device)
                                          for a in data.assoc])
            else:
                assoc_tensor = torch.tensor(data.assoc, device=data.x.device)
        else:
            assoc_tensor = data.assoc
        
        edge_index = knn_graph(data.x[:, :3], k=k_value, batch=data.x_batch)
        embeddings, _ = model(data.x, edge_index, data.x_batch)
        
        batch_np = data.x_batch.detach().cpu().numpy()
        _, counts = np.unique(batch_np, return_counts=True)
        
        loss_event_total = 0.0
        start_idx = 0
        for count in counts:
            end_idx = start_idx + count
            event_embeddings = embeddings[start_idx:end_idx]
            event_group_ids = assoc_tensor[start_idx:end_idx]
            event_pos_indices = data.x_pe[start_idx:end_idx, 1].view(-1)
            # For testing, we can use the hard-negative loss.
            loss_event = contrastive_loss_hard(event_embeddings, event_pos_indices, event_group_ids, temperature=0.3)
            loss_event_total += loss_event
            start_idx = end_idx
        total_loss += loss_event_total / len(counts)
    return total_loss / len(test_loader.dataset)

# %% [markdown]
# # Train and Validate

# %%
device = torch.device('cpu')
# Load DataLoader with current batch_size
train_loader = DataLoader(data_train, batch_size=BS, shuffle=True, follow_batch=['x'])
val_loader = DataLoader(data_val, batch_size=BS, shuffle=False, follow_batch=['x'])

# Train and evaluate the model for the specified number of epochs
best_val_loss = float('inf')

# Store train and validation losses for all epochs
train_losses = []
val_losses = []

output_dir = '/vols/cms/mm1221/hgcal/pion5New/Track/resultsEndHard/SEGATxyz/'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
epochs = 20
for epoch in range(epochs):
    print(f'Epoch {epoch+1}/{epochs}')
    
    # For epochs 1-20 use the old loss method.
    if epoch < 2:
        train_loss = train_old(train_loader, model, optimizer, device, k)
        val_loss = test_old(val_loader, model, device, k)
        print(f"Old Method: Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    # For epochs 21-30, gradually shift from random negatives (alpha=0) to hard negatives (alpha=1).
    elif epoch < 4:
        alpha = (epoch - 2) / 2.0   # linearly increase from 0 to 1
        train_loss = train_new(train_loader, model, optimizer, device, k, alpha)
        val_loss = test_new(val_loader, model, device, k)
        print(f"Transition Method (alpha={alpha:.2f}): Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    # For epochs 31-40, use the new method with hard negatives (alpha=1).
    else:
        alpha = 1.0
        train_loss = train_new(train_loader, model, optimizer, device, k, alpha)
        val_loss = test_new(val_loader, model, device, k)
        print(f"New Method (alpha={alpha}): Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
    

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    # Adjust the learning rate
    scheduler.step()

    # Save the best model if this epoch's validation loss is lower
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), os.path.join(output_dir, 'best_model.pt'))

    # Save intermediate state dictionaries
    state_dicts = {'model': model.state_dict(), 'opt': optimizer.state_dict(), 'lr': scheduler.state_dict()}
    torch.save(state_dicts, os.path.join(output_dir, f'epoch-{epoch}.pt'))

    print(f'Epoch {epoch+1}/{epochs} - Train Loss: {train_loss}, Validation Loss: {val_loss}')



# Save training and validation loss curves
loss_result_filename = (
    'result.csv'
)

# Dynamically adjust the epoch range to match the length of train_losses and val_losses
results_df = pd.DataFrame({
    'epoch': list(range(1, len(train_losses) + 1)),  # Adjusted to the actual length of losses
    'train_loss': train_losses,
    'val_loss': val_losses
})

# Save to a CSV file in the output directory
results_df.to_csv(os.path.join(output_dir, loss_result_filename), index=False)

print(f'Saved training and validation losses to {os.path.join(output_dir, loss_result_filename)}')
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 1/20
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 194/194 [01:49<00:00,  1.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:06<00:00,  3.63it/s]
# Old Method: Train Loss: 0.0083, Val Loss: 0.0020
# Epoch 1/20 - Train Loss: 0.008330954226158543, Validation Loss: 0.002001957932555419
# Epoch 2/20
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 194/194 [01:44<00:00,  1.85it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:06<00:00,  3.66it/s]
# Old Method: Train Loss: 0.0019, Val Loss: 0.0009
# Epoch 2/20 - Train Loss: 0.0019222859552106676, Validation Loss: 0.0009232569384646476
# Epoch 3/20
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 194/194 [09:17<00:00,  2.88s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:12<00:00,  2.04it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_921663/3482734383.py in <module>
#      30         train_loss = train_new(train_loader, model, optimizer, device, k, alpha)
#      31         val_loss = test_new(val_loader, model, device, k)
# ---> 32         print(f"Transition Method (alpha={alpha:.2f}): Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
#      33     # For epochs 31-40, use the new method with hard negatives (alpha=1).
#      34     else:
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch/_tensor.py in __format__(self, format_spec)
#     932         if self.dim() == 0 and not self.is_meta and type(self) is Tensor:
#     933             return self.item().__format__(format_spec)
# --> 934         return object.__format__(self, format_spec)
#     935
#     936     @_handle_torch_function_and_wrap_type_error_to_not_implemented
#
# TypeError: unsupported format string passed to Tensor.__format__

# %% [markdown]
# # Testing

# %% [markdown]
# ## Loading Testing Data

# %%
testpath = "/vols/cms/mm1221/Data/100k/5pi/test/"

data_test = CCV1(testpath, max_events=10000, inp='test')
# Out:
# ### Loading tracksters data
#   0%|                                                                                                                                                                                 | 0/1 [00:00<?, ?it/s]
# /vols/cms/mm1221/Data/100k/5pi/test/raw/test.root
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.42s/it]

# %%
#checkpoint= torch.load('/vols/cms/mm1221/hgcal/pion5New/Track/StaticEdge/results/SEGAT/results_lr0.001_bs64_hd128_nl4_do0.3_k16_cd64/best_model.pt',  map_location=torch.device('cpu'))
checkpoint= torch.load('/vols/cms/mm1221/hgcal/pion5New/Track/NegativeMining/resultsRandHard/best_model.pt',  map_location=torch.device('cpu'))

model.load_state_dict(checkpoint)  
model.eval()
# Out:
# Net(
#   (lc_encode): Sequential(
#     (0): Linear(in_features=15, out_features=128, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ELU(alpha=1.0)
#   )
#   (convs): ModuleList(
#     (0): CustomStaticEdgeConv(
#       (nn_module): Sequential(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): ELU(alpha=1.0)
#         (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Dropout(p=0.3, inplace=False)
#       )
#     )
#     (1): CustomGATLayer(
#       (W): Linear(in_features=128, out_features=128, bias=False)
#       (leakyrelu): LeakyReLU(negative_slope=0.4)
#       (dropout): Dropout(p=0.6, inplace=False)
#       (batch_norm): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): CustomStaticEdgeConv(
#       (nn_module): Sequential(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): ELU(alpha=1.0)
#         (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Dropout(p=0.3, inplace=False)
#       )
#     )
#     (3): CustomGATLayer(
#       (W): Linear(in_features=128, out_features=128, bias=False)
#       (leakyrelu): LeakyReLU(negative_slope=0.4)
#       (dropout): Dropout(p=0.6, inplace=False)
#       (batch_norm): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (output): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ELU(alpha=1.0)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=16, out_features=64, bias=True)
#   )
# )

# %%
all_predictions = []  


for i, data in enumerate(data_test):
    edge_index = knn_graph(data.x[:, :3], k=k)  
    predictions = model(data.x, edge_index, 1)
    all_predictions.append(predictions[0].detach().cpu().numpy())  
    
all_predictions = np.array(all_predictions)
# Out:
# /tmp/ipykernel_1244483/2736649685.py:9: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   all_predictions = np.array(all_predictions)

# %%
import numpy as np
import hdbscan

def HDBSCANClustering(all_predictions, 
                      min_cluster_size=5, 
                      min_samples=None, 
                      metric='euclidean', 
                      alpha=1.0,
                      cluster_selection_method='eom',
                      prediction_data=False,
                      allow_single_cluster=True,
                      core_dist_n_jobs=1,
                      cluster_selection_epsilon=0.0):
    """
    Performs HDBSCAN clustering on a list of prediction arrays with more hyperparameter control.

    Parameters:
    - all_predictions: List of numpy arrays, each containing data points for an event.
    - min_cluster_size: Minimum size of clusters.
    - min_samples: Number of samples in a neighborhood for a point to be considered a core point.
                   If None, it defaults to min_cluster_size.
    - metric: Distance metric to use.
    - alpha: Controls the balance between single linkage and average linkage clustering.
    - cluster_selection_method: 'eom' (Excess of Mass) or 'leaf' for finer clusters.
    - prediction_data: If True, allows later predictions on new data.
    - allow_single_cluster: If True, allows a single large cluster when applicable.
    - core_dist_n_jobs: Number of parallel jobs (-1 uses all cores).
    - cluster_selection_epsilon: Threshold distance for cluster selection (default 0.0).

    Returns:
    - all_cluster_labels: NumPy array of cluster labels for all events.
    """
    all_cluster_labels = []             

    for i, pred in enumerate(all_predictions):
        print(f"Processing event {i+1}/{len(all_predictions)}...")
        
        if len(pred) < 2:
            # Assign all points to cluster 0 (since HDBSCAN uses -1 for noise)
            cluster_labels = np.zeros(len(pred), dtype=int) 
        else:
            # Initialize HDBSCAN with specified parameters
            clusterer = hdbscan.HDBSCAN(
                min_cluster_size=min_cluster_size,
                min_samples=min_samples if min_samples is not None else min_cluster_size,
                metric=metric,
                alpha=alpha,
                cluster_selection_method=cluster_selection_method,
                prediction_data=prediction_data,
                allow_single_cluster=allow_single_cluster,
                core_dist_n_jobs=core_dist_n_jobs,
                cluster_selection_epsilon=cluster_selection_epsilon
            )
            
            # Perform clustering
            cluster_labels = clusterer.fit_predict(pred)  
        
        all_cluster_labels.append(cluster_labels)
    
    # Convert the list of cluster labels to a NumPy array
    all_cluster_labels = np.array(all_cluster_labels)
    return all_cluster_labels

all_cluster_labels = HDBSCANClustering(
    all_predictions, 
    min_cluster_size=2,  # Ensures at least 3 points per cluster
    metric='euclidean',  # Change distance metric
    alpha=1.0,  # Increase single linkage weighting
    cluster_selection_method='leaf',  # Allow finer clusters
    prediction_data=False,  # Enable future prediction capability
    allow_single_cluster=True,  # Allow one large cluster
    core_dist_n_jobs=-1  # Use all available CPU cores
)
# Out:
# Processing event 1/9536...
# Processing event 2/9536...
# Processing event 3/9536...
# Processing event 4/9536...
# Processing event 5/9536...
# Processing event 6/9536...
# Processing event 7/9536...
# Processing event 8/9536...
# Processing event 9/9536...
# Processing event 10/9536...
# Processing event 11/9536...
# Processing event 12/9536...
# Processing event 13/9536...
# Processing event 14/9536...
# Processing event 15/9536...
# Processing event 16/9536...
# Processing event 17/9536...
# Processing event 18/9536...
# Processing event 19/9536...
# Processing event 20/9536...
# Processing event 21/9536...
# Processing event 22/9536...
# Processing event 23/9536...
# Processing event 24/9536...
# Processing event 25/9536...
# Processing event 26/9536...
# Processing event 27/9536...
# Processing event 28/9536...
# Processing event 29/9536...
# Processing event 30/9536...
# Processing event 31/9536...
# Processing event 32/9536...
# Processing event 33/9536...
# Processing event 34/9536...
# Processing event 35/9536...
# Processing event 36/9536...
# Processing event 37/9536...
# Processing event 38/9536...
# Processing event 39/9536...
# Processing event 40/9536...
# Processing event 41/9536...
# Processing event 42/9536...
# Processing event 43/9536...
# Processing event 44/9536...
# Processing event 45/9536...
# Processing event 46/9536...
# Processing event 47/9536...
# Processing event 48/9536...
# Processing event 49/9536...
# Processing event 50/9536...
# Processing event 51/9536...
# Processing event 52/9536...
# Processing event 53/9536...
# Processing event 54/9536...
# Processing event 55/9536...
# Processing event 56/9536...
# Processing event 57/9536...
# Processing event 58/9536...
# Processing event 59/9536...
# Processing event 60/9536...
# Processing event 61/9536...
# Processing event 62/9536...
# Processing event 63/9536...
# Processing event 64/9536...
# Processing event 65/9536...
# Processing event 66/9536...
# Processing event 67/9536...
# Processing event 68/9536...
# Processing event 69/9536...
# Processing event 70/9536...
# Processing event 71/9536...
# Processing event 72/9536...
# Processing event 73/9536...
# Processing event 74/9536...
# Processing event 75/9536...
# Processing event 76/9536...
# Processing event 77/9536...
# Processing event 78/9536...
# Processing event 79/9536...
# Processing event 80/9536...
# Processing event 81/9536...
# Processing event 82/9536...
# Processing event 83/9536...
# Processing event 84/9536...
# Processing event 85/9536...
# Processing event 86/9536...
# Processing event 87/9536...
# Processing event 88/9536...
# Processing event 89/9536...
# Processing event 90/9536...
# Processing event 91/9536...
# Processing event 92/9536...
# Processing event 93/9536...
# Processing event 94/9536...
# Processing event 95/9536...
# Processing event 96/9536...
# Processing event 97/9536...
# Processing event 98/9536...
# Processing event 99/9536...
# Processing event 100/9536...
# Processing event 101/9536...
# Processing event 102/9536...
# Processing event 103/9536...
# Processing event 104/9536...
# Processing event 105/9536...
# Processing event 106/9536...
# Processing event 107/9536...
# Processing event 108/9536...
# Processing event 109/9536...
# Processing event 110/9536...
# Processing event 111/9536...
# Processing event 112/9536...
# Processing event 113/9536...
# Processing event 114/9536...
# Processing event 115/9536...
# Processing event 116/9536...
# Processing event 117/9536...
# Processing event 118/9536...
# Processing event 119/9536...
# Processing event 120/9536...
# Processing event 121/9536...
# Processing event 122/9536...
# Processing event 123/9536...
# Processing event 124/9536...
# Processing event 125/9536...
# Processing event 126/9536...
# Processing event 127/9536...
# Processing event 128/9536...
# Processing event 129/9536...
# Processing event 130/9536...
# Processing event 131/9536...
# Processing event 132/9536...
# Processing event 133/9536...
# Processing event 134/9536...
# Processing event 135/9536...
# Processing event 136/9536...
# Processing event 137/9536...
# Processing event 138/9536...
# Processing event 139/9536...
# Processing event 140/9536...
# Processing event 141/9536...
# Processing event 142/9536...
# Processing event 143/9536...
# Processing event 144/9536...
# Processing event 145/9536...
# Processing event 146/9536...
# Processing event 147/9536...
# Processing event 148/9536...
# Processing event 149/9536...
# Processing event 150/9536...
# Processing event 151/9536...
# Processing event 152/9536...
# Processing event 153/9536...
# Processing event 154/9536...
# Processing event 155/9536...
# Processing event 156/9536...
# Processing event 157/9536...
# Processing event 158/9536...
# Processing event 159/9536...
# Processing event 160/9536...
# Processing event 161/9536...
# Processing event 162/9536...
# Processing event 163/9536...
# Processing event 164/9536...
# Processing event 165/9536...
# Processing event 166/9536...
# Processing event 167/9536...
# Processing event 168/9536...
# Processing event 169/9536...
# Processing event 170/9536...
# Processing event 171/9536...
# Processing event 172/9536...
# Processing event 173/9536...
# Processing event 174/9536...
# Processing event 175/9536...
# Processing event 176/9536...
# Processing event 177/9536...
# Processing event 178/9536...
# Processing event 179/9536...
# Processing event 180/9536...
# Processing event 181/9536...
# Processing event 182/9536...
# Processing event 183/9536...
# Processing event 184/9536...
# Processing event 185/9536...
# Processing event 186/9536...
# Processing event 187/9536...
# Processing event 188/9536...
# Processing event 189/9536...
# Processing event 190/9536...
# Processing event 191/9536...
# Processing event 192/9536...
# Processing event 193/9536...
# Processing event 194/9536...
# Processing event 195/9536...
# Processing event 196/9536...
# Processing event 197/9536...
# Processing event 198/9536...
# Processing event 199/9536...
# Processing event 200/9536...
# Processing event 201/9536...
# Processing event 202/9536...
# Processing event 203/9536...
# Processing event 204/9536...
# Processing event 205/9536...
# Processing event 206/9536...
# Processing event 207/9536...
# Processing event 208/9536...
# Processing event 209/9536...
# Processing event 210/9536...
# Processing event 211/9536...
# Processing event 212/9536...
# Processing event 213/9536...
# Processing event 214/9536...
# Processing event 215/9536...
# Processing event 216/9536...
# Processing event 217/9536...
# Processing event 218/9536...
# Processing event 219/9536...
# Processing event 220/9536...
# Processing event 221/9536...
# Processing event 222/9536...
# Processing event 223/9536...
# Processing event 224/9536...
# Processing event 225/9536...
# Processing event 226/9536...
# Processing event 227/9536...
# Processing event 228/9536...
# Processing event 229/9536...
# Processing event 230/9536...
# Processing event 231/9536...
# Processing event 232/9536...
# Processing event 233/9536...
# Processing event 234/9536...
# Processing event 235/9536...
# Processing event 236/9536...
# Processing event 237/9536...
# Processing event 238/9536...
# Processing event 239/9536...
# Processing event 240/9536...
# Processing event 241/9536...
# Processing event 242/9536...
# Processing event 243/9536...
# Processing event 244/9536...
# Processing event 245/9536...
# Processing event 246/9536...
# Processing event 247/9536...
# Processing event 248/9536...
# Processing event 249/9536...
# Processing event 250/9536...
# Processing event 251/9536...
# Processing event 252/9536...
# Processing event 253/9536...
# Processing event 254/9536...
# Processing event 255/9536...
# Processing event 256/9536...
# Processing event 257/9536...
# Processing event 258/9536...
# Processing event 259/9536...
# Processing event 260/9536...
# Processing event 261/9536...
# Processing event 262/9536...
# Processing event 263/9536...
# Processing event 264/9536...
# Processing event 265/9536...
# Processing event 266/9536...
# Processing event 267/9536...
# Processing event 268/9536...
# Processing event 269/9536...
# Processing event 270/9536...
# Processing event 271/9536...
# Processing event 272/9536...
# Processing event 273/9536...
# Processing event 274/9536...
# Processing event 275/9536...
# Processing event 276/9536...
# Processing event 277/9536...
# Processing event 278/9536...
# Processing event 279/9536...
# Processing event 280/9536...
# Processing event 281/9536...
# Processing event 282/9536...
# Processing event 283/9536...
# Processing event 284/9536...
# Processing event 285/9536...
# Processing event 286/9536...
# Processing event 287/9536...
# Processing event 288/9536...
# Processing event 289/9536...
# Processing event 290/9536...
# Processing event 291/9536...
# Processing event 292/9536...
# Processing event 293/9536...
# Processing event 294/9536...
# Processing event 295/9536...
# Processing event 296/9536...
# Processing event 297/9536...
# Processing event 298/9536...
# Processing event 299/9536...
# Processing event 300/9536...
# Processing event 301/9536...
# Processing event 302/9536...
# Processing event 303/9536...
# Processing event 304/9536...
# Processing event 305/9536...
# Processing event 306/9536...
# Processing event 307/9536...
# Processing event 308/9536...
# Processing event 309/9536...
# Processing event 310/9536...
# Processing event 311/9536...
# Processing event 312/9536...
# Processing event 313/9536...
# Processing event 314/9536...
# Processing event 315/9536...
# Processing event 316/9536...
# Processing event 317/9536...
# Processing event 318/9536...
# Processing event 319/9536...
# Processing event 320/9536...
# Processing event 321/9536...
# Processing event 322/9536...
# Processing event 323/9536...
# Processing event 324/9536...
# Processing event 325/9536...
# Processing event 326/9536...
# Processing event 327/9536...
# Processing event 328/9536...
# Processing event 329/9536...
# Processing event 330/9536...
# Processing event 331/9536...
# Processing event 332/9536...
# Processing event 333/9536...
# Processing event 334/9536...
# Processing event 335/9536...
# Processing event 336/9536...
# Processing event 337/9536...
# Processing event 338/9536...
# Processing event 339/9536...
# Processing event 340/9536...
# Processing event 341/9536...
# Processing event 342/9536...
# Processing event 343/9536...
# Processing event 344/9536...
# Processing event 345/9536...
# Processing event 346/9536...
# Processing event 347/9536...
# Processing event 348/9536...
# Processing event 349/9536...
# Processing event 350/9536...
# Processing event 351/9536...
# Processing event 352/9536...
# Processing event 353/9536...
# Processing event 354/9536...
# Processing event 355/9536...
# Processing event 356/9536...
# Processing event 357/9536...
# Processing event 358/9536...
# Processing event 359/9536...
# Processing event 360/9536...
# Processing event 361/9536...
# Processing event 362/9536...
# Processing event 363/9536...
# Processing event 364/9536...
# Processing event 365/9536...
# Processing event 366/9536...
# Processing event 367/9536...
# Processing event 368/9536...
# Processing event 369/9536...
# Processing event 370/9536...
# Processing event 371/9536...
# Processing event 372/9536...
# Processing event 373/9536...
# Processing event 374/9536...
# Processing event 375/9536...
# Processing event 376/9536...
# Processing event 377/9536...
# Processing event 378/9536...
# Processing event 379/9536...
# Processing event 380/9536...
# Processing event 381/9536...
# Processing event 382/9536...
# Processing event 383/9536...
# Processing event 384/9536...
# Processing event 385/9536...
# Processing event 386/9536...
# Processing event 387/9536...
# Processing event 388/9536...
# Processing event 389/9536...
# Processing event 390/9536...
# Processing event 391/9536...
# Processing event 392/9536...
# Processing event 393/9536...
# Processing event 394/9536...
# Processing event 395/9536...
# Processing event 396/9536...
# Processing event 397/9536...
# Processing event 398/9536...
# Processing event 399/9536...
# Processing event 400/9536...
# Processing event 401/9536...
# Processing event 402/9536...
# Processing event 403/9536...
# Processing event 404/9536...
# Processing event 405/9536...
# Processing event 406/9536...
# Processing event 407/9536...
# Processing event 408/9536...
# Processing event 409/9536...
# Processing event 410/9536...
# Processing event 411/9536...
# Processing event 412/9536...
# Processing event 413/9536...
# Processing event 414/9536...
# Processing event 415/9536...
# Processing event 416/9536...
# Processing event 417/9536...
# Processing event 418/9536...
# Processing event 419/9536...
# Processing event 420/9536...
# Processing event 421/9536...
# Processing event 422/9536...
# Processing event 423/9536...
# Processing event 424/9536...
# Processing event 425/9536...
# Processing event 426/9536...
# Processing event 427/9536...
# Processing event 428/9536...
# Processing event 429/9536...
# Processing event 430/9536...
# Processing event 431/9536...
# Processing event 432/9536...
# Processing event 433/9536...
# Processing event 434/9536...
# Processing event 435/9536...
# Processing event 436/9536...
# Processing event 437/9536...
# Processing event 438/9536...
# Processing event 439/9536...
# Processing event 440/9536...
# Processing event 441/9536...
# Processing event 442/9536...
# Processing event 443/9536...
# Processing event 444/9536...
# Processing event 445/9536...
# Processing event 446/9536...
# Processing event 447/9536...
# Processing event 448/9536...
# Processing event 449/9536...
# Processing event 450/9536...
# Processing event 451/9536...
# Processing event 452/9536...
# Processing event 453/9536...
# Processing event 454/9536...
# Processing event 455/9536...
# Processing event 456/9536...
# Processing event 457/9536...
# Processing event 458/9536...
# Processing event 459/9536...
# Processing event 460/9536...
# Processing event 461/9536...
# Processing event 462/9536...
# Processing event 463/9536...
# Processing event 464/9536...
# Processing event 465/9536...
# Processing event 466/9536...
# Processing event 467/9536...
# Processing event 468/9536...
# Processing event 469/9536...
# Processing event 470/9536...
# Processing event 471/9536...
# Processing event 472/9536...
# Processing event 473/9536...
# Processing event 474/9536...
# Processing event 475/9536...
# Processing event 476/9536...
# Processing event 477/9536...
# Processing event 478/9536...
# Processing event 479/9536...
# Processing event 480/9536...
# Processing event 481/9536...
# Processing event 482/9536...
# Processing event 483/9536...
# Processing event 484/9536...
# Processing event 485/9536...
# Processing event 486/9536...
# Processing event 487/9536...
# Processing event 488/9536...
# Processing event 489/9536...
# Processing event 490/9536...
# Processing event 491/9536...
# Processing event 492/9536...
# Processing event 493/9536...
# Processing event 494/9536...
# Processing event 495/9536...
# Processing event 496/9536...
# Processing event 497/9536...
# Processing event 498/9536...
# Processing event 499/9536...
# Processing event 500/9536...
# Processing event 501/9536...
# Processing event 502/9536...
# Processing event 503/9536...
# Processing event 504/9536...
# Processing event 505/9536...
# Processing event 506/9536...
# Processing event 507/9536...
# Processing event 508/9536...
# Processing event 509/9536...
# Processing event 510/9536...
# Processing event 511/9536...
# Processing event 512/9536...
# Processing event 513/9536...
# Processing event 514/9536...
# Processing event 515/9536...
# Processing event 516/9536...
# Processing event 517/9536...
# Processing event 518/9536...
# Processing event 519/9536...
# Processing event 520/9536...
# Processing event 521/9536...
# Processing event 522/9536...
# Processing event 523/9536...
# Processing event 524/9536...
# Processing event 525/9536...
# Processing event 526/9536...
# Processing event 527/9536...
# Processing event 528/9536...
# Processing event 529/9536...
# Processing event 530/9536...
# Processing event 531/9536...
# Processing event 532/9536...
# Processing event 533/9536...
# Processing event 534/9536...
# Processing event 535/9536...
# Processing event 536/9536...
# Processing event 537/9536...
# Processing event 538/9536...
# Processing event 539/9536...
# Processing event 540/9536...
# Processing event 541/9536...
# Processing event 542/9536...
# Processing event 543/9536...
# Processing event 544/9536...
# Processing event 545/9536...
# Processing event 546/9536...
# Processing event 547/9536...
# Processing event 548/9536...
# Processing event 549/9536...
# Processing event 550/9536...
# Processing event 551/9536...
# Processing event 552/9536...
# Processing event 553/9536...
# Processing event 554/9536...
# Processing event 555/9536...
# Processing event 556/9536...
# Processing event 557/9536...
# Processing event 558/9536...
# Processing event 559/9536...
# Processing event 560/9536...
# Processing event 561/9536...
# Processing event 562/9536...
# Processing event 563/9536...
# Processing event 564/9536...
# Processing event 565/9536...
# Processing event 566/9536...
# Processing event 567/9536...
# Processing event 568/9536...
# Processing event 569/9536...
# Processing event 570/9536...
# Processing event 571/9536...
# Processing event 572/9536...
# Processing event 573/9536...
# Processing event 574/9536...
# Processing event 575/9536...
# Processing event 576/9536...
# Processing event 577/9536...
# Processing event 578/9536...
# Processing event 579/9536...
# Processing event 580/9536...
# Processing event 581/9536...
# Processing event 582/9536...
# Processing event 583/9536...
# Processing event 584/9536...
# Processing event 585/9536...
# Processing event 586/9536...
# Processing event 587/9536...
# Processing event 588/9536...
# Processing event 589/9536...
# Processing event 590/9536...
# Processing event 591/9536...
# Processing event 592/9536...
# Processing event 593/9536...
# Processing event 594/9536...
# Processing event 595/9536...
# Processing event 596/9536...
# Processing event 597/9536...
# Processing event 598/9536...
# Processing event 599/9536...
# Processing event 600/9536...
# Processing event 601/9536...
# Processing event 602/9536...
# Processing event 603/9536...
# Processing event 604/9536...
# Processing event 605/9536...
# Processing event 606/9536...
# Processing event 607/9536...
# Processing event 608/9536...
# Processing event 609/9536...
# Processing event 610/9536...
# Processing event 611/9536...
# Processing event 612/9536...
# Processing event 613/9536...
# Processing event 614/9536...
# Processing event 615/9536...
# Processing event 616/9536...
# Processing event 617/9536...
# Processing event 618/9536...
# Processing event 619/9536...
# Processing event 620/9536...
# Processing event 621/9536...
# Processing event 622/9536...
# Processing event 623/9536...
# Processing event 624/9536...
# Processing event 625/9536...
# Processing event 626/9536...
# Processing event 627/9536...
# Processing event 628/9536...
# Processing event 629/9536...
# Processing event 630/9536...
# Processing event 631/9536...
# Processing event 632/9536...
# Processing event 633/9536...
# Processing event 634/9536...
# Processing event 635/9536...
# Processing event 636/9536...
# Processing event 637/9536...
# Processing event 638/9536...
# Processing event 639/9536...
# Processing event 640/9536...
# Processing event 641/9536...
# Processing event 642/9536...
# Processing event 643/9536...
# Processing event 644/9536...
# Processing event 645/9536...
# Processing event 646/9536...
# Processing event 647/9536...
# Processing event 648/9536...
# Processing event 649/9536...
# Processing event 650/9536...
# Processing event 651/9536...
# Processing event 652/9536...
# Processing event 653/9536...
# Processing event 654/9536...
# Processing event 655/9536...
# Processing event 656/9536...
# Processing event 657/9536...
# Processing event 658/9536...
# Processing event 659/9536...
# Processing event 660/9536...
# Processing event 661/9536...
# Processing event 662/9536...
# Processing event 663/9536...
# Processing event 664/9536...
# Processing event 665/9536...
# Processing event 666/9536...
# Processing event 667/9536...
# Processing event 668/9536...
# Processing event 669/9536...
# Processing event 670/9536...
# Processing event 671/9536...
# Processing event 672/9536...
# Processing event 673/9536...
# Processing event 674/9536...
# Processing event 675/9536...
# Processing event 676/9536...
# Processing event 677/9536...
# Processing event 678/9536...
# Processing event 679/9536...
# Processing event 680/9536...
# Processing event 681/9536...
# Processing event 682/9536...
# Processing event 683/9536...
# Processing event 684/9536...
# Processing event 685/9536...
# Processing event 686/9536...
# Processing event 687/9536...
# Processing event 688/9536...
# Processing event 689/9536...
# Processing event 690/9536...
# Processing event 691/9536...
# Processing event 692/9536...
# Processing event 693/9536...
# Processing event 694/9536...
# Processing event 695/9536...
# Processing event 696/9536...
# Processing event 697/9536...
# Processing event 698/9536...
# Processing event 699/9536...
# Processing event 700/9536...
# Processing event 701/9536...
# Processing event 702/9536...
# Processing event 703/9536...
# Processing event 704/9536...
# Processing event 705/9536...
# Processing event 706/9536...
# Processing event 707/9536...
# Processing event 708/9536...
# Processing event 709/9536...
# Processing event 710/9536...
# Processing event 711/9536...
# Processing event 712/9536...
# Processing event 713/9536...
# Processing event 714/9536...
# Processing event 715/9536...
# Processing event 716/9536...
# Processing event 717/9536...
# Processing event 718/9536...
# Processing event 719/9536...
# Processing event 720/9536...
# Processing event 721/9536...
# Processing event 722/9536...
# Processing event 723/9536...
# Processing event 724/9536...
# Processing event 725/9536...
# Processing event 726/9536...
# Processing event 727/9536...
# Processing event 728/9536...
# Processing event 729/9536...
# Processing event 730/9536...
# Processing event 731/9536...
# Processing event 732/9536...
# Processing event 733/9536...
# Processing event 734/9536...
# Processing event 735/9536...
# Processing event 736/9536...
# Processing event 737/9536...
# Processing event 738/9536...
# Processing event 739/9536...
# Processing event 740/9536...
# Processing event 741/9536...
# Processing event 742/9536...
# Processing event 743/9536...
# Processing event 744/9536...
# Processing event 745/9536...
# Processing event 746/9536...
# Processing event 747/9536...
# Processing event 748/9536...
# Processing event 749/9536...
# Processing event 750/9536...
# Processing event 751/9536...
# Processing event 752/9536...
# Processing event 753/9536...
# Processing event 754/9536...
# Processing event 755/9536...
# Processing event 756/9536...
# Processing event 757/9536...
# Processing event 758/9536...
# Processing event 759/9536...
# Processing event 760/9536...
# Processing event 761/9536...
# Processing event 762/9536...
# Processing event 763/9536...
# Processing event 764/9536...
# Processing event 765/9536...
# Processing event 766/9536...
# Processing event 767/9536...
# Processing event 768/9536...
# Processing event 769/9536...
# Processing event 770/9536...
# Processing event 771/9536...
# Processing event 772/9536...
# Processing event 773/9536...
# Processing event 774/9536...
# Processing event 775/9536...
# Processing event 776/9536...
# Processing event 777/9536...
# Processing event 778/9536...
# Processing event 779/9536...
# Processing event 780/9536...
# Processing event 781/9536...
# Processing event 782/9536...
# Processing event 783/9536...
# Processing event 784/9536...
# Processing event 785/9536...
# Processing event 786/9536...
# Processing event 787/9536...
# Processing event 788/9536...
# Processing event 789/9536...
# Processing event 790/9536...
# Processing event 791/9536...
# Processing event 792/9536...
# Processing event 793/9536...
# Processing event 794/9536...
# Processing event 795/9536...
# Processing event 796/9536...
# Processing event 797/9536...
# Processing event 798/9536...
# Processing event 799/9536...
# Processing event 800/9536...
# Processing event 801/9536...
# Processing event 802/9536...
# Processing event 803/9536...
# Processing event 804/9536...
# Processing event 805/9536...
# Processing event 806/9536...
# Processing event 807/9536...
# Processing event 808/9536...
# Processing event 809/9536...
# Processing event 810/9536...
# Processing event 811/9536...
# Processing event 812/9536...
# Processing event 813/9536...
# Processing event 814/9536...
# Processing event 815/9536...
# Processing event 816/9536...
# Processing event 817/9536...
# Processing event 818/9536...
# Processing event 819/9536...
# Processing event 820/9536...
# Processing event 821/9536...
# Processing event 822/9536...
# Processing event 823/9536...
# Processing event 824/9536...
# Processing event 825/9536...
# Processing event 826/9536...
# Processing event 827/9536...
# Processing event 828/9536...
# Processing event 829/9536...
# Processing event 830/9536...
# Processing event 831/9536...
# Processing event 832/9536...
# Processing event 833/9536...
# Processing event 834/9536...
# Processing event 835/9536...
# Processing event 836/9536...
# Processing event 837/9536...
# Processing event 838/9536...
# Processing event 839/9536...
# Processing event 840/9536...
# Processing event 841/9536...
# Processing event 842/9536...
# Processing event 843/9536...
# Processing event 844/9536...
# Processing event 845/9536...
# Processing event 846/9536...
# Processing event 847/9536...
# Processing event 848/9536...
# Processing event 849/9536...
# Processing event 850/9536...
# Processing event 851/9536...
# Processing event 852/9536...
# Processing event 853/9536...
# Processing event 854/9536...
# Processing event 855/9536...
# Processing event 856/9536...
# Processing event 857/9536...
# Processing event 858/9536...
# Processing event 859/9536...
# Processing event 860/9536...
# Processing event 861/9536...
# Processing event 862/9536...
# Processing event 863/9536...
# Processing event 864/9536...
# Processing event 865/9536...
# Processing event 866/9536...
# Processing event 867/9536...
# Processing event 868/9536...
# Processing event 869/9536...
# Processing event 870/9536...
# Processing event 871/9536...
# Processing event 872/9536...
# Processing event 873/9536...
# Processing event 874/9536...
# Processing event 875/9536...
# Processing event 876/9536...
# Processing event 877/9536...
# Processing event 878/9536...
# Processing event 879/9536...
# Processing event 880/9536...
# Processing event 881/9536...
# Processing event 882/9536...
# Processing event 883/9536...
# Processing event 884/9536...
# Processing event 885/9536...
# Processing event 886/9536...
# Processing event 887/9536...
# Processing event 888/9536...
# Processing event 889/9536...
# Processing event 890/9536...
# Processing event 891/9536...
# Processing event 892/9536...
# Processing event 893/9536...
# Processing event 894/9536...
# Processing event 895/9536...
# Processing event 896/9536...
# Processing event 897/9536...
# Processing event 898/9536...
# Processing event 899/9536...
# Processing event 900/9536...
# Processing event 901/9536...
# Processing event 902/9536...
# Processing event 903/9536...
# Processing event 904/9536...
# Processing event 905/9536...
# Processing event 906/9536...
# Processing event 907/9536...
# Processing event 908/9536...
# Processing event 909/9536...
# Processing event 910/9536...
# Processing event 911/9536...
# Processing event 912/9536...
# Processing event 913/9536...
# Processing event 914/9536...
# Processing event 915/9536...
# Processing event 916/9536...
# Processing event 917/9536...
# Processing event 918/9536...
# Processing event 919/9536...
# Processing event 920/9536...
# Processing event 921/9536...
# Processing event 922/9536...
# Processing event 923/9536...
# Processing event 924/9536...
# Processing event 925/9536...
# Processing event 926/9536...
# Processing event 927/9536...
# Processing event 928/9536...
# Processing event 929/9536...
# Processing event 930/9536...
# Processing event 931/9536...
# Processing event 932/9536...
# Processing event 933/9536...
# Processing event 934/9536...
# Processing event 935/9536...
# Processing event 936/9536...
# Processing event 937/9536...
# Processing event 938/9536...
# Processing event 939/9536...
# Processing event 940/9536...
# Processing event 941/9536...
# Processing event 942/9536...
# Processing event 943/9536...
# Processing event 944/9536...
# Processing event 945/9536...
# Processing event 946/9536...
# Processing event 947/9536...
# Processing event 948/9536...
# Processing event 949/9536...
# Processing event 950/9536...
# Processing event 951/9536...
# Processing event 952/9536...
# Processing event 953/9536...
# Processing event 954/9536...
# Processing event 955/9536...
# Processing event 956/9536...
# Processing event 957/9536...
# Processing event 958/9536...
# Processing event 959/9536...
# Processing event 960/9536...
# Processing event 961/9536...
# Processing event 962/9536...
# Processing event 963/9536...
# Processing event 964/9536...
# Processing event 965/9536...
# Processing event 966/9536...
# Processing event 967/9536...
# Processing event 968/9536...
# Processing event 969/9536...
# Processing event 970/9536...
# Processing event 971/9536...
# Processing event 972/9536...
# Processing event 973/9536...
# Processing event 974/9536...
# Processing event 975/9536...
# Processing event 976/9536...
# Processing event 977/9536...
# Processing event 978/9536...
# Processing event 979/9536...
# Processing event 980/9536...
# Processing event 981/9536...
# Processing event 982/9536...
# Processing event 983/9536...
# Processing event 984/9536...
# Processing event 985/9536...
# Processing event 986/9536...
# Processing event 987/9536...
# Processing event 988/9536...
# Processing event 989/9536...
# Processing event 990/9536...
# Processing event 991/9536...
# Processing event 992/9536...
# Processing event 993/9536...
# Processing event 994/9536...
# Processing event 995/9536...
# Processing event 996/9536...
# Processing event 997/9536...
# Processing event 998/9536...
# Processing event 999/9536...
# Processing event 1000/9536...
# Processing event 1001/9536...
# Processing event 1002/9536...
# Processing event 1003/9536...
# Processing event 1004/9536...
# Processing event 1005/9536...
# Processing event 1006/9536...
# Processing event 1007/9536...
# Processing event 1008/9536...
# Processing event 1009/9536...
# Processing event 1010/9536...
# Processing event 1011/9536...
# Processing event 1012/9536...
# Processing event 1013/9536...
# Processing event 1014/9536...
# Processing event 1015/9536...
# Processing event 1016/9536...
# Processing event 1017/9536...
# Processing event 1018/9536...
# Processing event 1019/9536...
# Processing event 1020/9536...
# Processing event 1021/9536...
# Processing event 1022/9536...
# Processing event 1023/9536...
# Processing event 1024/9536...
# Processing event 1025/9536...
# Processing event 1026/9536...
# Processing event 1027/9536...
# Processing event 1028/9536...
# Processing event 1029/9536...
# Processing event 1030/9536...
# Processing event 1031/9536...
# Processing event 1032/9536...
# Processing event 1033/9536...
# Processing event 1034/9536...
# Processing event 1035/9536...
# Processing event 1036/9536...
# Processing event 1037/9536...
# Processing event 1038/9536...
# Processing event 1039/9536...
# Processing event 1040/9536...
# Processing event 1041/9536...
# Processing event 1042/9536...
# Processing event 1043/9536...
# Processing event 1044/9536...
# Processing event 1045/9536...
# Processing event 1046/9536...
# Processing event 1047/9536...
# Processing event 1048/9536...
# Processing event 1049/9536...
# Processing event 1050/9536...
# Processing event 1051/9536...
# Processing event 1052/9536...
# Processing event 1053/9536...
# Processing event 1054/9536...
# Processing event 1055/9536...
# Processing event 1056/9536...
# Processing event 1057/9536...
# Processing event 1058/9536...
# Processing event 1059/9536...
# Processing event 1060/9536...
# Processing event 1061/9536...
# Processing event 1062/9536...
# Processing event 1063/9536...
# Processing event 1064/9536...
# Processing event 1065/9536...
# Processing event 1066/9536...
# Processing event 1067/9536...
# Processing event 1068/9536...
# Processing event 1069/9536...
# Processing event 1070/9536...
# Processing event 1071/9536...
# Processing event 1072/9536...
# Processing event 1073/9536...
# Processing event 1074/9536...
# Processing event 1075/9536...
# Processing event 1076/9536...
# Processing event 1077/9536...
# Processing event 1078/9536...
# Processing event 1079/9536...
# Processing event 1080/9536...
# Processing event 1081/9536...
# Processing event 1082/9536...
# Processing event 1083/9536...
# Processing event 1084/9536...
# Processing event 1085/9536...
# Processing event 1086/9536...
# Processing event 1087/9536...
# Processing event 1088/9536...
# Processing event 1089/9536...
# Processing event 1090/9536...
# Processing event 1091/9536...
# Processing event 1092/9536...
# Processing event 1093/9536...
# Processing event 1094/9536...
# Processing event 1095/9536...
# Processing event 1096/9536...
# Processing event 1097/9536...
# Processing event 1098/9536...
# Processing event 1099/9536...
# Processing event 1100/9536...
# Processing event 1101/9536...
# Processing event 1102/9536...
# Processing event 1103/9536...
# Processing event 1104/9536...
# Processing event 1105/9536...
# Processing event 1106/9536...
# Processing event 1107/9536...
# Processing event 1108/9536...
# Processing event 1109/9536...
# Processing event 1110/9536...
# Processing event 1111/9536...
# Processing event 1112/9536...
# Processing event 1113/9536...
# Processing event 1114/9536...
# Processing event 1115/9536...
# Processing event 1116/9536...
# Processing event 1117/9536...
# Processing event 1118/9536...
# Processing event 1119/9536...
# Processing event 1120/9536...
# Processing event 1121/9536...
# Processing event 1122/9536...
# Processing event 1123/9536...
# Processing event 1124/9536...
# Processing event 1125/9536...
# Processing event 1126/9536...
# Processing event 1127/9536...
# Processing event 1128/9536...
# Processing event 1129/9536...
# Processing event 1130/9536...
# Processing event 1131/9536...
# Processing event 1132/9536...
# Processing event 1133/9536...
# Processing event 1134/9536...
# Processing event 1135/9536...
# Processing event 1136/9536...
# Processing event 1137/9536...
# Processing event 1138/9536...
# Processing event 1139/9536...
# Processing event 1140/9536...
# Processing event 1141/9536...
# Processing event 1142/9536...
# Processing event 1143/9536...
# Processing event 1144/9536...
# Processing event 1145/9536...
# Processing event 1146/9536...
# Processing event 1147/9536...
# Processing event 1148/9536...
# Processing event 1149/9536...
# Processing event 1150/9536...
# Processing event 1151/9536...
# Processing event 1152/9536...
# Processing event 1153/9536...
# Processing event 1154/9536...
# Processing event 1155/9536...
# Processing event 1156/9536...
# Processing event 1157/9536...
# Processing event 1158/9536...
# Processing event 1159/9536...
# Processing event 1160/9536...
# Processing event 1161/9536...
# Processing event 1162/9536...
# Processing event 1163/9536...
# Processing event 1164/9536...
# Processing event 1165/9536...
# Processing event 1166/9536...
# Processing event 1167/9536...
# Processing event 1168/9536...
# Processing event 1169/9536...
# Processing event 1170/9536...
# Processing event 1171/9536...
# Processing event 1172/9536...
# Processing event 1173/9536...
# Processing event 1174/9536...
# Processing event 1175/9536...
# Processing event 1176/9536...
# Processing event 1177/9536...
# Processing event 1178/9536...
# Processing event 1179/9536...
# Processing event 1180/9536...
# Processing event 1181/9536...
# Processing event 1182/9536...
# Processing event 1183/9536...
# Processing event 1184/9536...
# Processing event 1185/9536...
# Processing event 1186/9536...
# Processing event 1187/9536...
# Processing event 1188/9536...
# Processing event 1189/9536...
# Processing event 1190/9536...
# Processing event 1191/9536...
# Processing event 1192/9536...
# Processing event 1193/9536...
# Processing event 1194/9536...
# Processing event 1195/9536...
# Processing event 1196/9536...
# Processing event 1197/9536...
# Processing event 1198/9536...
# Processing event 1199/9536...
# Processing event 1200/9536...
# Processing event 1201/9536...
# Processing event 1202/9536...
# Processing event 1203/9536...
# Processing event 1204/9536...
# Processing event 1205/9536...
# Processing event 1206/9536...
# Processing event 1207/9536...
# Processing event 1208/9536...
# Processing event 1209/9536...
# Processing event 1210/9536...
# Processing event 1211/9536...
# Processing event 1212/9536...
# Processing event 1213/9536...
# Processing event 1214/9536...
# Processing event 1215/9536...
# Processing event 1216/9536...
# Processing event 1217/9536...
# Processing event 1218/9536...
# Processing event 1219/9536...
# Processing event 1220/9536...
# Processing event 1221/9536...
# Processing event 1222/9536...
# Processing event 1223/9536...
# Processing event 1224/9536...
# Processing event 1225/9536...
# Processing event 1226/9536...
# Processing event 1227/9536...
# Processing event 1228/9536...
# Processing event 1229/9536...
# Processing event 1230/9536...
# Processing event 1231/9536...
# Processing event 1232/9536...
# Processing event 1233/9536...
# Processing event 1234/9536...
# Processing event 1235/9536...
# Processing event 1236/9536...
# Processing event 1237/9536...
# Processing event 1238/9536...
# Processing event 1239/9536...
# Processing event 1240/9536...
# Processing event 1241/9536...
# Processing event 1242/9536...
# Processing event 1243/9536...
# Processing event 1244/9536...
# Processing event 1245/9536...
# Processing event 1246/9536...
# Processing event 1247/9536...
# Processing event 1248/9536...
# Processing event 1249/9536...
# Processing event 1250/9536...
# Processing event 1251/9536...
# Processing event 1252/9536...
# Processing event 1253/9536...
# Processing event 1254/9536...
# Processing event 1255/9536...
# Processing event 1256/9536...
# Processing event 1257/9536...
# Processing event 1258/9536...
# Processing event 1259/9536...
# Processing event 1260/9536...
# Processing event 1261/9536...
# Processing event 1262/9536...
# Processing event 1263/9536...
# Processing event 1264/9536...
# Processing event 1265/9536...
# Processing event 1266/9536...
# Processing event 1267/9536...
# Processing event 1268/9536...
# Processing event 1269/9536...
# Processing event 1270/9536...
# Processing event 1271/9536...
# Processing event 1272/9536...
# Processing event 1273/9536...
# Processing event 1274/9536...
# Processing event 1275/9536...
# Processing event 1276/9536...
# Processing event 1277/9536...
# Processing event 1278/9536...
# Processing event 1279/9536...
# Processing event 1280/9536...
# Processing event 1281/9536...
# Processing event 1282/9536...
# Processing event 1283/9536...
# Processing event 1284/9536...
# Processing event 1285/9536...
# Processing event 1286/9536...
# Processing event 1287/9536...
# Processing event 1288/9536...
# Processing event 1289/9536...
# Processing event 1290/9536...
# Processing event 1291/9536...
# Processing event 1292/9536...
# Processing event 1293/9536...
# Processing event 1294/9536...
# Processing event 1295/9536...
# Processing event 1296/9536...
# Processing event 1297/9536...
# Processing event 1298/9536...
# Processing event 1299/9536...
# Processing event 1300/9536...
# Processing event 1301/9536...
# Processing event 1302/9536...
# Processing event 1303/9536...
# Processing event 1304/9536...
# Processing event 1305/9536...
# Processing event 1306/9536...
# Processing event 1307/9536...
# Processing event 1308/9536...
# Processing event 1309/9536...
# Processing event 1310/9536...
# Processing event 1311/9536...
# Processing event 1312/9536...
# Processing event 1313/9536...
# Processing event 1314/9536...
# Processing event 1315/9536...
# Processing event 1316/9536...
# Processing event 1317/9536...
# Processing event 1318/9536...
# Processing event 1319/9536...
# Processing event 1320/9536...
# Processing event 1321/9536...
# Processing event 1322/9536...
# Processing event 1323/9536...
# Processing event 1324/9536...
# Processing event 1325/9536...
# Processing event 1326/9536...
# Processing event 1327/9536...
# Processing event 1328/9536...
# Processing event 1329/9536...
# Processing event 1330/9536...
# Processing event 1331/9536...
# Processing event 1332/9536...
# Processing event 1333/9536...
# Processing event 1334/9536...
# Processing event 1335/9536...
# Processing event 1336/9536...
# Processing event 1337/9536...
# Processing event 1338/9536...
# Processing event 1339/9536...
# Processing event 1340/9536...
# Processing event 1341/9536...
# Processing event 1342/9536...
# Processing event 1343/9536...
# Processing event 1344/9536...
# Processing event 1345/9536...
# Processing event 1346/9536...
# Processing event 1347/9536...
# Processing event 1348/9536...
# Processing event 1349/9536...
# Processing event 1350/9536...
# Processing event 1351/9536...
# Processing event 1352/9536...
# Processing event 1353/9536...
# Processing event 1354/9536...
# Processing event 1355/9536...
# Processing event 1356/9536...
# Processing event 1357/9536...
# Processing event 1358/9536...
# Processing event 1359/9536...
# Processing event 1360/9536...
# Processing event 1361/9536...
# Processing event 1362/9536...
# Processing event 1363/9536...
# Processing event 1364/9536...
# Processing event 1365/9536...
# Processing event 1366/9536...
# Processing event 1367/9536...
# Processing event 1368/9536...
# Processing event 1369/9536...
# Processing event 1370/9536...
# Processing event 1371/9536...
# Processing event 1372/9536...
# Processing event 1373/9536...
# Processing event 1374/9536...
# Processing event 1375/9536...
# Processing event 1376/9536...
# Processing event 1377/9536...
# Processing event 1378/9536...
# Processing event 1379/9536...
# Processing event 1380/9536...
# Processing event 1381/9536...
# Processing event 1382/9536...
# Processing event 1383/9536...
# Processing event 1384/9536...
# Processing event 1385/9536...
# Processing event 1386/9536...
# Processing event 1387/9536...
# Processing event 1388/9536...
# Processing event 1389/9536...
# Processing event 1390/9536...
# Processing event 1391/9536...
# Processing event 1392/9536...
# Processing event 1393/9536...
# Processing event 1394/9536...
# Processing event 1395/9536...
# Processing event 1396/9536...
# Processing event 1397/9536...
# Processing event 1398/9536...
# Processing event 1399/9536...
# Processing event 1400/9536...
# Processing event 1401/9536...
# Processing event 1402/9536...
# Processing event 1403/9536...
# Processing event 1404/9536...
# Processing event 1405/9536...
# Processing event 1406/9536...
# Processing event 1407/9536...
# Processing event 1408/9536...
# Processing event 1409/9536...
# Processing event 1410/9536...
# Processing event 1411/9536...
# Processing event 1412/9536...
# Processing event 1413/9536...
# Processing event 1414/9536...
# Processing event 1415/9536...
# Processing event 1416/9536...
# Processing event 1417/9536...
# Processing event 1418/9536...
# Processing event 1419/9536...
# Processing event 1420/9536...
# Processing event 1421/9536...
# Processing event 1422/9536...
# Processing event 1423/9536...
# Processing event 1424/9536...
# Processing event 1425/9536...
# Processing event 1426/9536...
# Processing event 1427/9536...
# Processing event 1428/9536...
# Processing event 1429/9536...
# Processing event 1430/9536...
# Processing event 1431/9536...
# Processing event 1432/9536...
# Processing event 1433/9536...
# Processing event 1434/9536...
# Processing event 1435/9536...
# Processing event 1436/9536...
# Processing event 1437/9536...
# Processing event 1438/9536...
# Processing event 1439/9536...
# Processing event 1440/9536...
# Processing event 1441/9536...
# Processing event 1442/9536...
# Processing event 1443/9536...
# Processing event 1444/9536...
# Processing event 1445/9536...
# Processing event 1446/9536...
# Processing event 1447/9536...
# Processing event 1448/9536...
# Processing event 1449/9536...
# Processing event 1450/9536...
# Processing event 1451/9536...
# Processing event 1452/9536...
# Processing event 1453/9536...
# Processing event 1454/9536...
# Processing event 1455/9536...
# Processing event 1456/9536...
# Processing event 1457/9536...
# Processing event 1458/9536...
# Processing event 1459/9536...
# Processing event 1460/9536...
# Processing event 1461/9536...
# Processing event 1462/9536...
# Processing event 1463/9536...
# Processing event 1464/9536...
# Processing event 1465/9536...
# Processing event 1466/9536...
# Processing event 1467/9536...
# Processing event 1468/9536...
# Processing event 1469/9536...
# Processing event 1470/9536...
# Processing event 1471/9536...
# Processing event 1472/9536...
# Processing event 1473/9536...
# Processing event 1474/9536...
# Processing event 1475/9536...
# Processing event 1476/9536...
# Processing event 1477/9536...
# Processing event 1478/9536...
# Processing event 1479/9536...
# Processing event 1480/9536...
# Processing event 1481/9536...
# Processing event 1482/9536...
# Processing event 1483/9536...
# Processing event 1484/9536...
# Processing event 1485/9536...
# Processing event 1486/9536...
# Processing event 1487/9536...
# Processing event 1488/9536...
# Processing event 1489/9536...
# Processing event 1490/9536...
# Processing event 1491/9536...
# Processing event 1492/9536...
# Processing event 1493/9536...
# Processing event 1494/9536...
# Processing event 1495/9536...
# Processing event 1496/9536...
# Processing event 1497/9536...
# Processing event 1498/9536...
# Processing event 1499/9536...
# Processing event 1500/9536...
# Processing event 1501/9536...
# Processing event 1502/9536...
# Processing event 1503/9536...
# Processing event 1504/9536...
# Processing event 1505/9536...
# Processing event 1506/9536...
# Processing event 1507/9536...
# Processing event 1508/9536...
# Processing event 1509/9536...
# Processing event 1510/9536...
# Processing event 1511/9536...
# Processing event 1512/9536...
# Processing event 1513/9536...
# Processing event 1514/9536...
# Processing event 1515/9536...
# Processing event 1516/9536...
# Processing event 1517/9536...
# Processing event 1518/9536...
# Processing event 1519/9536...
# Processing event 1520/9536...
# Processing event 1521/9536...
# Processing event 1522/9536...
# Processing event 1523/9536...
# Processing event 1524/9536...
# Processing event 1525/9536...
# Processing event 1526/9536...
# Processing event 1527/9536...
# Processing event 1528/9536...
# Processing event 1529/9536...
# Processing event 1530/9536...
# Processing event 1531/9536...
# Processing event 1532/9536...
# Processing event 1533/9536...
# Processing event 1534/9536...
# Processing event 1535/9536...
# Processing event 1536/9536...
# Processing event 1537/9536...
# Processing event 1538/9536...
# Processing event 1539/9536...
# Processing event 1540/9536...
# Processing event 1541/9536...
# Processing event 1542/9536...
# Processing event 1543/9536...
# Processing event 1544/9536...
# Processing event 1545/9536...
# Processing event 1546/9536...
# Processing event 1547/9536...
# Processing event 1548/9536...
# Processing event 1549/9536...
# Processing event 1550/9536...
# Processing event 1551/9536...
# Processing event 1552/9536...
# Processing event 1553/9536...
# Processing event 1554/9536...
# Processing event 1555/9536...
# Processing event 1556/9536...
# Processing event 1557/9536...
# Processing event 1558/9536...
# Processing event 1559/9536...
# Processing event 1560/9536...
# Processing event 1561/9536...
# Processing event 1562/9536...
# Processing event 1563/9536...
# Processing event 1564/9536...
# Processing event 1565/9536...
# Processing event 1566/9536...
# Processing event 1567/9536...
# Processing event 1568/9536...
# Processing event 1569/9536...
# Processing event 1570/9536...
# Processing event 1571/9536...
# Processing event 1572/9536...
# Processing event 1573/9536...
# Processing event 1574/9536...
# Processing event 1575/9536...
# Processing event 1576/9536...
# Processing event 1577/9536...
# Processing event 1578/9536...
# Processing event 1579/9536...
# Processing event 1580/9536...
# Processing event 1581/9536...
# Processing event 1582/9536...
# Processing event 1583/9536...
# Processing event 1584/9536...
# Processing event 1585/9536...
# Processing event 1586/9536...
# Processing event 1587/9536...
# Processing event 1588/9536...
# Processing event 1589/9536...
# Processing event 1590/9536...
# Processing event 1591/9536...
# Processing event 1592/9536...
# Processing event 1593/9536...
# Processing event 1594/9536...
# Processing event 1595/9536...
# Processing event 1596/9536...
# Processing event 1597/9536...
# Processing event 1598/9536...
# Processing event 1599/9536...
# Processing event 1600/9536...
# Processing event 1601/9536...
# Processing event 1602/9536...
# Processing event 1603/9536...
# Processing event 1604/9536...
# Processing event 1605/9536...
# Processing event 1606/9536...
# Processing event 1607/9536...
# Processing event 1608/9536...
# Processing event 1609/9536...
# Processing event 1610/9536...
# Processing event 1611/9536...
# Processing event 1612/9536...
# Processing event 1613/9536...
# Processing event 1614/9536...
# Processing event 1615/9536...
# Processing event 1616/9536...
# Processing event 1617/9536...
# Processing event 1618/9536...
# Processing event 1619/9536...
# Processing event 1620/9536...
# Processing event 1621/9536...
# Processing event 1622/9536...
# Processing event 1623/9536...
# Processing event 1624/9536...
# Processing event 1625/9536...
# Processing event 1626/9536...
# Processing event 1627/9536...
# Processing event 1628/9536...
# Processing event 1629/9536...
# Processing event 1630/9536...
# Processing event 1631/9536...
# Processing event 1632/9536...
# Processing event 1633/9536...
# Processing event 1634/9536...
# Processing event 1635/9536...
# Processing event 1636/9536...
# ...
# Processing event 9016/9536...
# Processing event 9017/9536...
# Processing event 9018/9536...
# Processing event 9019/9536...
# Processing event 9020/9536...
# Processing event 9021/9536...
# Processing event 9022/9536...
# Processing event 9023/9536...
# Processing event 9024/9536...
# Processing event 9025/9536...
# Processing event 9026/9536...
# Processing event 9027/9536...
# Processing event 9028/9536...
# Processing event 9029/9536...
# Processing event 9030/9536...
# Processing event 9031/9536...
# Processing event 9032/9536...
# Processing event 9033/9536...
# Processing event 9034/9536...
# Processing event 9035/9536...
# Processing event 9036/9536...
# Processing event 9037/9536...
# Processing event 9038/9536...
# Processing event 9039/9536...
# Processing event 9040/9536...
# Processing event 9041/9536...
# Processing event 9042/9536...
# Processing event 9043/9536...
# Processing event 9044/9536...
# Processing event 9045/9536...
# Processing event 9046/9536...
# Processing event 9047/9536...
# Processing event 9048/9536...
# Processing event 9049/9536...
# Processing event 9050/9536...
# Processing event 9051/9536...
# Processing event 9052/9536...
# Processing event 9053/9536...
# Processing event 9054/9536...
# Processing event 9055/9536...
# Processing event 9056/9536...
# Processing event 9057/9536...
# Processing event 9058/9536...
# Processing event 9059/9536...
# Processing event 9060/9536...
# Processing event 9061/9536...
# Processing event 9062/9536...
# Processing event 9063/9536...
# Processing event 9064/9536...
# Processing event 9065/9536...
# Processing event 9066/9536...
# Processing event 9067/9536...
# Processing event 9068/9536...
# Processing event 9069/9536...
# Processing event 9070/9536...
# Processing event 9071/9536...
# Processing event 9072/9536...
# Processing event 9073/9536...
# Processing event 9074/9536...
# Processing event 9075/9536...
# Processing event 9076/9536...
# Processing event 9077/9536...
# Processing event 9078/9536...
# Processing event 9079/9536...
# Processing event 9080/9536...
# Processing event 9081/9536...
# Processing event 9082/9536...
# Processing event 9083/9536...
# Processing event 9084/9536...
# Processing event 9085/9536...
# Processing event 9086/9536...
# Processing event 9087/9536...
# Processing event 9088/9536...
# Processing event 9089/9536...
# Processing event 9090/9536...
# Processing event 9091/9536...
# Processing event 9092/9536...
# Processing event 9093/9536...
# Processing event 9094/9536...
# Processing event 9095/9536...
# Processing event 9096/9536...
# Processing event 9097/9536...
# Processing event 9098/9536...
# Processing event 9099/9536...
# Processing event 9100/9536...
# Processing event 9101/9536...
# Processing event 9102/9536...
# Processing event 9103/9536...
# Processing event 9104/9536...
# Processing event 9105/9536...
# Processing event 9106/9536...
# Processing event 9107/9536...
# Processing event 9108/9536...
# Processing event 9109/9536...
# Processing event 9110/9536...
# Processing event 9111/9536...
# Processing event 9112/9536...
# Processing event 9113/9536...
# Processing event 9114/9536...
# Processing event 9115/9536...
# Processing event 9116/9536...
# Processing event 9117/9536...
# Processing event 9118/9536...
# Processing event 9119/9536...
# Processing event 9120/9536...
# Processing event 9121/9536...
# Processing event 9122/9536...
# Processing event 9123/9536...
# Processing event 9124/9536...
# Processing event 9125/9536...
# Processing event 9126/9536...
# Processing event 9127/9536...
# Processing event 9128/9536...
# Processing event 9129/9536...
# Processing event 9130/9536...
# Processing event 9131/9536...
# Processing event 9132/9536...
# Processing event 9133/9536...
# Processing event 9134/9536...
# Processing event 9135/9536...
# Processing event 9136/9536...
# Processing event 9137/9536...
# Processing event 9138/9536...
# Processing event 9139/9536...
# Processing event 9140/9536...
# Processing event 9141/9536...
# Processing event 9142/9536...
# Processing event 9143/9536...
# Processing event 9144/9536...
# Processing event 9145/9536...
# Processing event 9146/9536...
# Processing event 9147/9536...
# Processing event 9148/9536...
# Processing event 9149/9536...
# Processing event 9150/9536...
# Processing event 9151/9536...
# Processing event 9152/9536...
# Processing event 9153/9536...
# Processing event 9154/9536...
# Processing event 9155/9536...
# Processing event 9156/9536...
# Processing event 9157/9536...
# Processing event 9158/9536...
# Processing event 9159/9536...
# Processing event 9160/9536...
# Processing event 9161/9536...
# Processing event 9162/9536...
# Processing event 9163/9536...
# Processing event 9164/9536...
# Processing event 9165/9536...
# Processing event 9166/9536...
# Processing event 9167/9536...
# Processing event 9168/9536...
# Processing event 9169/9536...
# Processing event 9170/9536...
# Processing event 9171/9536...
# Processing event 9172/9536...
# Processing event 9173/9536...
# Processing event 9174/9536...
# Processing event 9175/9536...
# Processing event 9176/9536...
# Processing event 9177/9536...
# Processing event 9178/9536...
# Processing event 9179/9536...
# Processing event 9180/9536...
# Processing event 9181/9536...
# Processing event 9182/9536...
# Processing event 9183/9536...
# Processing event 9184/9536...
# Processing event 9185/9536...
# Processing event 9186/9536...
# Processing event 9187/9536...
# Processing event 9188/9536...
# Processing event 9189/9536...
# Processing event 9190/9536...
# Processing event 9191/9536...
# Processing event 9192/9536...
# Processing event 9193/9536...
# Processing event 9194/9536...
# Processing event 9195/9536...
# Processing event 9196/9536...
# Processing event 9197/9536...
# Processing event 9198/9536...
# Processing event 9199/9536...
# Processing event 9200/9536...
# Processing event 9201/9536...
# Processing event 9202/9536...
# Processing event 9203/9536...
# Processing event 9204/9536...
# Processing event 9205/9536...
# Processing event 9206/9536...
# Processing event 9207/9536...
# Processing event 9208/9536...
# Processing event 9209/9536...
# Processing event 9210/9536...
# Processing event 9211/9536...
# Processing event 9212/9536...
# Processing event 9213/9536...
# Processing event 9214/9536...
# Processing event 9215/9536...
# Processing event 9216/9536...
# Processing event 9217/9536...
# Processing event 9218/9536...
# Processing event 9219/9536...
# Processing event 9220/9536...
# Processing event 9221/9536...
# Processing event 9222/9536...
# Processing event 9223/9536...
# Processing event 9224/9536...
# Processing event 9225/9536...
# Processing event 9226/9536...
# Processing event 9227/9536...
# Processing event 9228/9536...
# Processing event 9229/9536...
# Processing event 9230/9536...
# Processing event 9231/9536...
# Processing event 9232/9536...
# Processing event 9233/9536...
# Processing event 9234/9536...
# Processing event 9235/9536...
# Processing event 9236/9536...
# Processing event 9237/9536...
# Processing event 9238/9536...
# Processing event 9239/9536...
# Processing event 9240/9536...
# Processing event 9241/9536...
# Processing event 9242/9536...
# Processing event 9243/9536...
# Processing event 9244/9536...
# Processing event 9245/9536...
# Processing event 9246/9536...
# Processing event 9247/9536...
# Processing event 9248/9536...
# Processing event 9249/9536...
# Processing event 9250/9536...
# Processing event 9251/9536...
# Processing event 9252/9536...
# Processing event 9253/9536...
# Processing event 9254/9536...
# Processing event 9255/9536...
# Processing event 9256/9536...
# Processing event 9257/9536...
# Processing event 9258/9536...
# Processing event 9259/9536...
# Processing event 9260/9536...
# Processing event 9261/9536...
# Processing event 9262/9536...
# Processing event 9263/9536...
# Processing event 9264/9536...
# Processing event 9265/9536...
# Processing event 9266/9536...
# Processing event 9267/9536...
# Processing event 9268/9536...
# Processing event 9269/9536...
# Processing event 9270/9536...
# Processing event 9271/9536...
# Processing event 9272/9536...
# Processing event 9273/9536...
# Processing event 9274/9536...
# Processing event 9275/9536...
# Processing event 9276/9536...
# Processing event 9277/9536...
# Processing event 9278/9536...
# Processing event 9279/9536...
# Processing event 9280/9536...
# Processing event 9281/9536...
# Processing event 9282/9536...
# Processing event 9283/9536...
# Processing event 9284/9536...
# Processing event 9285/9536...
# Processing event 9286/9536...
# Processing event 9287/9536...
# Processing event 9288/9536...
# Processing event 9289/9536...
# Processing event 9290/9536...
# Processing event 9291/9536...
# Processing event 9292/9536...
# Processing event 9293/9536...
# Processing event 9294/9536...
# Processing event 9295/9536...
# Processing event 9296/9536...
# Processing event 9297/9536...
# Processing event 9298/9536...
# Processing event 9299/9536...
# Processing event 9300/9536...
# Processing event 9301/9536...
# Processing event 9302/9536...
# Processing event 9303/9536...
# Processing event 9304/9536...
# Processing event 9305/9536...
# Processing event 9306/9536...
# Processing event 9307/9536...
# Processing event 9308/9536...
# Processing event 9309/9536...
# Processing event 9310/9536...
# Processing event 9311/9536...
# Processing event 9312/9536...
# Processing event 9313/9536...
# Processing event 9314/9536...
# Processing event 9315/9536...
# Processing event 9316/9536...
# Processing event 9317/9536...
# Processing event 9318/9536...
# Processing event 9319/9536...
# Processing event 9320/9536...
# Processing event 9321/9536...
# Processing event 9322/9536...
# Processing event 9323/9536...
# Processing event 9324/9536...
# Processing event 9325/9536...
# Processing event 9326/9536...
# Processing event 9327/9536...
# Processing event 9328/9536...
# Processing event 9329/9536...
# Processing event 9330/9536...
# Processing event 9331/9536...
# Processing event 9332/9536...
# Processing event 9333/9536...
# Processing event 9334/9536...
# Processing event 9335/9536...
# Processing event 9336/9536...
# Processing event 9337/9536...
# Processing event 9338/9536...
# Processing event 9339/9536...
# Processing event 9340/9536...
# Processing event 9341/9536...
# Processing event 9342/9536...
# Processing event 9343/9536...
# Processing event 9344/9536...
# Processing event 9345/9536...
# Processing event 9346/9536...
# Processing event 9347/9536...
# Processing event 9348/9536...
# Processing event 9349/9536...
# Processing event 9350/9536...
# Processing event 9351/9536...
# Processing event 9352/9536...
# Processing event 9353/9536...
# Processing event 9354/9536...
# Processing event 9355/9536...
# Processing event 9356/9536...
# Processing event 9357/9536...
# Processing event 9358/9536...
# Processing event 9359/9536...
# Processing event 9360/9536...
# Processing event 9361/9536...
# Processing event 9362/9536...
# Processing event 9363/9536...
# Processing event 9364/9536...
# Processing event 9365/9536...
# Processing event 9366/9536...
# Processing event 9367/9536...
# Processing event 9368/9536...
# Processing event 9369/9536...
# Processing event 9370/9536...
# Processing event 9371/9536...
# Processing event 9372/9536...
# Processing event 9373/9536...
# Processing event 9374/9536...
# Processing event 9375/9536...
# Processing event 9376/9536...
# Processing event 9377/9536...
# Processing event 9378/9536...
# Processing event 9379/9536...
# Processing event 9380/9536...
# Processing event 9381/9536...
# Processing event 9382/9536...
# Processing event 9383/9536...
# Processing event 9384/9536...
# Processing event 9385/9536...
# Processing event 9386/9536...
# Processing event 9387/9536...
# Processing event 9388/9536...
# Processing event 9389/9536...
# Processing event 9390/9536...
# Processing event 9391/9536...
# Processing event 9392/9536...
# Processing event 9393/9536...
# Processing event 9394/9536...
# Processing event 9395/9536...
# Processing event 9396/9536...
# Processing event 9397/9536...
# Processing event 9398/9536...
# Processing event 9399/9536...
# Processing event 9400/9536...
# Processing event 9401/9536...
# Processing event 9402/9536...
# Processing event 9403/9536...
# Processing event 9404/9536...
# Processing event 9405/9536...
# Processing event 9406/9536...
# Processing event 9407/9536...
# Processing event 9408/9536...
# Processing event 9409/9536...
# Processing event 9410/9536...
# Processing event 9411/9536...
# Processing event 9412/9536...
# Processing event 9413/9536...
# Processing event 9414/9536...
# Processing event 9415/9536...
# Processing event 9416/9536...
# Processing event 9417/9536...
# Processing event 9418/9536...
# Processing event 9419/9536...
# Processing event 9420/9536...
# Processing event 9421/9536...
# Processing event 9422/9536...
# Processing event 9423/9536...
# Processing event 9424/9536...
# Processing event 9425/9536...
# Processing event 9426/9536...
# Processing event 9427/9536...
# Processing event 9428/9536...
# Processing event 9429/9536...
# Processing event 9430/9536...
# Processing event 9431/9536...
# Processing event 9432/9536...
# Processing event 9433/9536...
# Processing event 9434/9536...
# Processing event 9435/9536...
# Processing event 9436/9536...
# Processing event 9437/9536...
# Processing event 9438/9536...
# Processing event 9439/9536...
# Processing event 9440/9536...
# Processing event 9441/9536...
# Processing event 9442/9536...
# Processing event 9443/9536...
# Processing event 9444/9536...
# Processing event 9445/9536...
# Processing event 9446/9536...
# Processing event 9447/9536...
# Processing event 9448/9536...
# Processing event 9449/9536...
# Processing event 9450/9536...
# Processing event 9451/9536...
# Processing event 9452/9536...
# Processing event 9453/9536...
# Processing event 9454/9536...
# Processing event 9455/9536...
# Processing event 9456/9536...
# Processing event 9457/9536...
# Processing event 9458/9536...
# Processing event 9459/9536...
# Processing event 9460/9536...
# Processing event 9461/9536...
# Processing event 9462/9536...
# Processing event 9463/9536...
# Processing event 9464/9536...
# Processing event 9465/9536...
# Processing event 9466/9536...
# Processing event 9467/9536...
# Processing event 9468/9536...
# Processing event 9469/9536...
# Processing event 9470/9536...
# Processing event 9471/9536...
# Processing event 9472/9536...
# Processing event 9473/9536...
# Processing event 9474/9536...
# Processing event 9475/9536...
# Processing event 9476/9536...
# Processing event 9477/9536...
# Processing event 9478/9536...
# Processing event 9479/9536...
# Processing event 9480/9536...
# Processing event 9481/9536...
# Processing event 9482/9536...
# Processing event 9483/9536...
# Processing event 9484/9536...
# Processing event 9485/9536...
# Processing event 9486/9536...
# Processing event 9487/9536...
# Processing event 9488/9536...
# Processing event 9489/9536...
# Processing event 9490/9536...
# Processing event 9491/9536...
# Processing event 9492/9536...
# Processing event 9493/9536...
# Processing event 9494/9536...
# Processing event 9495/9536...
# Processing event 9496/9536...
# Processing event 9497/9536...
# Processing event 9498/9536...
# Processing event 9499/9536...
# Processing event 9500/9536...
# Processing event 9501/9536...
# Processing event 9502/9536...
# Processing event 9503/9536...
# Processing event 9504/9536...
# Processing event 9505/9536...
# Processing event 9506/9536...
# Processing event 9507/9536...
# Processing event 9508/9536...
# Processing event 9509/9536...
# Processing event 9510/9536...
# Processing event 9511/9536...
# Processing event 9512/9536...
# Processing event 9513/9536...
# Processing event 9514/9536...
# Processing event 9515/9536...
# Processing event 9516/9536...
# Processing event 9517/9536...
# Processing event 9518/9536...
# Processing event 9519/9536...
# Processing event 9520/9536...
# Processing event 9521/9536...
# Processing event 9522/9536...
# Processing event 9523/9536...
# Processing event 9524/9536...
# Processing event 9525/9536...
# Processing event 9526/9536...
# Processing event 9527/9536...
# Processing event 9528/9536...
# Processing event 9529/9536...
# Processing event 9530/9536...
# Processing event 9531/9536...
# Processing event 9532/9536...
# Processing event 9533/9536...
# Processing event 9534/9536...
# Processing event 9535/9536...
# Processing event 9536/9536...
# /tmp/ipykernel_1244483/1411266961.py:61: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   all_cluster_labels = np.array(all_cluster_labels)

# %%
recon_ind = []

for event_idx, labels in enumerate(all_cluster_labels):
    event_clusters = {} 
    
    for cluster_idx, cluster_label in enumerate(labels):
        if cluster_label not in event_clusters:
            event_clusters[cluster_label] = []
        event_clusters[cluster_label].extend(Track_ind[event_idx][cluster_idx])
    
    recon_ind.append([event_clusters[label] for label in sorted(event_clusters.keys())])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1244483/387040593.py in <module>
#       7         if cluster_label not in event_clusters:
#       8             event_clusters[cluster_label] = []
# ----> 9         event_clusters[cluster_label].extend(Track_ind[event_idx][cluster_idx])
#      10
#      11     recon_ind.append([event_clusters[label] for label in sorted(event_clusters.keys())])
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/awkward/highlevel.py in __getitem__(self, where)
#     989         """
#     990         if not hasattr(self, "_tracers"):
# --> 991             tmp = ak._util.wrap(self.layout[where], self._behavior)
#     992         else:
#     993             tmp = ak._connect._jax.jax_utils._jaxtracers_getitem(self, where)
#
# ValueError: in ListOffsetArray64 attempting to get 1, index out of range
#
# (https://github.com/scikit-hep/awkward-1.0/blob/1.10.3/src/libawkward/array/ListOffsetArray.cpp#L682)

# %%
def calculate_sim_to_reco_score(CaloParticle, energies_indices, ReconstructedTrackster, Multi):
    """
    Calculate the sim-to-reco score for a given CaloParticle and ReconstructedTrackster.
    
    Parameters:
    - CaloParticle: array of Layer Clusters in the CaloParticle.
    - Multiplicity: array of Multiplicity for layer clusters in CP
    - energies_indices: array of energies associated with all LC (indexed by LC).
    - ReconstructedTrackster: array of LC in the reconstructed Trackster.
    
    Returns:
    - sim_to_reco_score: the calculated sim-to-reco score.
    """
    numerator = 0.0
    denominator = 0.0

    energy_caloparticle_lc = energies_indices[CaloParticle] / Multi
    total_energy_caloparticle = sum(energy_caloparticle_lc)
    if total_energy_caloparticle == 0:
        return 1.0  # No energy in the CaloParticle implies perfect mismatch

    # Calculate total energy of the ReconstructedTrackster
    total_energy_trackster = sum(energies_indices[det_id] for det_id in ReconstructedTrackster)
    i = 0
    # Iterate over all DetIds in the CaloParticle
    for det_id in CaloParticle:
        energy_k = energies_indices[det_id]  # Energy for the current DetId in CaloParticle
        # Fraction of energy in the Trackster (fr_k^TST)
        fr_tst_k = 1 if det_id in ReconstructedTrackster else 0.0
        # Fraction of energy in the CaloParticle (fr_k^SC)
        fr_sc_k = 1 / Multi[i]

        # Update numerator using the min function
        numerator += min(
            (fr_tst_k - fr_sc_k) ** 2,  # First term in the min function
            fr_sc_k ** 2                # Second term in the min function
        ) * (energy_k ** 2)

        # Update denominator
        denominator += (fr_sc_k ** 2) * (energy_k ** 2)
        i+=1

    # Calculate score
    sim_to_reco_score = numerator / denominator if denominator != 0 else 1.0
    return sim_to_reco_score

def calculate_reco_to_sim_score(ReconstructedTrackster, energies_indices, CaloParticle, Multi):
    """
    Calculate the reco-to-sim score for a given ReconstructedTrackster and CaloParticle.

    Parameters:
    - ReconstructedTrackster: array of DetIds in the ReconstructedTrackster.
    - energies_indices: array of energies associated with all DetIds (indexed by DetId).
    - CaloParticle: array of DetIds in the CaloParticle.

    Returns:
    - reco_to_sim_score: the calculated reco-to-sim score.
    """
    numerator = 0.0
    denominator = 0.0

    # Calculate total energy of the ReconstructedTrackster
    total_energy_trackster = sum(energies_indices[det_id] for det_id in ReconstructedTrackster)
    if total_energy_trackster == 0:
        return 1.0  # No energy in the Trackster implies perfect mismatch

    energy_caloparticle_lc = energies_indices[CaloParticle] / Multi
    total_energy_caloparticle = sum(energy_caloparticle_lc)
    # Iterate over all DetIds in the ReconstructedTrackster
    for det_id in ReconstructedTrackster:
        energy_k = energies_indices[det_id]  # Energy for the current DetId in the Trackster
        
        # Fraction of energy in the Trackster (fr_k^TST)
        fr_tst_k = 1

        #fr_sc_k = 1 if det_id in CaloParticle else 0.0
        if det_id in CaloParticle:
            index = np.where(CaloParticle == det_id)[0][0]  # Find the index
            Multiplicity = Multi[index]
            fr_sc_k = 1
        else:
            fr_sc_k = 0
            
        # Update numerator using the min function
        numerator += min(
            (fr_tst_k - fr_sc_k) ** 2,  # First term in the min function
            fr_tst_k ** 2               # Second term in the min function
        ) * (energy_k ** 2)

        # Update denominator
        denominator += (fr_tst_k ** 2) * (energy_k ** 2)

    # Calculate score
    reco_to_sim_score = numerator / denominator if denominator != 0 else 1.0
    return reco_to_sim_score

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm  # For progress bar
def calculate_all_event_scores(GT_ind, energies, recon_ind, LC_x, LC_y, LC_z, LC_eta, multi, num_events = 100):
    """
    Calculate sim-to-reco and reco-to-sim scores for all CaloParticle and ReconstructedTrackster combinations across all events.

    Parameters:
    - GT_ind: List of CaloParticle indices for all events.
    - energies: List of energy arrays for all events.
    - recon_ind: List of ReconstructedTrackster indices for all events.
    - LC_x, LC_y, LC_z, LC_eta: Lists of x, y, z positions and eta values for all DetIds across events.

    Returns:
    - DataFrame containing scores and additional features for each CaloParticle-Trackster combination across all events.
    """
    # Initialize an empty list to store results
    all_results = []

    # Loop over all events with a progress bar
    for event_index in range(num_events):
        caloparticles = GT_ind[event_index]  # Indices for all CaloParticles in the event
        tracksters = recon_ind[event_index]  # Indices for all ReconstructedTracksters in the event
        event_energies = energies[event_index]  # Energies for this event
        event_multi = multi[event_index]

        # Extract layer cluster positions and eta for this event
        event_x = np.array(LC_x[event_index])
        event_y = np.array(LC_y[event_index])
        event_z = np.array(LC_z[event_index])
        event_eta = np.array(LC_eta[event_index])

        # Compute barycenter for each CaloParticle
        cp_barycenters = []
        cp_avg_etas = []
        for caloparticle in caloparticles:
            # Compute barycenter (x, y, z)
            
            barycenter_x = np.mean([event_x[det_id] for det_id in caloparticle])
            barycenter_y = np.mean([event_y[det_id] for det_id in caloparticle])
            barycenter_z = np.mean([event_z[det_id] for det_id in caloparticle])
            cp_barycenters.append(np.array([barycenter_x, barycenter_y, barycenter_z]))
            
            # Compute average eta
            avg_eta = np.mean([event_eta[det_id] for det_id in caloparticle])
            cp_avg_etas.append(avg_eta)

        # Compute separation between two CaloParticles if at least two exist
        if len(cp_barycenters) >= 2:
            cp_separation = np.linalg.norm(cp_barycenters[0] - cp_barycenters[1])
        else:
            cp_separation = 0.0
            
        trackster_det_id_sets = [set(trackster) for trackster in tracksters]

        # Loop over all CaloParticles
        for calo_idx, caloparticle in enumerate(caloparticles):
            Calo_multi = event_multi[calo_idx]
            calo_det_ids = set(calo_id for calo_id in caloparticle)
            # Loop over all Tracksters
            for trackster_idx, trackster in enumerate(tracksters):
                # Calculate sim-to-reco score
                trackster_det_ids = trackster_det_id_sets[trackster_idx]
                shared_det_ids = calo_det_ids.intersection(trackster_det_ids)
                
                # Calculate shared_energy by summing energies of shared det_ids
                shared_energy = np.sum(event_energies[list(shared_det_ids)]) if shared_det_ids else 0.0
                
                
                sim_to_reco_score = calculate_sim_to_reco_score(caloparticle, event_energies, trackster, Calo_multi)
                # Calculate reco-to-sim score
                reco_to_sim_score = calculate_reco_to_sim_score(trackster, event_energies, caloparticle, Calo_multi)

                # Calculate total energy for CaloParticle and Trackster
                cp_energy_lc2 = event_energies[caloparticle] / Calo_multi
                cp_energy = np.sum(cp_energy_lc2)
                
                trackster_energy = np.sum([event_energies[det_id] for det_id in trackster])

                # Calculate energy difference ratio
                energy_diff_ratio = (trackster_energy / cp_energy if cp_energy != 0 else None)

                # Append results
                all_results.append({
                    "event_index": event_index,
                    "cp_id": calo_idx,
                    "trackster_id": trackster_idx,
                    "sim_to_reco_score": sim_to_reco_score,
                    "reco_to_sim_score": reco_to_sim_score,
                    "cp_energy": cp_energy,
                    "trackster_energy": trackster_energy,
                    "cp_avg_eta": cp_avg_etas[calo_idx],
                    "cp_separation": cp_separation,
                    "energy_ratio": energy_diff_ratio,
                    "shared_energy": shared_energy  # New column
                })

    # Convert results to a DataFrame
    df = pd.DataFrame(all_results)
    return df

# %%
df_CL = calculate_all_event_scores(GT_ind, energies, recon_ind, LC_x, LC_y, LC_z, LC_eta, GT_mult, num_events = 100)
df_TICL = calculate_all_event_scores(GT_ind, energies, MT_ind, LC_x, LC_y, LC_z, LC_eta, GT_mult, num_events = 100)

# %%
#5: Print metrics

def calculate_metrics(df, model_name):
    # ----- Efficiency Calculation -----
    # Step 1: Filter out rows where 'cp_id' is NaN
    cp_valid = df.dropna(subset=['cp_id']).copy()

    # Step 2: Group by 'event_index' and 'cp_id' to process each CaloParticle individually
    cp_grouped = cp_valid.groupby(['event_index', 'cp_id'])

    # Step 3: For each CaloParticle, check if any 'shared_energy' >= 50% of 'cp_energy'
    def is_cp_associated(group):
        cp_energy = group['cp_energy'].iloc[0]  # Assuming 'cp_energy' is consistent within the group
        threshold = 0.5 * cp_energy
        return (group['shared_energy'] >= threshold).any()

    # Apply the association function to each group
    cp_associated = cp_grouped.apply(is_cp_associated)

    # Step 4: Calculate the number of associated CaloParticles and total CaloParticles
    num_associated_cp = cp_associated.sum()
    total_cp = cp_associated.count()
    efficiency = num_associated_cp / total_cp if total_cp > 0 else 0

    # ----- Purity Calculation -----
    tst_valid = df.dropna(subset=['trackster_id']).copy()
    tst_grouped = tst_valid.groupby(['event_index', 'trackster_id'])
    tst_associated = tst_grouped['reco_to_sim_score'].min() < 0.2
    num_associated_tst = tst_associated.sum()
    total_tst = tst_associated.count()
    purity = num_associated_tst / total_tst if total_tst > 0 else 0

    # ----- Average Energy Ratio Calculation -----
    low_score_mask = df['sim_to_reco_score'] < 0.2
    low_score_events = df[low_score_mask]
    if not low_score_events.empty:
        avg_energy_ratio = (low_score_events['trackster_energy'] / low_score_events['cp_energy']).mean()
    else:
        avg_energy_ratio = 0

    # Print results for the model
    print(f"\nModel: {model_name}")
    print(f"Efficiency: {efficiency:.4f} ({num_associated_cp} associated CPs out of {total_cp} total CPs)")
    print(f"Purity: {purity:.4f} ({num_associated_tst} associated Tracksters out of {total_tst} total Tracksters)")
    print(f"Num tracksters ratio: {total_tst / total_cp if total_cp > 0 else 0:.4f}")
    print(f"Average Energy Ratio: {avg_energy_ratio:.4f}")

    return {
        'efficiency': efficiency,
        'purity': purity,
        'avg_energy_ratio': avg_energy_ratio,
    }

# Example usage
our_model_metrics = calculate_metrics(df_CL, "Our Model")
cern_model_metrics = calculate_metrics(df_TICL, "CERN Model")
