# %%
import uproot  # For loading ROOT files
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %%
from dataAnalyse import CCV2
from torch_geometric.data import DataLoader

# %%
testpath = "/vols/cms/mm1221/Data/5e/test/"  # Replace with your ROOT file path
data_test = CCV2(testpath, max_events=12000, inp = 'test')

test_loader = DataLoader(data_test, batch_size=1, shuffle=False, follow_batch=['x'])
# Out:
# ### Loading tracksters data
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:21<00:00, 21.48s/it]
# /cvmfs/sft.cern.ch/lcg/views/LCG_105a_cuda/x86_64-el9-gcc11-opt/lib/python3.9/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
data_path = '/vols/cms/mm1221/Data/5e/test/raw/test.root'
data_file = uproot.open(data_path)

Track_ind = data_file['tracksters;1']['vertices_indexes'].array()
GT_ind = data_file['simtrackstersCP;1']['vertices_indexes'].array()
GT_bc = data_file['simtrackstersCP;1']['barycenter_x'].array()
energies = data_file['clusters;1']['energy'].array()
LC_x = data_file['clusters;1']['position_x'].array()
LC_y = data_file['clusters;1']['position_y'].array()
LC_z = data_file['clusters;1']['position_z'].array()
LC_eta = data_file['clusters;1']['position_eta'].array()
MT_ind = data_file['trackstersMerged;1']['vertices_indexes'].array()

skim_mask = []
for e in GT_bc:
    if 1 <= len(e) <= 5:
        skim_mask.append(True)
    else:
        skim_mask.append(False)
        
GT_ind = GT_ind[skim_mask]
energies = energies[skim_mask]
Track_ind = Track_ind[skim_mask]
MT_ind = MT_ind[skim_mask]

LC_x = LC_x[skim_mask]
LC_y = LC_y[skim_mask]
LC_z = LC_z[skim_mask]
LC_eta = LC_eta[skim_mask]

# %%
#0.0001,32,64,4,0.2,16,8
# Initialize model and load state dictionary
from model import Net
model = Net(64, 4, 0.2, 8)
checkpoint= torch.load('/vols/cms/mm1221/hgcal/elec5/Track/StaticEdge/results/init/results_lr0.0001_bs32_hd64_nl4_do0.2_k16_cd8/best_model.pt',  map_location=torch.device('cpu'))
model.load_state_dict(checkpoint)  # Directly use the loaded checkpoint
model.eval()  # Set model to evaluation mode
# Out:
# Net(
#   (lc_encode): Sequential(
#     (0): Linear(in_features=15, out_features=64, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ELU(alpha=1.0)
#   )
#   (convs): ModuleList(
#     (0-3): 4 x CustomStaticEdgeConv(
#       (nn_module): Sequential(
#         (0): Linear(in_features=128, out_features=64, bias=True)
#         (1): ELU(alpha=1.0)
#         (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (output): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ELU(alpha=1.0)
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=8, bias=True)
#   )
# )

# %%
from torch_geometric.nn import knn_graph

all_predictions = []  # List to store predictions for all events

# Loop through all events in the test dataset
for i, data in enumerate(data_test):
    print(f"Processing event {i+1}/{len(data_test)}...")

    # Compute k-nearest neighbor graph for the event
    edge_index = knn_graph(data.x, k=16)  # Adjust 'k' as needed
    
    # Generate predictions for the event
    predictions = model(data.x, edge_index, 1)
    
    # Store predictions
    all_predictions.append(predictions[0].detach().cpu().numpy())  # Convert to numpy if needed

# Convert list of predictions to a single numpy array
all_predictions = np.array(all_predictions)

# Print result
print("Predictions for all events shape:", all_predictions.shape)
# Out:
# Processing event 1/2417...
# Processing event 2/2417...
# Processing event 3/2417...
# Processing event 4/2417...
# Processing event 5/2417...
# Processing event 6/2417...
# Processing event 7/2417...
# Processing event 8/2417...
# Processing event 9/2417...
# Processing event 10/2417...
# Processing event 11/2417...
# Processing event 12/2417...
# Processing event 13/2417...
# Processing event 14/2417...
# Processing event 15/2417...
# Processing event 16/2417...
# Processing event 17/2417...
# Processing event 18/2417...
# Processing event 19/2417...
# Processing event 20/2417...
# Processing event 21/2417...
# Processing event 22/2417...
# Processing event 23/2417...
# Processing event 24/2417...
# Processing event 25/2417...
# Processing event 26/2417...
# Processing event 27/2417...
# Processing event 28/2417...
# Processing event 29/2417...
# Processing event 30/2417...
# Processing event 31/2417...
# Processing event 32/2417...
# Processing event 33/2417...
# Processing event 34/2417...
# Processing event 35/2417...
# Processing event 36/2417...
# Processing event 37/2417...
# Processing event 38/2417...
# Processing event 39/2417...
# Processing event 40/2417...
# Processing event 41/2417...
# Processing event 42/2417...
# Processing event 43/2417...
# Processing event 44/2417...
# Processing event 45/2417...
# Processing event 46/2417...
# Processing event 47/2417...
# Processing event 48/2417...
# Processing event 49/2417...
# Processing event 50/2417...
# Processing event 51/2417...
# Processing event 52/2417...
# Processing event 53/2417...
# Processing event 54/2417...
# Processing event 55/2417...
# Processing event 56/2417...
# Processing event 57/2417...
# Processing event 58/2417...
# Processing event 59/2417...
# Processing event 60/2417...
# Processing event 61/2417...
# Processing event 62/2417...
# Processing event 63/2417...
# Processing event 64/2417...
# Processing event 65/2417...
# Processing event 66/2417...
# Processing event 67/2417...
# Processing event 68/2417...
# Processing event 69/2417...
# Processing event 70/2417...
# Processing event 71/2417...
# Processing event 72/2417...
# Processing event 73/2417...
# Processing event 74/2417...
# Processing event 75/2417...
# Processing event 76/2417...
# Processing event 77/2417...
# Processing event 78/2417...
# Processing event 79/2417...
# Processing event 80/2417...
# Processing event 81/2417...
# Processing event 82/2417...
# Processing event 83/2417...
# Processing event 84/2417...
# Processing event 85/2417...
# Processing event 86/2417...
# Processing event 87/2417...
# Processing event 88/2417...
# Processing event 89/2417...
# Processing event 90/2417...
# Processing event 91/2417...
# Processing event 92/2417...
# Processing event 93/2417...
# Processing event 94/2417...
# Processing event 95/2417...
# Processing event 96/2417...
# Processing event 97/2417...
# Processing event 98/2417...
# Processing event 99/2417...
# Processing event 100/2417...
# Processing event 101/2417...
# Processing event 102/2417...
# Processing event 103/2417...
# Processing event 104/2417...
# Processing event 105/2417...
# Processing event 106/2417...
# Processing event 107/2417...
# Processing event 108/2417...
# Processing event 109/2417...
# Processing event 110/2417...
# Processing event 111/2417...
# Processing event 112/2417...
# Processing event 113/2417...
# Processing event 114/2417...
# Processing event 115/2417...
# Processing event 116/2417...
# Processing event 117/2417...
# Processing event 118/2417...
# Processing event 119/2417...
# Processing event 120/2417...
# Processing event 121/2417...
# Processing event 122/2417...
# Processing event 123/2417...
# Processing event 124/2417...
# Processing event 125/2417...
# Processing event 126/2417...
# Processing event 127/2417...
# Processing event 128/2417...
# Processing event 129/2417...
# Processing event 130/2417...
# Processing event 131/2417...
# Processing event 132/2417...
# Processing event 133/2417...
# Processing event 134/2417...
# Processing event 135/2417...
# Processing event 136/2417...
# Processing event 137/2417...
# Processing event 138/2417...
# Processing event 139/2417...
# Processing event 140/2417...
# Processing event 141/2417...
# Processing event 142/2417...
# Processing event 143/2417...
# Processing event 144/2417...
# Processing event 145/2417...
# Processing event 146/2417...
# Processing event 147/2417...
# Processing event 148/2417...
# Processing event 149/2417...
# Processing event 150/2417...
# Processing event 151/2417...
# Processing event 152/2417...
# Processing event 153/2417...
# Processing event 154/2417...
# Processing event 155/2417...
# Processing event 156/2417...
# Processing event 157/2417...
# Processing event 158/2417...
# Processing event 159/2417...
# Processing event 160/2417...
# Processing event 161/2417...
# Processing event 162/2417...
# Processing event 163/2417...
# Processing event 164/2417...
# Processing event 165/2417...
# Processing event 166/2417...
# Processing event 167/2417...
# Processing event 168/2417...
# Processing event 169/2417...
# Processing event 170/2417...
# Processing event 171/2417...
# Processing event 172/2417...
# Processing event 173/2417...
# Processing event 174/2417...
# Processing event 175/2417...
# Processing event 176/2417...
# Processing event 177/2417...
# Processing event 178/2417...
# Processing event 179/2417...
# Processing event 180/2417...
# Processing event 181/2417...
# Processing event 182/2417...
# Processing event 183/2417...
# Processing event 184/2417...
# Processing event 185/2417...
# Processing event 186/2417...
# Processing event 187/2417...
# Processing event 188/2417...
# Processing event 189/2417...
# Processing event 190/2417...
# Processing event 191/2417...
# Processing event 192/2417...
# Processing event 193/2417...
# Processing event 194/2417...
# Processing event 195/2417...
# Processing event 196/2417...
# Processing event 197/2417...
# Processing event 198/2417...
# Processing event 199/2417...
# Processing event 200/2417...
# Processing event 201/2417...
# Processing event 202/2417...
# Processing event 203/2417...
# Processing event 204/2417...
# Processing event 205/2417...
# Processing event 206/2417...
# Processing event 207/2417...
# Processing event 208/2417...
# Processing event 209/2417...
# Processing event 210/2417...
# Processing event 211/2417...
# Processing event 212/2417...
# Processing event 213/2417...
# Processing event 214/2417...
# Processing event 215/2417...
# Processing event 216/2417...
# Processing event 217/2417...
# Processing event 218/2417...
# Processing event 219/2417...
# Processing event 220/2417...
# Processing event 221/2417...
# Processing event 222/2417...
# Processing event 223/2417...
# Processing event 224/2417...
# Processing event 225/2417...
# Processing event 226/2417...
# Processing event 227/2417...
# Processing event 228/2417...
# Processing event 229/2417...
# Processing event 230/2417...
# Processing event 231/2417...
# Processing event 232/2417...
# Processing event 233/2417...
# Processing event 234/2417...
# Processing event 235/2417...
# Processing event 236/2417...
# Processing event 237/2417...
# Processing event 238/2417...
# Processing event 239/2417...
# Processing event 240/2417...
# Processing event 241/2417...
# Processing event 242/2417...
# Processing event 243/2417...
# Processing event 244/2417...
# Processing event 245/2417...
# Processing event 246/2417...
# Processing event 247/2417...
# Processing event 248/2417...
# Processing event 249/2417...
# Processing event 250/2417...
# Processing event 251/2417...
# Processing event 252/2417...
# Processing event 253/2417...
# Processing event 254/2417...
# Processing event 255/2417...
# Processing event 256/2417...
# Processing event 257/2417...
# Processing event 258/2417...
# Processing event 259/2417...
# Processing event 260/2417...
# Processing event 261/2417...
# Processing event 262/2417...
# Processing event 263/2417...
# Processing event 264/2417...
# Processing event 265/2417...
# Processing event 266/2417...
# Processing event 267/2417...
# Processing event 268/2417...
# Processing event 269/2417...
# Processing event 270/2417...
# Processing event 271/2417...
# Processing event 272/2417...
# Processing event 273/2417...
# Processing event 274/2417...
# Processing event 275/2417...
# Processing event 276/2417...
# Processing event 277/2417...
# Processing event 278/2417...
# Processing event 279/2417...
# Processing event 280/2417...
# Processing event 281/2417...
# Processing event 282/2417...
# Processing event 283/2417...
# Processing event 284/2417...
# Processing event 285/2417...
# Processing event 286/2417...
# Processing event 287/2417...
# Processing event 288/2417...
# Processing event 289/2417...
# Processing event 290/2417...
# Processing event 291/2417...
# Processing event 292/2417...
# Processing event 293/2417...
# Processing event 294/2417...
# Processing event 295/2417...
# Processing event 296/2417...
# Processing event 297/2417...
# Processing event 298/2417...
# Processing event 299/2417...
# Processing event 300/2417...
# Processing event 301/2417...
# Processing event 302/2417...
# Processing event 303/2417...
# Processing event 304/2417...
# Processing event 305/2417...
# Processing event 306/2417...
# Processing event 307/2417...
# Processing event 308/2417...
# Processing event 309/2417...
# Processing event 310/2417...
# Processing event 311/2417...
# Processing event 312/2417...
# Processing event 313/2417...
# Processing event 314/2417...
# Processing event 315/2417...
# Processing event 316/2417...
# Processing event 317/2417...
# Processing event 318/2417...
# Processing event 319/2417...
# Processing event 320/2417...
# Processing event 321/2417...
# Processing event 322/2417...
# Processing event 323/2417...
# Processing event 324/2417...
# Processing event 325/2417...
# Processing event 326/2417...
# Processing event 327/2417...
# Processing event 328/2417...
# Processing event 329/2417...
# Processing event 330/2417...
# Processing event 331/2417...
# Processing event 332/2417...
# Processing event 333/2417...
# Processing event 334/2417...
# Processing event 335/2417...
# Processing event 336/2417...
# Processing event 337/2417...
# Processing event 338/2417...
# Processing event 339/2417...
# Processing event 340/2417...
# Processing event 341/2417...
# Processing event 342/2417...
# Processing event 343/2417...
# Processing event 344/2417...
# Processing event 345/2417...
# Processing event 346/2417...
# Processing event 347/2417...
# Processing event 348/2417...
# Processing event 349/2417...
# Processing event 350/2417...
# Processing event 351/2417...
# Processing event 352/2417...
# Processing event 353/2417...
# Processing event 354/2417...
# Processing event 355/2417...
# Processing event 356/2417...
# Processing event 357/2417...
# Processing event 358/2417...
# Processing event 359/2417...
# Processing event 360/2417...
# Processing event 361/2417...
# Processing event 362/2417...
# Processing event 363/2417...
# Processing event 364/2417...
# Processing event 365/2417...
# Processing event 366/2417...
# Processing event 367/2417...
# Processing event 368/2417...
# Processing event 369/2417...
# Processing event 370/2417...
# Processing event 371/2417...
# Processing event 372/2417...
# Processing event 373/2417...
# Processing event 374/2417...
# Processing event 375/2417...
# Processing event 376/2417...
# Processing event 377/2417...
# Processing event 378/2417...
# Processing event 379/2417...
# Processing event 380/2417...
# Processing event 381/2417...
# Processing event 382/2417...
# Processing event 383/2417...
# Processing event 384/2417...
# Processing event 385/2417...
# Processing event 386/2417...
# Processing event 387/2417...
# Processing event 388/2417...
# Processing event 389/2417...
# Processing event 390/2417...
# Processing event 391/2417...
# Processing event 392/2417...
# Processing event 393/2417...
# Processing event 394/2417...
# Processing event 395/2417...
# Processing event 396/2417...
# Processing event 397/2417...
# Processing event 398/2417...
# Processing event 399/2417...
# Processing event 400/2417...
# Processing event 401/2417...
# Processing event 402/2417...
# Processing event 403/2417...
# Processing event 404/2417...
# Processing event 405/2417...
# Processing event 406/2417...
# Processing event 407/2417...
# Processing event 408/2417...
# Processing event 409/2417...
# Processing event 410/2417...
# Processing event 411/2417...
# Processing event 412/2417...
# Processing event 413/2417...
# Processing event 414/2417...
# Processing event 415/2417...
# Processing event 416/2417...
# Processing event 417/2417...
# Processing event 418/2417...
# Processing event 419/2417...
# Processing event 420/2417...
# Processing event 421/2417...
# Processing event 422/2417...
# Processing event 423/2417...
# Processing event 424/2417...
# Processing event 425/2417...
# Processing event 426/2417...
# Processing event 427/2417...
# Processing event 428/2417...
# Processing event 429/2417...
# Processing event 430/2417...
# Processing event 431/2417...
# Processing event 432/2417...
# Processing event 433/2417...
# Processing event 434/2417...
# Processing event 435/2417...
# Processing event 436/2417...
# Processing event 437/2417...
# Processing event 438/2417...
# Processing event 439/2417...
# Processing event 440/2417...
# Processing event 441/2417...
# Processing event 442/2417...
# Processing event 443/2417...
# Processing event 444/2417...
# Processing event 445/2417...
# Processing event 446/2417...
# Processing event 447/2417...
# Processing event 448/2417...
# Processing event 449/2417...
# Processing event 450/2417...
# Processing event 451/2417...
# Processing event 452/2417...
# Processing event 453/2417...
# Processing event 454/2417...
# Processing event 455/2417...
# Processing event 456/2417...
# Processing event 457/2417...
# Processing event 458/2417...
# Processing event 459/2417...
# Processing event 460/2417...
# Processing event 461/2417...
# Processing event 462/2417...
# Processing event 463/2417...
# Processing event 464/2417...
# Processing event 465/2417...
# Processing event 466/2417...
# Processing event 467/2417...
# Processing event 468/2417...
# Processing event 469/2417...
# Processing event 470/2417...
# Processing event 471/2417...
# Processing event 472/2417...
# Processing event 473/2417...
# Processing event 474/2417...
# Processing event 475/2417...
# Processing event 476/2417...
# Processing event 477/2417...
# Processing event 478/2417...
# Processing event 479/2417...
# Processing event 480/2417...
# Processing event 481/2417...
# Processing event 482/2417...
# Processing event 483/2417...
# Processing event 484/2417...
# Processing event 485/2417...
# Processing event 486/2417...
# Processing event 487/2417...
# Processing event 488/2417...
# Processing event 489/2417...
# Processing event 490/2417...
# Processing event 491/2417...
# Processing event 492/2417...
# Processing event 493/2417...
# Processing event 494/2417...
# Processing event 495/2417...
# Processing event 496/2417...
# Processing event 497/2417...
# Processing event 498/2417...
# Processing event 499/2417...
# Processing event 500/2417...
# Processing event 501/2417...
# Processing event 502/2417...
# Processing event 503/2417...
# Processing event 504/2417...
# Processing event 505/2417...
# Processing event 506/2417...
# Processing event 507/2417...
# Processing event 508/2417...
# Processing event 509/2417...
# Processing event 510/2417...
# Processing event 511/2417...
# Processing event 512/2417...
# Processing event 513/2417...
# Processing event 514/2417...
# Processing event 515/2417...
# Processing event 516/2417...
# Processing event 517/2417...
# Processing event 518/2417...
# Processing event 519/2417...
# Processing event 520/2417...
# Processing event 521/2417...
# Processing event 522/2417...
# Processing event 523/2417...
# Processing event 524/2417...
# Processing event 525/2417...
# Processing event 526/2417...
# Processing event 527/2417...
# Processing event 528/2417...
# Processing event 529/2417...
# Processing event 530/2417...
# Processing event 531/2417...
# Processing event 532/2417...
# Processing event 533/2417...
# Processing event 534/2417...
# Processing event 535/2417...
# Processing event 536/2417...
# Processing event 537/2417...
# Processing event 538/2417...
# Processing event 539/2417...
# Processing event 540/2417...
# Processing event 541/2417...
# Processing event 542/2417...
# Processing event 543/2417...
# Processing event 544/2417...
# Processing event 545/2417...
# Processing event 546/2417...
# Processing event 547/2417...
# Processing event 548/2417...
# Processing event 549/2417...
# Processing event 550/2417...
# Processing event 551/2417...
# Processing event 552/2417...
# Processing event 553/2417...
# Processing event 554/2417...
# Processing event 555/2417...
# Processing event 556/2417...
# Processing event 557/2417...
# Processing event 558/2417...
# Processing event 559/2417...
# Processing event 560/2417...
# Processing event 561/2417...
# Processing event 562/2417...
# Processing event 563/2417...
# Processing event 564/2417...
# Processing event 565/2417...
# Processing event 566/2417...
# Processing event 567/2417...
# Processing event 568/2417...
# Processing event 569/2417...
# Processing event 570/2417...
# Processing event 571/2417...
# Processing event 572/2417...
# Processing event 573/2417...
# Processing event 574/2417...
# Processing event 575/2417...
# Processing event 576/2417...
# Processing event 577/2417...
# Processing event 578/2417...
# Processing event 579/2417...
# Processing event 580/2417...
# Processing event 581/2417...
# Processing event 582/2417...
# Processing event 583/2417...
# Processing event 584/2417...
# Processing event 585/2417...
# Processing event 586/2417...
# Processing event 587/2417...
# Processing event 588/2417...
# Processing event 589/2417...
# Processing event 590/2417...
# Processing event 591/2417...
# Processing event 592/2417...
# Processing event 593/2417...
# Processing event 594/2417...
# Processing event 595/2417...
# Processing event 596/2417...
# Processing event 597/2417...
# Processing event 598/2417...
# Processing event 599/2417...
# Processing event 600/2417...
# Processing event 601/2417...
# Processing event 602/2417...
# Processing event 603/2417...
# Processing event 604/2417...
# Processing event 605/2417...
# Processing event 606/2417...
# Processing event 607/2417...
# Processing event 608/2417...
# Processing event 609/2417...
# Processing event 610/2417...
# Processing event 611/2417...
# Processing event 612/2417...
# Processing event 613/2417...
# Processing event 614/2417...
# Processing event 615/2417...
# Processing event 616/2417...
# Processing event 617/2417...
# Processing event 618/2417...
# Processing event 619/2417...
# Processing event 620/2417...
# Processing event 621/2417...
# Processing event 622/2417...
# Processing event 623/2417...
# Processing event 624/2417...
# Processing event 625/2417...
# Processing event 626/2417...
# Processing event 627/2417...
# Processing event 628/2417...
# Processing event 629/2417...
# Processing event 630/2417...
# Processing event 631/2417...
# Processing event 632/2417...
# Processing event 633/2417...
# Processing event 634/2417...
# Processing event 635/2417...
# Processing event 636/2417...
# Processing event 637/2417...
# Processing event 638/2417...
# Processing event 639/2417...
# Processing event 640/2417...
# Processing event 641/2417...
# Processing event 642/2417...
# Processing event 643/2417...
# Processing event 644/2417...
# Processing event 645/2417...
# Processing event 646/2417...
# Processing event 647/2417...
# Processing event 648/2417...
# Processing event 649/2417...
# Processing event 650/2417...
# Processing event 651/2417...
# Processing event 652/2417...
# Processing event 653/2417...
# Processing event 654/2417...
# Processing event 655/2417...
# Processing event 656/2417...
# Processing event 657/2417...
# Processing event 658/2417...
# Processing event 659/2417...
# Processing event 660/2417...
# Processing event 661/2417...
# Processing event 662/2417...
# Processing event 663/2417...
# Processing event 664/2417...
# Processing event 665/2417...
# Processing event 666/2417...
# Processing event 667/2417...
# Processing event 668/2417...
# Processing event 669/2417...
# Processing event 670/2417...
# Processing event 671/2417...
# Processing event 672/2417...
# Processing event 673/2417...
# Processing event 674/2417...
# Processing event 675/2417...
# Processing event 676/2417...
# Processing event 677/2417...
# Processing event 678/2417...
# Processing event 679/2417...
# Processing event 680/2417...
# Processing event 681/2417...
# Processing event 682/2417...
# Processing event 683/2417...
# Processing event 684/2417...
# Processing event 685/2417...
# Processing event 686/2417...
# Processing event 687/2417...
# Processing event 688/2417...
# Processing event 689/2417...
# Processing event 690/2417...
# Processing event 691/2417...
# Processing event 692/2417...
# Processing event 693/2417...
# Processing event 694/2417...
# Processing event 695/2417...
# Processing event 696/2417...
# Processing event 697/2417...
# Processing event 698/2417...
# Processing event 699/2417...
# Processing event 700/2417...
# Processing event 701/2417...
# Processing event 702/2417...
# Processing event 703/2417...
# Processing event 704/2417...
# Processing event 705/2417...
# Processing event 706/2417...
# Processing event 707/2417...
# Processing event 708/2417...
# Processing event 709/2417...
# Processing event 710/2417...
# Processing event 711/2417...
# Processing event 712/2417...
# Processing event 713/2417...
# Processing event 714/2417...
# Processing event 715/2417...
# Processing event 716/2417...
# Processing event 717/2417...
# Processing event 718/2417...
# Processing event 719/2417...
# Processing event 720/2417...
# Processing event 721/2417...
# Processing event 722/2417...
# Processing event 723/2417...
# Processing event 724/2417...
# Processing event 725/2417...
# Processing event 726/2417...
# Processing event 727/2417...
# Processing event 728/2417...
# Processing event 729/2417...
# Processing event 730/2417...
# Processing event 731/2417...
# Processing event 732/2417...
# Processing event 733/2417...
# Processing event 734/2417...
# Processing event 735/2417...
# Processing event 736/2417...
# Processing event 737/2417...
# Processing event 738/2417...
# Processing event 739/2417...
# Processing event 740/2417...
# Processing event 741/2417...
# Processing event 742/2417...
# Processing event 743/2417...
# Processing event 744/2417...
# Processing event 745/2417...
# Processing event 746/2417...
# Processing event 747/2417...
# Processing event 748/2417...
# Processing event 749/2417...
# Processing event 750/2417...
# Processing event 751/2417...
# Processing event 752/2417...
# Processing event 753/2417...
# Processing event 754/2417...
# Processing event 755/2417...
# Processing event 756/2417...
# Processing event 757/2417...
# Processing event 758/2417...
# Processing event 759/2417...
# Processing event 760/2417...
# Processing event 761/2417...
# Processing event 762/2417...
# Processing event 763/2417...
# Processing event 764/2417...
# Processing event 765/2417...
# Processing event 766/2417...
# Processing event 767/2417...
# Processing event 768/2417...
# Processing event 769/2417...
# Processing event 770/2417...
# Processing event 771/2417...
# Processing event 772/2417...
# Processing event 773/2417...
# Processing event 774/2417...
# Processing event 775/2417...
# Processing event 776/2417...
# Processing event 777/2417...
# Processing event 778/2417...
# Processing event 779/2417...
# Processing event 780/2417...
# Processing event 781/2417...
# Processing event 782/2417...
# Processing event 783/2417...
# Processing event 784/2417...
# Processing event 785/2417...
# Processing event 786/2417...
# Processing event 787/2417...
# Processing event 788/2417...
# Processing event 789/2417...
# Processing event 790/2417...
# Processing event 791/2417...
# Processing event 792/2417...
# Processing event 793/2417...
# Processing event 794/2417...
# Processing event 795/2417...
# Processing event 796/2417...
# Processing event 797/2417...
# Processing event 798/2417...
# Processing event 799/2417...
# Processing event 800/2417...
# Processing event 801/2417...
# Processing event 802/2417...
# Processing event 803/2417...
# Processing event 804/2417...
# Processing event 805/2417...
# Processing event 806/2417...
# Processing event 807/2417...
# Processing event 808/2417...
# Processing event 809/2417...
# Processing event 810/2417...
# Processing event 811/2417...
# Processing event 812/2417...
# Processing event 813/2417...
# Processing event 814/2417...
# Processing event 815/2417...
# Processing event 816/2417...
# Processing event 817/2417...
# Processing event 818/2417...
# Processing event 819/2417...
# Processing event 820/2417...
# Processing event 821/2417...
# Processing event 822/2417...
# Processing event 823/2417...
# Processing event 824/2417...
# Processing event 825/2417...
# Processing event 826/2417...
# Processing event 827/2417...
# Processing event 828/2417...
# Processing event 829/2417...
# Processing event 830/2417...
# Processing event 831/2417...
# Processing event 832/2417...
# Processing event 833/2417...
# Processing event 834/2417...
# Processing event 835/2417...
# Processing event 836/2417...
# Processing event 837/2417...
# Processing event 838/2417...
# Processing event 839/2417...
# Processing event 840/2417...
# Processing event 841/2417...
# Processing event 842/2417...
# Processing event 843/2417...
# Processing event 844/2417...
# Processing event 845/2417...
# Processing event 846/2417...
# Processing event 847/2417...
# Processing event 848/2417...
# Processing event 849/2417...
# Processing event 850/2417...
# Processing event 851/2417...
# Processing event 852/2417...
# Processing event 853/2417...
# Processing event 854/2417...
# Processing event 855/2417...
# Processing event 856/2417...
# Processing event 857/2417...
# Processing event 858/2417...
# Processing event 859/2417...
# Processing event 860/2417...
# Processing event 861/2417...
# Processing event 862/2417...
# Processing event 863/2417...
# Processing event 864/2417...
# Processing event 865/2417...
# Processing event 866/2417...
# Processing event 867/2417...
# Processing event 868/2417...
# Processing event 869/2417...
# Processing event 870/2417...
# Processing event 871/2417...
# Processing event 872/2417...
# Processing event 873/2417...
# Processing event 874/2417...
# Processing event 875/2417...
# Processing event 876/2417...
# Processing event 877/2417...
# Processing event 878/2417...
# Processing event 879/2417...
# Processing event 880/2417...
# Processing event 881/2417...
# Processing event 882/2417...
# Processing event 883/2417...
# Processing event 884/2417...
# Processing event 885/2417...
# Processing event 886/2417...
# Processing event 887/2417...
# Processing event 888/2417...
# Processing event 889/2417...
# Processing event 890/2417...
# Processing event 891/2417...
# Processing event 892/2417...
# Processing event 893/2417...
# Processing event 894/2417...
# Processing event 895/2417...
# Processing event 896/2417...
# Processing event 897/2417...
# Processing event 898/2417...
# Processing event 899/2417...
# Processing event 900/2417...
# Processing event 901/2417...
# Processing event 902/2417...
# Processing event 903/2417...
# Processing event 904/2417...
# Processing event 905/2417...
# Processing event 906/2417...
# Processing event 907/2417...
# Processing event 908/2417...
# Processing event 909/2417...
# Processing event 910/2417...
# Processing event 911/2417...
# Processing event 912/2417...
# Processing event 913/2417...
# Processing event 914/2417...
# Processing event 915/2417...
# Processing event 916/2417...
# Processing event 917/2417...
# Processing event 918/2417...
# Processing event 919/2417...
# Processing event 920/2417...
# Processing event 921/2417...
# Processing event 922/2417...
# Processing event 923/2417...
# Processing event 924/2417...
# Processing event 925/2417...
# Processing event 926/2417...
# Processing event 927/2417...
# Processing event 928/2417...
# Processing event 929/2417...
# Processing event 930/2417...
# Processing event 931/2417...
# Processing event 932/2417...
# Processing event 933/2417...
# Processing event 934/2417...
# Processing event 935/2417...
# Processing event 936/2417...
# Processing event 937/2417...
# Processing event 938/2417...
# Processing event 939/2417...
# Processing event 940/2417...
# Processing event 941/2417...
# Processing event 942/2417...
# Processing event 943/2417...
# Processing event 944/2417...
# Processing event 945/2417...
# Processing event 946/2417...
# Processing event 947/2417...
# Processing event 948/2417...
# Processing event 949/2417...
# Processing event 950/2417...
# Processing event 951/2417...
# Processing event 952/2417...
# Processing event 953/2417...
# Processing event 954/2417...
# Processing event 955/2417...
# Processing event 956/2417...
# Processing event 957/2417...
# Processing event 958/2417...
# Processing event 959/2417...
# Processing event 960/2417...
# Processing event 961/2417...
# Processing event 962/2417...
# Processing event 963/2417...
# Processing event 964/2417...
# Processing event 965/2417...
# Processing event 966/2417...
# Processing event 967/2417...
# Processing event 968/2417...
# Processing event 969/2417...
# Processing event 970/2417...
# Processing event 971/2417...
# Processing event 972/2417...
# Processing event 973/2417...
# Processing event 974/2417...
# Processing event 975/2417...
# Processing event 976/2417...
# Processing event 977/2417...
# Processing event 978/2417...
# Processing event 979/2417...
# Processing event 980/2417...
# Processing event 981/2417...
# Processing event 982/2417...
# Processing event 983/2417...
# Processing event 984/2417...
# Processing event 985/2417...
# Processing event 986/2417...
# Processing event 987/2417...
# Processing event 988/2417...
# Processing event 989/2417...
# Processing event 990/2417...
# Processing event 991/2417...
# Processing event 992/2417...
# Processing event 993/2417...
# Processing event 994/2417...
# Processing event 995/2417...
# Processing event 996/2417...
# Processing event 997/2417...
# Processing event 998/2417...
# Processing event 999/2417...
# Processing event 1000/2417...
# Processing event 1001/2417...
# Processing event 1002/2417...
# Processing event 1003/2417...
# Processing event 1004/2417...
# Processing event 1005/2417...
# Processing event 1006/2417...
# Processing event 1007/2417...
# Processing event 1008/2417...
# Processing event 1009/2417...
# Processing event 1010/2417...
# Processing event 1011/2417...
# Processing event 1012/2417...
# Processing event 1013/2417...
# Processing event 1014/2417...
# Processing event 1015/2417...
# Processing event 1016/2417...
# Processing event 1017/2417...
# Processing event 1018/2417...
# Processing event 1019/2417...
# Processing event 1020/2417...
# Processing event 1021/2417...
# Processing event 1022/2417...
# Processing event 1023/2417...
# Processing event 1024/2417...
# Processing event 1025/2417...
# Processing event 1026/2417...
# Processing event 1027/2417...
# Processing event 1028/2417...
# Processing event 1029/2417...
# Processing event 1030/2417...
# Processing event 1031/2417...
# Processing event 1032/2417...
# Processing event 1033/2417...
# Processing event 1034/2417...
# Processing event 1035/2417...
# Processing event 1036/2417...
# Processing event 1037/2417...
# Processing event 1038/2417...
# Processing event 1039/2417...
# Processing event 1040/2417...
# Processing event 1041/2417...
# Processing event 1042/2417...
# Processing event 1043/2417...
# Processing event 1044/2417...
# Processing event 1045/2417...
# Processing event 1046/2417...
# Processing event 1047/2417...
# Processing event 1048/2417...
# Processing event 1049/2417...
# Processing event 1050/2417...
# Processing event 1051/2417...
# Processing event 1052/2417...
# Processing event 1053/2417...
# Processing event 1054/2417...
# Processing event 1055/2417...
# Processing event 1056/2417...
# Processing event 1057/2417...
# Processing event 1058/2417...
# Processing event 1059/2417...
# Processing event 1060/2417...
# Processing event 1061/2417...
# Processing event 1062/2417...
# Processing event 1063/2417...
# Processing event 1064/2417...
# Processing event 1065/2417...
# Processing event 1066/2417...
# Processing event 1067/2417...
# Processing event 1068/2417...
# Processing event 1069/2417...
# Processing event 1070/2417...
# Processing event 1071/2417...
# Processing event 1072/2417...
# Processing event 1073/2417...
# Processing event 1074/2417...
# Processing event 1075/2417...
# Processing event 1076/2417...
# Processing event 1077/2417...
# Processing event 1078/2417...
# Processing event 1079/2417...
# Processing event 1080/2417...
# Processing event 1081/2417...
# Processing event 1082/2417...
# Processing event 1083/2417...
# Processing event 1084/2417...
# Processing event 1085/2417...
# Processing event 1086/2417...
# Processing event 1087/2417...
# Processing event 1088/2417...
# Processing event 1089/2417...
# Processing event 1090/2417...
# Processing event 1091/2417...
# Processing event 1092/2417...
# Processing event 1093/2417...
# Processing event 1094/2417...
# Processing event 1095/2417...
# Processing event 1096/2417...
# Processing event 1097/2417...
# Processing event 1098/2417...
# Processing event 1099/2417...
# Processing event 1100/2417...
# Processing event 1101/2417...
# Processing event 1102/2417...
# Processing event 1103/2417...
# Processing event 1104/2417...
# Processing event 1105/2417...
# Processing event 1106/2417...
# Processing event 1107/2417...
# Processing event 1108/2417...
# Processing event 1109/2417...
# Processing event 1110/2417...
# Processing event 1111/2417...
# Processing event 1112/2417...
# Processing event 1113/2417...
# Processing event 1114/2417...
# Processing event 1115/2417...
# Processing event 1116/2417...
# Processing event 1117/2417...
# Processing event 1118/2417...
# Processing event 1119/2417...
# Processing event 1120/2417...
# Processing event 1121/2417...
# Processing event 1122/2417...
# Processing event 1123/2417...
# Processing event 1124/2417...
# Processing event 1125/2417...
# Processing event 1126/2417...
# Processing event 1127/2417...
# Processing event 1128/2417...
# Processing event 1129/2417...
# Processing event 1130/2417...
# Processing event 1131/2417...
# Processing event 1132/2417...
# Processing event 1133/2417...
# Processing event 1134/2417...
# Processing event 1135/2417...
# Processing event 1136/2417...
# Processing event 1137/2417...
# Processing event 1138/2417...
# Processing event 1139/2417...
# Processing event 1140/2417...
# Processing event 1141/2417...
# Processing event 1142/2417...
# Processing event 1143/2417...
# Processing event 1144/2417...
# Processing event 1145/2417...
# Processing event 1146/2417...
# Processing event 1147/2417...
# Processing event 1148/2417...
# Processing event 1149/2417...
# Processing event 1150/2417...
# Processing event 1151/2417...
# Processing event 1152/2417...
# Processing event 1153/2417...
# Processing event 1154/2417...
# Processing event 1155/2417...
# Processing event 1156/2417...
# Processing event 1157/2417...
# Processing event 1158/2417...
# Processing event 1159/2417...
# Processing event 1160/2417...
# Processing event 1161/2417...
# Processing event 1162/2417...
# Processing event 1163/2417...
# Processing event 1164/2417...
# Processing event 1165/2417...
# Processing event 1166/2417...
# Processing event 1167/2417...
# Processing event 1168/2417...
# Processing event 1169/2417...
# Processing event 1170/2417...
# Processing event 1171/2417...
# Processing event 1172/2417...
# Processing event 1173/2417...
# Processing event 1174/2417...
# Processing event 1175/2417...
# Processing event 1176/2417...
# Processing event 1177/2417...
# Processing event 1178/2417...
# Processing event 1179/2417...
# Processing event 1180/2417...
# Processing event 1181/2417...
# Processing event 1182/2417...
# Processing event 1183/2417...
# Processing event 1184/2417...
# Processing event 1185/2417...
# Processing event 1186/2417...
# Processing event 1187/2417...
# Processing event 1188/2417...
# Processing event 1189/2417...
# Processing event 1190/2417...
# Processing event 1191/2417...
# Processing event 1192/2417...
# Processing event 1193/2417...
# Processing event 1194/2417...
# Processing event 1195/2417...
# Processing event 1196/2417...
# Processing event 1197/2417...
# Processing event 1198/2417...
# Processing event 1199/2417...
# Processing event 1200/2417...
# Processing event 1201/2417...
# Processing event 1202/2417...
# Processing event 1203/2417...
# Processing event 1204/2417...
# Processing event 1205/2417...
# Processing event 1206/2417...
# Processing event 1207/2417...
# Processing event 1208/2417...
# Processing event 1209/2417...
# Processing event 1210/2417...
# Processing event 1211/2417...
# Processing event 1212/2417...
# Processing event 1213/2417...
# Processing event 1214/2417...
# Processing event 1215/2417...
# Processing event 1216/2417...
# Processing event 1217/2417...
# Processing event 1218/2417...
# Processing event 1219/2417...
# Processing event 1220/2417...
# Processing event 1221/2417...
# Processing event 1222/2417...
# Processing event 1223/2417...
# Processing event 1224/2417...
# Processing event 1225/2417...
# Processing event 1226/2417...
# Processing event 1227/2417...
# Processing event 1228/2417...
# Processing event 1229/2417...
# Processing event 1230/2417...
# Processing event 1231/2417...
# Processing event 1232/2417...
# Processing event 1233/2417...
# Processing event 1234/2417...
# Processing event 1235/2417...
# Processing event 1236/2417...
# Processing event 1237/2417...
# Processing event 1238/2417...
# Processing event 1239/2417...
# Processing event 1240/2417...
# Processing event 1241/2417...
# Processing event 1242/2417...
# Processing event 1243/2417...
# Processing event 1244/2417...
# Processing event 1245/2417...
# Processing event 1246/2417...
# Processing event 1247/2417...
# Processing event 1248/2417...
# Processing event 1249/2417...
# Processing event 1250/2417...
# Processing event 1251/2417...
# Processing event 1252/2417...
# Processing event 1253/2417...
# Processing event 1254/2417...
# Processing event 1255/2417...
# Processing event 1256/2417...
# Processing event 1257/2417...
# Processing event 1258/2417...
# Processing event 1259/2417...
# Processing event 1260/2417...
# Processing event 1261/2417...
# Processing event 1262/2417...
# Processing event 1263/2417...
# Processing event 1264/2417...
# Processing event 1265/2417...
# Processing event 1266/2417...
# Processing event 1267/2417...
# Processing event 1268/2417...
# Processing event 1269/2417...
# Processing event 1270/2417...
# Processing event 1271/2417...
# Processing event 1272/2417...
# Processing event 1273/2417...
# Processing event 1274/2417...
# Processing event 1275/2417...
# Processing event 1276/2417...
# Processing event 1277/2417...
# Processing event 1278/2417...
# Processing event 1279/2417...
# Processing event 1280/2417...
# Processing event 1281/2417...
# Processing event 1282/2417...
# Processing event 1283/2417...
# Processing event 1284/2417...
# Processing event 1285/2417...
# Processing event 1286/2417...
# Processing event 1287/2417...
# Processing event 1288/2417...
# Processing event 1289/2417...
# Processing event 1290/2417...
# Processing event 1291/2417...
# Processing event 1292/2417...
# Processing event 1293/2417...
# Processing event 1294/2417...
# Processing event 1295/2417...
# Processing event 1296/2417...
# Processing event 1297/2417...
# Processing event 1298/2417...
# Processing event 1299/2417...
# Processing event 1300/2417...
# Processing event 1301/2417...
# Processing event 1302/2417...
# Processing event 1303/2417...
# Processing event 1304/2417...
# Processing event 1305/2417...
# Processing event 1306/2417...
# Processing event 1307/2417...
# Processing event 1308/2417...
# Processing event 1309/2417...
# Processing event 1310/2417...
# Processing event 1311/2417...
# Processing event 1312/2417...
# Processing event 1313/2417...
# Processing event 1314/2417...
# Processing event 1315/2417...
# Processing event 1316/2417...
# Processing event 1317/2417...
# Processing event 1318/2417...
# Processing event 1319/2417...
# Processing event 1320/2417...
# Processing event 1321/2417...
# Processing event 1322/2417...
# Processing event 1323/2417...
# Processing event 1324/2417...
# Processing event 1325/2417...
# Processing event 1326/2417...
# Processing event 1327/2417...
# Processing event 1328/2417...
# Processing event 1329/2417...
# Processing event 1330/2417...
# Processing event 1331/2417...
# Processing event 1332/2417...
# Processing event 1333/2417...
# Processing event 1334/2417...
# Processing event 1335/2417...
# Processing event 1336/2417...
# Processing event 1337/2417...
# Processing event 1338/2417...
# Processing event 1339/2417...
# Processing event 1340/2417...
# Processing event 1341/2417...
# Processing event 1342/2417...
# Processing event 1343/2417...
# Processing event 1344/2417...
# Processing event 1345/2417...
# Processing event 1346/2417...
# Processing event 1347/2417...
# Processing event 1348/2417...
# Processing event 1349/2417...
# Processing event 1350/2417...
# Processing event 1351/2417...
# Processing event 1352/2417...
# Processing event 1353/2417...
# Processing event 1354/2417...
# Processing event 1355/2417...
# Processing event 1356/2417...
# Processing event 1357/2417...
# Processing event 1358/2417...
# Processing event 1359/2417...
# Processing event 1360/2417...
# Processing event 1361/2417...
# Processing event 1362/2417...
# Processing event 1363/2417...
# Processing event 1364/2417...
# Processing event 1365/2417...
# Processing event 1366/2417...
# Processing event 1367/2417...
# Processing event 1368/2417...
# Processing event 1369/2417...
# Processing event 1370/2417...
# Processing event 1371/2417...
# Processing event 1372/2417...
# Processing event 1373/2417...
# Processing event 1374/2417...
# Processing event 1375/2417...
# Processing event 1376/2417...
# Processing event 1377/2417...
# Processing event 1378/2417...
# Processing event 1379/2417...
# Processing event 1380/2417...
# Processing event 1381/2417...
# Processing event 1382/2417...
# Processing event 1383/2417...
# Processing event 1384/2417...
# Processing event 1385/2417...
# Processing event 1386/2417...
# Processing event 1387/2417...
# Processing event 1388/2417...
# Processing event 1389/2417...
# Processing event 1390/2417...
# Processing event 1391/2417...
# Processing event 1392/2417...
# Processing event 1393/2417...
# Processing event 1394/2417...
# Processing event 1395/2417...
# Processing event 1396/2417...
# Processing event 1397/2417...
# Processing event 1398/2417...
# Processing event 1399/2417...
# Processing event 1400/2417...
# Processing event 1401/2417...
# Processing event 1402/2417...
# Processing event 1403/2417...
# Processing event 1404/2417...
# Processing event 1405/2417...
# Processing event 1406/2417...
# Processing event 1407/2417...
# Processing event 1408/2417...
# Processing event 1409/2417...
# Processing event 1410/2417...
# Processing event 1411/2417...
# Processing event 1412/2417...
# Processing event 1413/2417...
# Processing event 1414/2417...
# Processing event 1415/2417...
# Processing event 1416/2417...
# Processing event 1417/2417...
# Processing event 1418/2417...
# Processing event 1419/2417...
# Processing event 1420/2417...
# Processing event 1421/2417...
# Processing event 1422/2417...
# Processing event 1423/2417...
# Processing event 1424/2417...
# Processing event 1425/2417...
# Processing event 1426/2417...
# Processing event 1427/2417...
# Processing event 1428/2417...
# Processing event 1429/2417...
# Processing event 1430/2417...
# Processing event 1431/2417...
# Processing event 1432/2417...
# Processing event 1433/2417...
# Processing event 1434/2417...
# Processing event 1435/2417...
# Processing event 1436/2417...
# Processing event 1437/2417...
# Processing event 1438/2417...
# Processing event 1439/2417...
# Processing event 1440/2417...
# Processing event 1441/2417...
# Processing event 1442/2417...
# Processing event 1443/2417...
# Processing event 1444/2417...
# Processing event 1445/2417...
# Processing event 1446/2417...
# Processing event 1447/2417...
# Processing event 1448/2417...
# Processing event 1449/2417...
# Processing event 1450/2417...
# Processing event 1451/2417...
# Processing event 1452/2417...
# Processing event 1453/2417...
# Processing event 1454/2417...
# Processing event 1455/2417...
# Processing event 1456/2417...
# Processing event 1457/2417...
# Processing event 1458/2417...
# Processing event 1459/2417...
# Processing event 1460/2417...
# Processing event 1461/2417...
# Processing event 1462/2417...
# Processing event 1463/2417...
# Processing event 1464/2417...
# Processing event 1465/2417...
# Processing event 1466/2417...
# Processing event 1467/2417...
# Processing event 1468/2417...
# Processing event 1469/2417...
# Processing event 1470/2417...
# Processing event 1471/2417...
# Processing event 1472/2417...
# Processing event 1473/2417...
# Processing event 1474/2417...
# Processing event 1475/2417...
# Processing event 1476/2417...
# Processing event 1477/2417...
# Processing event 1478/2417...
# Processing event 1479/2417...
# Processing event 1480/2417...
# Processing event 1481/2417...
# Processing event 1482/2417...
# Processing event 1483/2417...
# Processing event 1484/2417...
# Processing event 1485/2417...
# Processing event 1486/2417...
# Processing event 1487/2417...
# Processing event 1488/2417...
# Processing event 1489/2417...
# Processing event 1490/2417...
# Processing event 1491/2417...
# Processing event 1492/2417...
# Processing event 1493/2417...
# Processing event 1494/2417...
# Processing event 1495/2417...
# Processing event 1496/2417...
# Processing event 1497/2417...
# Processing event 1498/2417...
# Processing event 1499/2417...
# Processing event 1500/2417...
# Processing event 1501/2417...
# Processing event 1502/2417...
# Processing event 1503/2417...
# Processing event 1504/2417...
# Processing event 1505/2417...
# Processing event 1506/2417...
# Processing event 1507/2417...
# Processing event 1508/2417...
# Processing event 1509/2417...
# Processing event 1510/2417...
# Processing event 1511/2417...
# Processing event 1512/2417...
# Processing event 1513/2417...
# Processing event 1514/2417...
# Processing event 1515/2417...
# Processing event 1516/2417...
# Processing event 1517/2417...
# Processing event 1518/2417...
# Processing event 1519/2417...
# Processing event 1520/2417...
# Processing event 1521/2417...
# Processing event 1522/2417...
# Processing event 1523/2417...
# Processing event 1524/2417...
# Processing event 1525/2417...
# Processing event 1526/2417...
# Processing event 1527/2417...
# Processing event 1528/2417...
# Processing event 1529/2417...
# Processing event 1530/2417...
# Processing event 1531/2417...
# Processing event 1532/2417...
# Processing event 1533/2417...
# Processing event 1534/2417...
# Processing event 1535/2417...
# Processing event 1536/2417...
# Processing event 1537/2417...
# Processing event 1538/2417...
# Processing event 1539/2417...
# Processing event 1540/2417...
# Processing event 1541/2417...
# Processing event 1542/2417...
# Processing event 1543/2417...
# Processing event 1544/2417...
# Processing event 1545/2417...
# Processing event 1546/2417...
# Processing event 1547/2417...
# Processing event 1548/2417...
# Processing event 1549/2417...
# Processing event 1550/2417...
# Processing event 1551/2417...
# Processing event 1552/2417...
# Processing event 1553/2417...
# Processing event 1554/2417...
# Processing event 1555/2417...
# Processing event 1556/2417...
# Processing event 1557/2417...
# Processing event 1558/2417...
# Processing event 1559/2417...
# Processing event 1560/2417...
# Processing event 1561/2417...
# Processing event 1562/2417...
# Processing event 1563/2417...
# Processing event 1564/2417...
# Processing event 1565/2417...
# Processing event 1566/2417...
# Processing event 1567/2417...
# Processing event 1568/2417...
# Processing event 1569/2417...
# Processing event 1570/2417...
# Processing event 1571/2417...
# Processing event 1572/2417...
# Processing event 1573/2417...
# Processing event 1574/2417...
# Processing event 1575/2417...
# Processing event 1576/2417...
# Processing event 1577/2417...
# Processing event 1578/2417...
# Processing event 1579/2417...
# Processing event 1580/2417...
# Processing event 1581/2417...
# Processing event 1582/2417...
# Processing event 1583/2417...
# Processing event 1584/2417...
# Processing event 1585/2417...
# Processing event 1586/2417...
# Processing event 1587/2417...
# Processing event 1588/2417...
# Processing event 1589/2417...
# Processing event 1590/2417...
# Processing event 1591/2417...
# Processing event 1592/2417...
# Processing event 1593/2417...
# Processing event 1594/2417...
# Processing event 1595/2417...
# Processing event 1596/2417...
# Processing event 1597/2417...
# Processing event 1598/2417...
# Processing event 1599/2417...
# Processing event 1600/2417...
# Processing event 1601/2417...
# Processing event 1602/2417...
# Processing event 1603/2417...
# Processing event 1604/2417...
# Processing event 1605/2417...
# Processing event 1606/2417...
# Processing event 1607/2417...
# Processing event 1608/2417...
# Processing event 1609/2417...
# Processing event 1610/2417...
# Processing event 1611/2417...
# Processing event 1612/2417...
# Processing event 1613/2417...
# Processing event 1614/2417...
# Processing event 1615/2417...
# Processing event 1616/2417...
# Processing event 1617/2417...
# Processing event 1618/2417...
# Processing event 1619/2417...
# Processing event 1620/2417...
# Processing event 1621/2417...
# Processing event 1622/2417...
# Processing event 1623/2417...
# Processing event 1624/2417...
# Processing event 1625/2417...
# Processing event 1626/2417...
# Processing event 1627/2417...
# Processing event 1628/2417...
# Processing event 1629/2417...
# Processing event 1630/2417...
# Processing event 1631/2417...
# Processing event 1632/2417...
# Processing event 1633/2417...
# Processing event 1634/2417...
# Processing event 1635/2417...
# Processing event 1636/2417...
# ...
# Processing event 1898/2417...
# Processing event 1899/2417...
# Processing event 1900/2417...
# Processing event 1901/2417...
# Processing event 1902/2417...
# Processing event 1903/2417...
# Processing event 1904/2417...
# Processing event 1905/2417...
# Processing event 1906/2417...
# Processing event 1907/2417...
# Processing event 1908/2417...
# Processing event 1909/2417...
# Processing event 1910/2417...
# Processing event 1911/2417...
# Processing event 1912/2417...
# Processing event 1913/2417...
# Processing event 1914/2417...
# Processing event 1915/2417...
# Processing event 1916/2417...
# Processing event 1917/2417...
# Processing event 1918/2417...
# Processing event 1919/2417...
# Processing event 1920/2417...
# Processing event 1921/2417...
# Processing event 1922/2417...
# Processing event 1923/2417...
# Processing event 1924/2417...
# Processing event 1925/2417...
# Processing event 1926/2417...
# Processing event 1927/2417...
# Processing event 1928/2417...
# Processing event 1929/2417...
# Processing event 1930/2417...
# Processing event 1931/2417...
# Processing event 1932/2417...
# Processing event 1933/2417...
# Processing event 1934/2417...
# Processing event 1935/2417...
# Processing event 1936/2417...
# Processing event 1937/2417...
# Processing event 1938/2417...
# Processing event 1939/2417...
# Processing event 1940/2417...
# Processing event 1941/2417...
# Processing event 1942/2417...
# Processing event 1943/2417...
# Processing event 1944/2417...
# Processing event 1945/2417...
# Processing event 1946/2417...
# Processing event 1947/2417...
# Processing event 1948/2417...
# Processing event 1949/2417...
# Processing event 1950/2417...
# Processing event 1951/2417...
# Processing event 1952/2417...
# Processing event 1953/2417...
# Processing event 1954/2417...
# Processing event 1955/2417...
# Processing event 1956/2417...
# Processing event 1957/2417...
# Processing event 1958/2417...
# Processing event 1959/2417...
# Processing event 1960/2417...
# Processing event 1961/2417...
# Processing event 1962/2417...
# Processing event 1963/2417...
# Processing event 1964/2417...
# Processing event 1965/2417...
# Processing event 1966/2417...
# Processing event 1967/2417...
# Processing event 1968/2417...
# Processing event 1969/2417...
# Processing event 1970/2417...
# Processing event 1971/2417...
# Processing event 1972/2417...
# Processing event 1973/2417...
# Processing event 1974/2417...
# Processing event 1975/2417...
# Processing event 1976/2417...
# Processing event 1977/2417...
# Processing event 1978/2417...
# Processing event 1979/2417...
# Processing event 1980/2417...
# Processing event 1981/2417...
# Processing event 1982/2417...
# Processing event 1983/2417...
# Processing event 1984/2417...
# Processing event 1985/2417...
# Processing event 1986/2417...
# Processing event 1987/2417...
# Processing event 1988/2417...
# Processing event 1989/2417...
# Processing event 1990/2417...
# Processing event 1991/2417...
# Processing event 1992/2417...
# Processing event 1993/2417...
# Processing event 1994/2417...
# Processing event 1995/2417...
# Processing event 1996/2417...
# Processing event 1997/2417...
# Processing event 1998/2417...
# Processing event 1999/2417...
# Processing event 2000/2417...
# Processing event 2001/2417...
# Processing event 2002/2417...
# Processing event 2003/2417...
# Processing event 2004/2417...
# Processing event 2005/2417...
# Processing event 2006/2417...
# Processing event 2007/2417...
# Processing event 2008/2417...
# Processing event 2009/2417...
# Processing event 2010/2417...
# Processing event 2011/2417...
# Processing event 2012/2417...
# Processing event 2013/2417...
# Processing event 2014/2417...
# Processing event 2015/2417...
# Processing event 2016/2417...
# Processing event 2017/2417...
# Processing event 2018/2417...
# Processing event 2019/2417...
# Processing event 2020/2417...
# Processing event 2021/2417...
# Processing event 2022/2417...
# Processing event 2023/2417...
# Processing event 2024/2417...
# Processing event 2025/2417...
# Processing event 2026/2417...
# Processing event 2027/2417...
# Processing event 2028/2417...
# Processing event 2029/2417...
# Processing event 2030/2417...
# Processing event 2031/2417...
# Processing event 2032/2417...
# Processing event 2033/2417...
# Processing event 2034/2417...
# Processing event 2035/2417...
# Processing event 2036/2417...
# Processing event 2037/2417...
# Processing event 2038/2417...
# Processing event 2039/2417...
# Processing event 2040/2417...
# Processing event 2041/2417...
# Processing event 2042/2417...
# Processing event 2043/2417...
# Processing event 2044/2417...
# Processing event 2045/2417...
# Processing event 2046/2417...
# Processing event 2047/2417...
# Processing event 2048/2417...
# Processing event 2049/2417...
# Processing event 2050/2417...
# Processing event 2051/2417...
# Processing event 2052/2417...
# Processing event 2053/2417...
# Processing event 2054/2417...
# Processing event 2055/2417...
# Processing event 2056/2417...
# Processing event 2057/2417...
# Processing event 2058/2417...
# Processing event 2059/2417...
# Processing event 2060/2417...
# Processing event 2061/2417...
# Processing event 2062/2417...
# Processing event 2063/2417...
# Processing event 2064/2417...
# Processing event 2065/2417...
# Processing event 2066/2417...
# Processing event 2067/2417...
# Processing event 2068/2417...
# Processing event 2069/2417...
# Processing event 2070/2417...
# Processing event 2071/2417...
# Processing event 2072/2417...
# Processing event 2073/2417...
# Processing event 2074/2417...
# Processing event 2075/2417...
# Processing event 2076/2417...
# Processing event 2077/2417...
# Processing event 2078/2417...
# Processing event 2079/2417...
# Processing event 2080/2417...
# Processing event 2081/2417...
# Processing event 2082/2417...
# Processing event 2083/2417...
# Processing event 2084/2417...
# Processing event 2085/2417...
# Processing event 2086/2417...
# Processing event 2087/2417...
# Processing event 2088/2417...
# Processing event 2089/2417...
# Processing event 2090/2417...
# Processing event 2091/2417...
# Processing event 2092/2417...
# Processing event 2093/2417...
# Processing event 2094/2417...
# Processing event 2095/2417...
# Processing event 2096/2417...
# Processing event 2097/2417...
# Processing event 2098/2417...
# Processing event 2099/2417...
# Processing event 2100/2417...
# Processing event 2101/2417...
# Processing event 2102/2417...
# Processing event 2103/2417...
# Processing event 2104/2417...
# Processing event 2105/2417...
# Processing event 2106/2417...
# Processing event 2107/2417...
# Processing event 2108/2417...
# Processing event 2109/2417...
# Processing event 2110/2417...
# Processing event 2111/2417...
# Processing event 2112/2417...
# Processing event 2113/2417...
# Processing event 2114/2417...
# Processing event 2115/2417...
# Processing event 2116/2417...
# Processing event 2117/2417...
# Processing event 2118/2417...
# Processing event 2119/2417...
# Processing event 2120/2417...
# Processing event 2121/2417...
# Processing event 2122/2417...
# Processing event 2123/2417...
# Processing event 2124/2417...
# Processing event 2125/2417...
# Processing event 2126/2417...
# Processing event 2127/2417...
# Processing event 2128/2417...
# Processing event 2129/2417...
# Processing event 2130/2417...
# Processing event 2131/2417...
# Processing event 2132/2417...
# Processing event 2133/2417...
# Processing event 2134/2417...
# Processing event 2135/2417...
# Processing event 2136/2417...
# Processing event 2137/2417...
# Processing event 2138/2417...
# Processing event 2139/2417...
# Processing event 2140/2417...
# Processing event 2141/2417...
# Processing event 2142/2417...
# Processing event 2143/2417...
# Processing event 2144/2417...
# Processing event 2145/2417...
# Processing event 2146/2417...
# Processing event 2147/2417...
# Processing event 2148/2417...
# Processing event 2149/2417...
# Processing event 2150/2417...
# Processing event 2151/2417...
# Processing event 2152/2417...
# Processing event 2153/2417...
# Processing event 2154/2417...
# Processing event 2155/2417...
# Processing event 2156/2417...
# Processing event 2157/2417...
# Processing event 2158/2417...
# Processing event 2159/2417...
# Processing event 2160/2417...
# Processing event 2161/2417...
# Processing event 2162/2417...
# Processing event 2163/2417...
# Processing event 2164/2417...
# Processing event 2165/2417...
# Processing event 2166/2417...
# Processing event 2167/2417...
# Processing event 2168/2417...
# Processing event 2169/2417...
# Processing event 2170/2417...
# Processing event 2171/2417...
# Processing event 2172/2417...
# Processing event 2173/2417...
# Processing event 2174/2417...
# Processing event 2175/2417...
# Processing event 2176/2417...
# Processing event 2177/2417...
# Processing event 2178/2417...
# Processing event 2179/2417...
# Processing event 2180/2417...
# Processing event 2181/2417...
# Processing event 2182/2417...
# Processing event 2183/2417...
# Processing event 2184/2417...
# Processing event 2185/2417...
# Processing event 2186/2417...
# Processing event 2187/2417...
# Processing event 2188/2417...
# Processing event 2189/2417...
# Processing event 2190/2417...
# Processing event 2191/2417...
# Processing event 2192/2417...
# Processing event 2193/2417...
# Processing event 2194/2417...
# Processing event 2195/2417...
# Processing event 2196/2417...
# Processing event 2197/2417...
# Processing event 2198/2417...
# Processing event 2199/2417...
# Processing event 2200/2417...
# Processing event 2201/2417...
# Processing event 2202/2417...
# Processing event 2203/2417...
# Processing event 2204/2417...
# Processing event 2205/2417...
# Processing event 2206/2417...
# Processing event 2207/2417...
# Processing event 2208/2417...
# Processing event 2209/2417...
# Processing event 2210/2417...
# Processing event 2211/2417...
# Processing event 2212/2417...
# Processing event 2213/2417...
# Processing event 2214/2417...
# Processing event 2215/2417...
# Processing event 2216/2417...
# Processing event 2217/2417...
# Processing event 2218/2417...
# Processing event 2219/2417...
# Processing event 2220/2417...
# Processing event 2221/2417...
# Processing event 2222/2417...
# Processing event 2223/2417...
# Processing event 2224/2417...
# Processing event 2225/2417...
# Processing event 2226/2417...
# Processing event 2227/2417...
# Processing event 2228/2417...
# Processing event 2229/2417...
# Processing event 2230/2417...
# Processing event 2231/2417...
# Processing event 2232/2417...
# Processing event 2233/2417...
# Processing event 2234/2417...
# Processing event 2235/2417...
# Processing event 2236/2417...
# Processing event 2237/2417...
# Processing event 2238/2417...
# Processing event 2239/2417...
# Processing event 2240/2417...
# Processing event 2241/2417...
# Processing event 2242/2417...
# Processing event 2243/2417...
# Processing event 2244/2417...
# Processing event 2245/2417...
# Processing event 2246/2417...
# Processing event 2247/2417...
# Processing event 2248/2417...
# Processing event 2249/2417...
# Processing event 2250/2417...
# Processing event 2251/2417...
# Processing event 2252/2417...
# Processing event 2253/2417...
# Processing event 2254/2417...
# Processing event 2255/2417...
# Processing event 2256/2417...
# Processing event 2257/2417...
# Processing event 2258/2417...
# Processing event 2259/2417...
# Processing event 2260/2417...
# Processing event 2261/2417...
# Processing event 2262/2417...
# Processing event 2263/2417...
# Processing event 2264/2417...
# Processing event 2265/2417...
# Processing event 2266/2417...
# Processing event 2267/2417...
# Processing event 2268/2417...
# Processing event 2269/2417...
# Processing event 2270/2417...
# Processing event 2271/2417...
# Processing event 2272/2417...
# Processing event 2273/2417...
# Processing event 2274/2417...
# Processing event 2275/2417...
# Processing event 2276/2417...
# Processing event 2277/2417...
# Processing event 2278/2417...
# Processing event 2279/2417...
# Processing event 2280/2417...
# Processing event 2281/2417...
# Processing event 2282/2417...
# Processing event 2283/2417...
# Processing event 2284/2417...
# Processing event 2285/2417...
# Processing event 2286/2417...
# Processing event 2287/2417...
# Processing event 2288/2417...
# Processing event 2289/2417...
# Processing event 2290/2417...
# Processing event 2291/2417...
# Processing event 2292/2417...
# Processing event 2293/2417...
# Processing event 2294/2417...
# Processing event 2295/2417...
# Processing event 2296/2417...
# Processing event 2297/2417...
# Processing event 2298/2417...
# Processing event 2299/2417...
# Processing event 2300/2417...
# Processing event 2301/2417...
# Processing event 2302/2417...
# Processing event 2303/2417...
# Processing event 2304/2417...
# Processing event 2305/2417...
# Processing event 2306/2417...
# Processing event 2307/2417...
# Processing event 2308/2417...
# Processing event 2309/2417...
# Processing event 2310/2417...
# Processing event 2311/2417...
# Processing event 2312/2417...
# Processing event 2313/2417...
# Processing event 2314/2417...
# Processing event 2315/2417...
# Processing event 2316/2417...
# Processing event 2317/2417...
# Processing event 2318/2417...
# Processing event 2319/2417...
# Processing event 2320/2417...
# Processing event 2321/2417...
# Processing event 2322/2417...
# Processing event 2323/2417...
# Processing event 2324/2417...
# Processing event 2325/2417...
# Processing event 2326/2417...
# Processing event 2327/2417...
# Processing event 2328/2417...
# Processing event 2329/2417...
# Processing event 2330/2417...
# Processing event 2331/2417...
# Processing event 2332/2417...
# Processing event 2333/2417...
# Processing event 2334/2417...
# Processing event 2335/2417...
# Processing event 2336/2417...
# Processing event 2337/2417...
# Processing event 2338/2417...
# Processing event 2339/2417...
# Processing event 2340/2417...
# Processing event 2341/2417...
# Processing event 2342/2417...
# Processing event 2343/2417...
# Processing event 2344/2417...
# Processing event 2345/2417...
# Processing event 2346/2417...
# Processing event 2347/2417...
# Processing event 2348/2417...
# Processing event 2349/2417...
# Processing event 2350/2417...
# Processing event 2351/2417...
# Processing event 2352/2417...
# Processing event 2353/2417...
# Processing event 2354/2417...
# Processing event 2355/2417...
# Processing event 2356/2417...
# Processing event 2357/2417...
# Processing event 2358/2417...
# Processing event 2359/2417...
# Processing event 2360/2417...
# Processing event 2361/2417...
# Processing event 2362/2417...
# Processing event 2363/2417...
# Processing event 2364/2417...
# Processing event 2365/2417...
# Processing event 2366/2417...
# Processing event 2367/2417...
# Processing event 2368/2417...
# Processing event 2369/2417...
# Processing event 2370/2417...
# Processing event 2371/2417...
# Processing event 2372/2417...
# Processing event 2373/2417...
# Processing event 2374/2417...
# Processing event 2375/2417...
# Processing event 2376/2417...
# Processing event 2377/2417...
# Processing event 2378/2417...
# Processing event 2379/2417...
# Processing event 2380/2417...
# Processing event 2381/2417...
# Processing event 2382/2417...
# Processing event 2383/2417...
# Processing event 2384/2417...
# Processing event 2385/2417...
# Processing event 2386/2417...
# Processing event 2387/2417...
# Processing event 2388/2417...
# Processing event 2389/2417...
# Processing event 2390/2417...
# Processing event 2391/2417...
# Processing event 2392/2417...
# Processing event 2393/2417...
# Processing event 2394/2417...
# Processing event 2395/2417...
# Processing event 2396/2417...
# Processing event 2397/2417...
# Processing event 2398/2417...
# Processing event 2399/2417...
# Processing event 2400/2417...
# Processing event 2401/2417...
# Processing event 2402/2417...
# Processing event 2403/2417...
# Processing event 2404/2417...
# Processing event 2405/2417...
# Processing event 2406/2417...
# Processing event 2407/2417...
# Processing event 2408/2417...
# Processing event 2409/2417...
# Processing event 2410/2417...
# Processing event 2411/2417...
# Processing event 2412/2417...
# Processing event 2413/2417...
# Processing event 2414/2417...
# Processing event 2415/2417...
# Processing event 2416/2417...
# Processing event 2417/2417...
# Predictions for all events shape: (2417,)
# /tmp/ipykernel_3798780/2618382674.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   all_predictions = np.array(all_predictions)

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import time

# Initialize lists to store cluster labels and clustering times
all_cluster_labels = []       # List to store cluster labels for all events
all_clustering_times = []     # List to store time taken for clustering each event

# Parameters for Agglomerative Clustering
distance_threshold = 0.9  # Adjust this value based on your data
linkage = 'average'           # Linkage criteria: 'ward', 'complete', 'average', 'single'
metric = 'cosine'             # Distance metric: 'cosine', 'euclidean', etc.
compute_distances = True      # Whether to compute distances between clusters

# Total number of events (for progress tracking)
total_events = len(all_predictions)

# Loop through all events in all_predictions
for i, pred in enumerate(all_predictions):
    #print(f"Processing event {i+1}/{total_events}...")
    
    # Check if there are less than 2 samples (nodes)
    if len(pred) < 2:
        cluster_labels = np.ones(len(pred), dtype=int)  # Assign all nodes to cluster 1
    else:
        # Initialize AgglomerativeClustering with specified parameters
        agglomerative = AgglomerativeClustering(
            n_clusters=None,                  # Let the algorithm determine the number of clusters
            distance_threshold=distance_threshold,
            linkage=linkage,
            metric=metric,
            compute_distances=compute_distances
        )
        
        # Record the start time
        start_time = time.time()
        
        # Perform clustering
        cluster_labels = agglomerative.fit_predict(pred)  # pred = predictions for this event
        
        # Record the end time
        end_time = time.time()
        
        # Calculate the time taken for clustering
        clustering_time = end_time - start_time
        all_clustering_times.append(clustering_time)
    
    # Append the cluster labels to the list
    all_cluster_labels.append(cluster_labels)

# Convert the list of cluster labels and times to NumPy arrays
all_cluster_labels = np.array(all_cluster_labels)
all_clustering_times = np.array(all_clustering_times)

# Print results
print("\nClustering Results:")
print("Shape of all_cluster_labels:", all_cluster_labels.shape)
print("Cluster labels for first event:", all_cluster_labels[0])

# Print timing information
total_time = all_clustering_times.sum()
average_time = all_clustering_times.mean()
print(f"\nTotal clustering time: {total_time:.2f} seconds")
print(f"Average clustering time per event: {average_time:.4f} seconds")






# Initialize recon_ind as an empty list
recon_ind = []

# Loop through each event
for event_idx, labels in enumerate(all_cluster_labels):
    event_clusters = {}  # Dictionary to store clusters for this event
    
    # Loop through each cluster label and corresponding track indices
    for cluster_idx, cluster_label in enumerate(labels):
        if cluster_label not in event_clusters:
            event_clusters[cluster_label] = []
        event_clusters[cluster_label].extend(Track_ind[event_idx][cluster_idx])
    
    # Append the clusters for this event as a list
    recon_ind.append([event_clusters[label] for label in sorted(event_clusters.keys())])

df_scores = calculate_all_event_scores(GT_ind, energies, recon_ind, LC_x, LC_y, LC_z, LC_eta)

import pandas as pd

# Ensure 'cp_id' and 'trackster_id' are numeric for both dataframes
df_scores['cp_id'] = pd.to_numeric(df_scores['cp_id'], errors='coerce')
df_scores['trackster_id'] = pd.to_numeric(df_scores['trackster_id'], errors='coerce')

df_CERN['cp_id'] = pd.to_numeric(df_CERN['cp_id'], errors='coerce')
df_CERN['trackster_id'] = pd.to_numeric(df_CERN['trackster_id'], errors='coerce')

# Define a function to calculate efficiency and purity
def calculate_efficiency_purity(df, model_name):
    # ----- Efficiency Calculation -----
    cp_valid = df.dropna(subset=['cp_id']).copy()
    cp_grouped = cp_valid.groupby(['event_index', 'cp_id'])
    cp_associated = cp_grouped['sim_to_reco_score'].min() < 0.2
    num_associated_cp = cp_associated.sum()
    total_cp = cp_associated.count()
    efficiency = num_associated_cp / total_cp if total_cp > 0 else 0

    # ----- Purity Calculation -----
    tst_valid = df.dropna(subset=['trackster_id']).copy()
    tst_grouped = tst_valid.groupby(['event_index', 'trackster_id'])
    tst_associated = tst_grouped['reco_to_sim_score'].min() < 0.2
    num_associated_tst = tst_associated.sum()
    total_tst = tst_associated.count()
    purity = num_associated_tst / total_tst if total_tst > 0 else 0

    # Print results for the model
    print(f"\nModel: {model_name}")
    print(f"Efficiency: {efficiency:.4f} ({num_associated_cp} associated CPs out of {total_cp} total CPs)")
    print(f"Purity: {purity:.4f} ({num_associated_tst} associated Tracksters out of {total_tst} total Tracksters)")
    return cp_valid, tst_valid
# Calculate for both models
cp_valid, tst_valid = calculate_efficiency_purity(df_scores, "Your Model")

calculate_efficiency_purity(df_CERN, "CERN Model")
# Out:
# /tmp/ipykernel_3798780/3206664821.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   all_cluster_labels = np.array(all_cluster_labels)
# Clustering Results:
# Shape of all_cluster_labels: (2417,)
# Cluster labels for first event: [1 0 0 1 0]
#
# Total clustering time: 0.75 seconds
# Average clustering time per event: 0.0003 seconds
# Processing events: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:23<00:00,  4.18it/s]
# Model: Your Model
# Efficiency: 0.6012 (202 associated CPs out of 336 total CPs)
# Purity: 0.9336 (197 associated Tracksters out of 211 total Tracksters)
#
# Model: CERN Model
# Efficiency: 0.4970 (167 associated CPs out of 336 total CPs)
# Purity: 1.0000 (272 associated Tracksters out of 272 total Tracksters)
# (     event_index  cp_id  trackster_id  sim_to_reco_score  reco_to_sim_score  \
#  0              0      0             0           0.319894           0.000007
#  1              0      0             1           0.680377           0.695091
#  2              0      1             0           0.854300           0.739486
#  3              0      1             1           0.146175           0.009501
#  4              0      2             0           0.866275           0.767160
#  ..           ...    ...           ...                ...                ...
#  991           98      4             6           1.000000           1.000000
#  992           99      0             0           0.947598           0.846471
#  993           99      0             1           0.053017           0.000000
#  994           99      1             0           0.194285           0.000000
#  995           99      1             1           0.806001           0.913218
#
#        cp_energy  trackster_energy  cp_avg_eta  cp_separation  \
#  0    266.785935        160.097883    2.303661       9.755692
#  1    266.785935        287.679577    2.303661       9.755692
#  2    335.722561        160.097883    2.179889       9.755692
#  3    335.722561        287.679577    2.179889       9.755692
#  4    311.218829        160.097883    2.137275       9.755692
#  ..          ...               ...         ...            ...
#  991  161.718032          1.349367    2.646266      22.115351
#  992  155.037995         73.936569    2.156460      14.181144
#  993  155.037995        135.953619    2.156460      14.181144
#  994   88.304708         73.936569    2.095085      14.181144
#  995   88.304708        135.953619    2.095085      14.181144
#
#       energy_diff_ratio
#  0            -0.399901
#  1             0.078316
#  2            -0.523124
#  3            -0.143103
#  4            -0.485578
#  ..                 ...
#  991          -0.991656
#  992          -0.523107
#  993          -0.123095
#  994          -0.162711
#  995           0.539596
#
#  [996 rows x 10 columns],
#       event_index  cp_id  trackster_id  sim_to_reco_score  reco_to_sim_score  \
#  0              0      0             0           0.319894           0.000007
#  1              0      0             1           0.680377           0.695091
#  2              0      1             0           0.854300           0.739486
#  3              0      1             1           0.146175           0.009501
#  4              0      2             0           0.866275           0.767160
#  ..           ...    ...           ...                ...                ...
#  991           98      4             6           1.000000           1.000000
#  992           99      0             0           0.947598           0.846471
#  993           99      0             1           0.053017           0.000000
#  994           99      1             0           0.194285           0.000000
#  995           99      1             1           0.806001           0.913218
#
#        cp_energy  trackster_energy  cp_avg_eta  cp_separation  \
#  0    266.785935        160.097883    2.303661       9.755692
#  1    266.785935        287.679577    2.303661       9.755692
#  2    335.722561        160.097883    2.179889       9.755692
#  3    335.722561        287.679577    2.179889       9.755692
#  4    311.218829        160.097883    2.137275       9.755692
#  ..          ...               ...         ...            ...
#  991  161.718032          1.349367    2.646266      22.115351
#  992  155.037995         73.936569    2.156460      14.181144
#  993  155.037995        135.953619    2.156460      14.181144
#  994   88.304708         73.936569    2.095085      14.181144
#  995   88.304708        135.953619    2.095085      14.181144
#
#       energy_diff_ratio
#  0            -0.399901
#  1             0.078316
#  2            -0.523124
#  3            -0.143103
#  4            -0.485578
#  ..                 ...
#  991          -0.991656
#  992          -0.523107
#  993          -0.123095
#  994          -0.162711
#  995           0.539596
#
#  [996 rows x 10 columns])

# %% [markdown]
# # Score Calculations

# %%
# Initialize recon_ind as an empty list
recon_ind = []

# Loop through each event
for event_idx, labels in enumerate(all_cluster_labels):
    event_clusters = {}  # Dictionary to store clusters for this event
    
    # Loop through each cluster label and corresponding track indices
    for cluster_idx, cluster_label in enumerate(labels):
        if cluster_label not in event_clusters:
            event_clusters[cluster_label] = []
        event_clusters[cluster_label].extend(Track_ind[event_idx][cluster_idx])
    
    # Append the clusters for this event as a list
    recon_ind.append([event_clusters[label] for label in sorted(event_clusters.keys())])

# %%
def calculate_sim_to_reco_score(CaloParticle, energies_indices, ReconstructedTrackster):
    """
    Calculate the sim-to-reco score for a given CaloParticle and ReconstructedTrackster.
    
    Parameters:
    - CaloParticle: array of DetIds in the CaloParticle.
    - energies_indices: array of energies associated with all DetIds (indexed by DetId).
    - ReconstructedTrackster: array of DetIds in the reconstructed Trackster.
    
    Returns:
    - sim_to_reco_score: the calculated sim-to-reco score.
    """
    numerator = 0.0
    denominator = 0.0

    # Calculate total energy of the CaloParticle
    total_energy_caloparticle = sum(energies_indices[det_id] for det_id in CaloParticle)
    if total_energy_caloparticle == 0:
        return 1.0  # No energy in the CaloParticle implies perfect mismatch

    # Calculate total energy of the ReconstructedTrackster
    total_energy_trackster = sum(energies_indices[det_id] for det_id in ReconstructedTrackster)

    # Iterate over all DetIds in the CaloParticle
    for det_id in CaloParticle:
        energy_k = energies_indices[det_id]  # Energy for the current DetId in CaloParticle

        # Fraction of energy in the Trackster (fr_k^TST)
        fr_tst_k = 1 if det_id in ReconstructedTrackster else 0.0

        # Fraction of energy in the CaloParticle (fr_k^SC)
        fr_sc_k = 1

        # Update numerator using the min function
        numerator += min(
            (fr_tst_k - fr_sc_k) ** 2,  # First term in the min function
            fr_sc_k ** 2                # Second term in the min function
        ) * (energy_k ** 2)

        # Update denominator
        denominator += (fr_sc_k ** 2) * (energy_k ** 2)

    # Calculate score
    sim_to_reco_score = numerator / denominator if denominator != 0 else 1.0
    return sim_to_reco_score

def calculate_reco_to_sim_score(ReconstructedTrackster, energies_indices, CaloParticle):
    """
    Calculate the reco-to-sim score for a given ReconstructedTrackster and CaloParticle.

    Parameters:
    - ReconstructedTrackster: array of DetIds in the ReconstructedTrackster.
    - energies_indices: array of energies associated with all DetIds (indexed by DetId).
    - CaloParticle: array of DetIds in the CaloParticle.

    Returns:
    - reco_to_sim_score: the calculated reco-to-sim score.
    """
    numerator = 0.0
    denominator = 0.0

    # Calculate total energy of the ReconstructedTrackster
    total_energy_trackster = sum(energies_indices[det_id] for det_id in ReconstructedTrackster)
    if total_energy_trackster == 0:
        return 1.0  # No energy in the Trackster implies perfect mismatch

    # Calculate total energy of the CaloParticle
    total_energy_caloparticle = sum(energies_indices[det_id] for det_id in CaloParticle)

    # Iterate over all DetIds in the ReconstructedTrackster
    for det_id in ReconstructedTrackster:
        energy_k = energies_indices[det_id]  # Energy for the current DetId in the Trackster

        # Fraction of energy in the Trackster (fr_k^TST)
        fr_tst_k = 1

        # Fraction of energy in the CaloParticle (fr_k^MC)
        fr_sc_k = 1 if det_id in CaloParticle else 0.0

        # Update numerator using the min function
        numerator += min(
            (fr_tst_k - fr_sc_k) ** 2,  # First term in the min function
            fr_tst_k ** 2               # Second term in the min function
        ) * (energy_k ** 2)

        # Update denominator
        denominator += (fr_tst_k ** 2) * (energy_k ** 2)

    # Calculate score
    reco_to_sim_score = numerator / denominator if denominator != 0 else 1.0
    return reco_to_sim_score

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm


def calculate_all_event_scores(GT_ind, energies, recon_ind, LC_x, LC_y, LC_z, LC_eta):
    """
    Calculate sim-to-reco and reco-to-sim scores for all CaloParticle and ReconstructedTrackster combinations across all events.

    Parameters:
    - GT_ind: List of CaloParticle indices for all events.
    - energies: List of energy arrays for all events.
    - recon_ind: List of ReconstructedTrackster indices for all events.
    - LC_x, LC_y, LC_z, LC_eta: Lists of x, y, z positions and eta values for all DetIds across events.

    Returns:
    - DataFrame containing scores and additional features for each CaloParticle-Trackster combination across all events.
    """
    # Initialize an empty list to store results
    all_results = []

    # Loop over all events with a progress bar
    for event_index in tqdm(range(100), desc="Processing events"):
        caloparticles = GT_ind[event_index]  # Indices for all CaloParticles in the event
        tracksters = recon_ind[event_index]  # Indices for all ReconstructedTracksters in the event
        event_energies = energies[event_index]  # Energies for this event

        # Extract layer cluster positions and eta for this event
        event_x = np.array(LC_x[event_index])
        event_y = np.array(LC_y[event_index])
        event_z = np.array(LC_z[event_index])
        event_eta = np.array(LC_eta[event_index])

        # Compute barycenter for each CaloParticle
        cp_barycenters = []
        cp_avg_etas = []
        for caloparticle in caloparticles:
            # Compute barycenter (x, y, z)
            barycenter_x = np.mean([event_x[det_id] for det_id in caloparticle])
            barycenter_y = np.mean([event_y[det_id] for det_id in caloparticle])
            barycenter_z = np.mean([event_z[det_id] for det_id in caloparticle])
            cp_barycenters.append(np.array([barycenter_x, barycenter_y, barycenter_z]))
            
            # Compute average eta
            avg_eta = np.mean([event_eta[det_id] for det_id in caloparticle])
            cp_avg_etas.append(avg_eta)

        # Compute separation between two CaloParticles if at least two exist
        if len(cp_barycenters) >= 2:
            cp_separation = np.linalg.norm(cp_barycenters[0] - cp_barycenters[1])
        else:
            cp_separation = 0.0

        # Loop over all CaloParticles
        for calo_idx, caloparticle in enumerate(caloparticles):
            # Loop over all Tracksters
            for trackster_idx, trackster in enumerate(tracksters):
                # Calculate sim-to-reco score
                sim_to_reco_score = calculate_sim_to_reco_score(caloparticle, event_energies, trackster)
                # Calculate reco-to-sim score
                reco_to_sim_score = calculate_reco_to_sim_score(trackster, event_energies, caloparticle)

                # Calculate total energy for CaloParticle and Trackster
                cp_energy = np.sum([event_energies[det_id] for det_id in caloparticle])
                trackster_energy = np.sum([event_energies[det_id] for det_id in trackster])

                # Calculate energy difference ratio
                energy_diff_ratio = (trackster_energy - cp_energy) / cp_energy if cp_energy != 0 else None

                # Append results
                all_results.append({
                    "event_index": event_index,
                    "cp_id": calo_idx,
                    "trackster_id": trackster_idx,
                    "sim_to_reco_score": sim_to_reco_score,
                    "reco_to_sim_score": reco_to_sim_score,
                    "cp_energy": cp_energy,
                    "trackster_energy": trackster_energy,
                    "cp_avg_eta": cp_avg_etas[calo_idx],
                    "cp_separation": cp_separation,
                    "energy_diff_ratio": energy_diff_ratio
                })

    # Convert results to a DataFrame
    df = pd.DataFrame(all_results)
    return df

# %%
df_scores = calculate_all_event_scores(GT_ind, energies, recon_ind, LC_x, LC_y, LC_z, LC_eta)
df_CERN = calculate_all_event_scores(GT_ind, energies, MT_ind, LC_x, LC_y, LC_z, LC_eta)
# Out:
# Processing events: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:31<00:00,  3.20it/s]
# Processing events: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:41<00:00,  2.41it/s]

# %%
# Assuming 'df' is your dataframe
max_sim_to_reco_score = df_scores['sim_to_reco_score'].max()
max_reco_to_sim_score = df_scores['reco_to_sim_score'].max()

print("Maximum sim-to-reco score:", max_sim_to_reco_score)
print("Maximum reco-to-sim score:", max_reco_to_sim_score)
# Out:
# Maximum sim-to-reco score: 1.0
# Maximum reco-to-sim score: 1.0

# %% [markdown]
# # Purity + Efficiency

# %%
import pandas as pd

# Ensure 'cp_id' and 'trackster_id' are numeric for both dataframes
df_scores['cp_id'] = pd.to_numeric(df_scores['cp_id'], errors='coerce')
df_scores['trackster_id'] = pd.to_numeric(df_scores['trackster_id'], errors='coerce')

df_CERN['cp_id'] = pd.to_numeric(df_CERN['cp_id'], errors='coerce')
df_CERN['trackster_id'] = pd.to_numeric(df_CERN['trackster_id'], errors='coerce')

# Define a function to calculate efficiency and purity
def calculate_efficiency_purity(df, model_name):
    # ----- Efficiency Calculation -----
    cp_valid = df.dropna(subset=['cp_id']).copy()
    cp_grouped = cp_valid.groupby(['event_index', 'cp_id'])
    cp_associated = cp_grouped['sim_to_reco_score'].min() < 0.2
    num_associated_cp = cp_associated.sum()
    total_cp = cp_associated.count()
    efficiency = num_associated_cp / total_cp if total_cp > 0 else 0

    # ----- Purity Calculation -----
    tst_valid = df.dropna(subset=['trackster_id']).copy()
    tst_grouped = tst_valid.groupby(['event_index', 'trackster_id'])
    tst_associated = tst_grouped['reco_to_sim_score'].min() < 0.2
    num_associated_tst = tst_associated.sum()
    total_tst = tst_associated.count()
    purity = num_associated_tst / total_tst if total_tst > 0 else 0

    # Print results for the model
    print(f"\nModel: {model_name}")
    print(f"Efficiency: {efficiency:.4f} ({num_associated_cp} associated CPs out of {total_cp} total CPs)")
    print(f"Purity: {purity:.4f} ({num_associated_tst} associated Tracksters out of {total_tst} total Tracksters)")
    return cp_valid, tst_valid
# Calculate for both models
cp_valid, tst_valid = calculate_efficiency_purity(df_scores, "Your Model")

calculate_efficiency_purity(df_CERN, "CERN Model")
# Out:
# Model: Your Model
# Efficiency: 0.4940 (166 associated CPs out of 336 total CPs)
# Purity: 0.9559 (282 associated Tracksters out of 295 total Tracksters)
#
# Model: CERN Model
# Efficiency: 0.4970 (167 associated CPs out of 336 total CPs)
# Purity: 1.0000 (272 associated Tracksters out of 272 total Tracksters)
# (     event_index  cp_id  trackster_id  sim_to_reco_score  reco_to_sim_score  \
#  0              0      0             0           0.319894           0.000007
#  1              0      0             1           0.680377           0.695091
#  2              0      1             0           0.854300           0.739486
#  3              0      1             1           0.146175           0.009501
#  4              0      2             0           0.866275           0.767160
#  ..           ...    ...           ...                ...                ...
#  991           98      4             6           1.000000           1.000000
#  992           99      0             0           0.947598           0.846471
#  993           99      0             1           0.053017           0.000000
#  994           99      1             0           0.194285           0.000000
#  995           99      1             1           0.806001           0.913218
#
#        cp_energy  trackster_energy  cp_avg_eta  cp_separation  \
#  0    266.785935        160.097883    2.303661       9.755692
#  1    266.785935        287.679577    2.303661       9.755692
#  2    335.722561        160.097883    2.179889       9.755692
#  3    335.722561        287.679577    2.179889       9.755692
#  4    311.218829        160.097883    2.137275       9.755692
#  ..          ...               ...         ...            ...
#  991  161.718032          1.349367    2.646266      22.115351
#  992  155.037995         73.936569    2.156460      14.181144
#  993  155.037995        135.953619    2.156460      14.181144
#  994   88.304708         73.936569    2.095085      14.181144
#  995   88.304708        135.953619    2.095085      14.181144
#
#       energy_diff_ratio
#  0            -0.399901
#  1             0.078316
#  2            -0.523124
#  3            -0.143103
#  4            -0.485578
#  ..                 ...
#  991          -0.991656
#  992          -0.523107
#  993          -0.123095
#  994          -0.162711
#  995           0.539596
#
#  [996 rows x 10 columns],
#       event_index  cp_id  trackster_id  sim_to_reco_score  reco_to_sim_score  \
#  0              0      0             0           0.319894           0.000007
#  1              0      0             1           0.680377           0.695091
#  2              0      1             0           0.854300           0.739486
#  3              0      1             1           0.146175           0.009501
#  4              0      2             0           0.866275           0.767160
#  ..           ...    ...           ...                ...                ...
#  991           98      4             6           1.000000           1.000000
#  992           99      0             0           0.947598           0.846471
#  993           99      0             1           0.053017           0.000000
#  994           99      1             0           0.194285           0.000000
#  995           99      1             1           0.806001           0.913218
#
#        cp_energy  trackster_energy  cp_avg_eta  cp_separation  \
#  0    266.785935        160.097883    2.303661       9.755692
#  1    266.785935        287.679577    2.303661       9.755692
#  2    335.722561        160.097883    2.179889       9.755692
#  3    335.722561        287.679577    2.179889       9.755692
#  4    311.218829        160.097883    2.137275       9.755692
#  ..          ...               ...         ...            ...
#  991  161.718032          1.349367    2.646266      22.115351
#  992  155.037995         73.936569    2.156460      14.181144
#  993  155.037995        135.953619    2.156460      14.181144
#  994   88.304708         73.936569    2.095085      14.181144
#  995   88.304708        135.953619    2.095085      14.181144
#
#       energy_diff_ratio
#  0            -0.399901
#  1             0.078316
#  2            -0.523124
#  3            -0.143103
#  4            -0.485578
#  ..                 ...
#  991          -0.991656
#  992          -0.523107
#  993          -0.123095
#  994          -0.162711
#  995           0.539596
#
#  [996 rows x 10 columns])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ----- Plotting Sim-to-Reco Score Distribution -----
plt.figure(figsize=(10, 6))
sns.histplot(df_scores['sim_to_reco_score'], bins=20, label='Your Model', color='blue')
sns.histplot(df_CERN['sim_to_reco_score'], bins=20, label='CERN Model', color='red')
plt.title('Distribution of Sim-to-Reco Scores')
plt.xlabel('Sim-to-Reco Score')
plt.ylabel('Frequency')

plt.legend()
plt.show()

# ----- Plotting Reco-to-Sim Score Distribution -----
plt.figure(figsize=(10, 6))
sns.histplot(df_scores['reco_to_sim_score'], bins=20, label='Your Model', color='blue')
sns.histplot(df_CERN['reco_to_sim_score'], bins=20, label='CERN Model', color='red')
plt.title('Distribution of Reco-to-Sim Scores')
plt.xlabel('Reco-to-Sim Score')
plt.ylabel('Frequency')

plt.legend()
plt.show()

# %%
# Assuming 'df' is your dataframe
max_sim_to_reco_score = df_CERN['sim_to_reco_score'].max()
max_reco_to_sim_score = df_CERN['reco_to_sim_score'].max()

print("Maximum sim-to-reco score:", max_sim_to_reco_score)
print("Maximum reco-to-sim score:", max_reco_to_sim_score)
# Out:
# Maximum sim-to-reco score: 1.0
# Maximum reco-to-sim score: 1.0

# %% [markdown]
# # Plot vs params

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ---- Preprocessing ----
df_scores['cp_id'] = pd.to_numeric(df_scores['cp_id'], errors='coerce')
df_scores['trackster_id'] = pd.to_numeric(df_scores['trackster_id'], errors='coerce')

df_CERN['cp_id'] = pd.to_numeric(df_CERN['cp_id'], errors='coerce')
df_CERN['trackster_id'] = pd.to_numeric(df_CERN['trackster_id'], errors='coerce')

# Map Required Columns from df_scores to df_CERN
event_mapping = df_scores[['event_index', 'cp_avg_eta', 'cp_energy', 'cp_separation']].drop_duplicates('event_index')
df_CERN = pd.merge(df_CERN, event_mapping, on='event_index', how='left')

# ---- Efficiency and Purity Calculation ----
def calculate_efficiency_purity(df):
    # Efficiency
    cp_valid = df.dropna(subset=['cp_id']).copy()
    cp_grouped = cp_valid.groupby(['event_index', 'cp_id'])
    cp_associated = cp_grouped['sim_to_reco_score'].min() < 0.2
    cp_efficiency = cp_associated.groupby(level=0).mean().reset_index(name='efficiency')
    cp_valid = cp_valid.merge(cp_efficiency, on='event_index', how='left')

    # Purity
    tst_valid = df.dropna(subset=['trackster_id']).copy()
    tst_grouped = tst_valid.groupby(['event_index', 'trackster_id'])
    tst_associated = tst_grouped['reco_to_sim_score'].min() < 0.2
    tst_purity = tst_associated.groupby(level=0).mean().reset_index(name='purity')
    tst_valid = tst_valid.merge(tst_purity, on='event_index', how='left')

    # Merge into a single DataFrame
    df_plot = pd.merge(cp_valid[['event_index', 'cp_avg_eta', 'cp_energy', 'cp_separation', 'efficiency']],
                       tst_valid[['event_index', 'purity']],
                       on='event_index',
                       how='inner')
    return df_plot

df_plot = calculate_efficiency_purity(df_scores)
df_plot_CERN = calculate_efficiency_purity(df_CERN)

# ---- Binning ----
eta_bins = np.linspace(df_plot['cp_avg_eta'].min(), df_plot['cp_avg_eta'].max(), 10)
energy_bins = np.linspace(df_plot['cp_energy'].min(), df_plot['cp_energy'].max(), 10)  # Capped at 225
separation_bins = np.linspace(df_plot['cp_separation'].min(), df_plot['cp_separation'].max(), 10)

df_plot['eta_bin'] = pd.cut(df_plot['cp_avg_eta'], bins=eta_bins, labels=False, include_lowest=True)
df_plot['energy_bin'] = pd.cut(df_plot['cp_energy'], bins=energy_bins, labels=False, include_lowest=True)
df_plot['separation_bin'] = pd.cut(df_plot['cp_separation'], bins=separation_bins, labels=False, include_lowest=True)

df_plot_CERN['eta_bin'] = pd.cut(df_plot_CERN['cp_avg_eta'], bins=eta_bins, labels=False, include_lowest=True)
df_plot_CERN['energy_bin'] = pd.cut(df_plot_CERN['cp_energy'], bins=energy_bins, labels=False, include_lowest=True)
df_plot_CERN['separation_bin'] = pd.cut(df_plot_CERN['cp_separation'], bins=separation_bins, labels=False, include_lowest=True)

def calculate_bin_error(numerator, denominator):
    if denominator > 0:
        efficiency = numerator / denominator
        error = np.sqrt(efficiency * (1 - efficiency) / denominator)
    else:
        efficiency = 0.0
        error = 0.0
    return efficiency, error

def aggregate_bins(data, bin_col):
    return data.groupby(bin_col).apply(lambda g: pd.Series({
        'efficiency_mean': g['efficiency'].mean(),
        'efficiency_error': calculate_bin_error(g['efficiency'].sum(), len(g))[1],
        'purity_mean': g['purity'].mean(),
        'purity_error': calculate_bin_error(g['purity'].sum(), len(g))[1],
        'count': len(g) // 4
    })).reset_index()

# Aggregate Data
eta_group = aggregate_bins(df_plot, 'eta_bin').set_index('eta_bin').reindex(range(len(eta_bins) - 1)).reset_index()
energy_group = aggregate_bins(df_plot, 'energy_bin').set_index('energy_bin').reindex(range(len(energy_bins) - 1)).reset_index()
separation_group = aggregate_bins(df_plot, 'separation_bin').set_index('separation_bin').reindex(range(len(separation_bins) - 1)).reset_index()

eta_group_CERN = aggregate_bins(df_plot_CERN, 'eta_bin').set_index('eta_bin').reindex(range(len(eta_bins) - 1)).reset_index()
energy_group_CERN = aggregate_bins(df_plot_CERN, 'energy_bin').set_index('energy_bin').reindex(range(len(energy_bins) - 1)).reset_index()
separation_group_CERN = aggregate_bins(df_plot_CERN, 'separation_bin').set_index('separation_bin').reindex(range(len(separation_bins) - 1)).reset_index()

# Fill Missing Values
for group in [eta_group_CERN, energy_group_CERN, separation_group_CERN]:
    group.fillna({'efficiency_mean': np.nan, 'efficiency_error': np.nan,
                  'purity_mean': np.nan, 'purity_error': np.nan, 'count': 0}, inplace=True)

# ---- Plotting ----
def plot_metric(x_bins, group, group_CERN, xlabel, ylabel, title, efficiency_color, purity_color):
    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax2 = ax1.twinx()

    # Your Model
    ax1.plot(x_bins, group['efficiency_mean'], marker='o', linestyle='-', color=efficiency_color, label='Efficiency (Your Model)')
    ax1.plot(x_bins, group['purity_mean'], marker='o', linestyle='-', color=purity_color, label='Purity (Your Model)')

    # CERN Model
    ax1.plot(x_bins, group_CERN['efficiency_mean'], marker='x', linestyle='--', color='red', label='Efficiency (CERN)')
    ax1.plot(x_bins, group_CERN['purity_mean'], marker='x', linestyle='--', color='orange', label='Purity (CERN)')

    ax1.set_ylim(0, 1)
    ax1.set_xlabel(xlabel)
    ax1.set_ylabel(ylabel)
    ax1.legend(loc='upper left')
    ax1.grid()

    ax2.bar(x_bins, group['count'], width=(x_bins[1] - x_bins[0]), color='lightblue', alpha=0.35, label='Event Count')
    ax2.set_ylabel('Number of Events')
    ax2.legend(loc='upper right')

    plt.title(title)
    plt.show()

# Plot Each Metric
plot_metric(eta_bins[:-1], eta_group, eta_group_CERN, 'Average Eta Bin', 'Efficiency / Purity', 'Efficiency, Purity vs cp_avg_eta', 'blue', 'green')
plot_metric(energy_bins[:-1], energy_group, energy_group_CERN, 'Energy Bin (Capped at 225)', 'Efficiency / Purity', 'Efficiency, Purity vs cp_energy', 'orange', 'green')
plot_metric(separation_bins[:-1], separation_group, separation_group_CERN, 'Separation Bin', 'Efficiency / Purity', 'Efficiency, Purity vs cp_separation', 'red', 'purple')

# %% [markdown]
# # Plotting Sigma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_energy_diff_vs_separation(df_scores):
    """
    Plot energy difference ratio metrics (mean and sigma) against CaloParticle separation.

    Parameters:
    - df_scores: DataFrame containing the calculated scores and features for events.

    Returns:
    - None (plots are displayed).
    """
    # Filter to include only associated events (reco-to-sim score < 0.2)
    associated_scores = df_scores[df_scores['reco_to_sim_score'] < 0.2]

    # Define bins for cp_separation
    separation_bins = np.linspace(associated_scores['cp_separation'].min(), associated_scores['cp_separation'].max(), 10)
    associated_scores['separation_bin'] = pd.cut(
        associated_scores['cp_separation'], bins=separation_bins, labels=False, include_lowest=True
    )

    # Initialize lists to store results
    separation_bin_centers = []
    sigma_values = []
    mean_values = []
    event_counts = []

    # Loop through each separation bin
    for bin_idx in range(len(separation_bins) - 1):
        # Select data for the current bin
        bin_data = associated_scores[associated_scores['separation_bin'] == bin_idx]['energy_diff_ratio']
        
        # Skip if no data in this bin
        if bin_data.empty:
            continue
        
        # Fit a Gaussian to the data
        mu, sigma = norm.fit(bin_data)
        
        # Store results
        bin_center = (separation_bins[bin_idx] + separation_bins[bin_idx + 1]) / 2
        separation_bin_centers.append(bin_center)
        sigma_values.append(sigma)
        mean_values.append(mu)
        event_counts.append(len(bin_data))

        # Plot example histograms for the first and middle bins
        if bin_idx == 0 or bin_idx == len(separation_bins) // 2:
            plt.figure(figsize=(8, 6))
            plt.hist(bin_data, bins=30, density=True, alpha=0.6, color='blue', label='Histogram')
            xmin, xmax = plt.xlim()
            x = np.linspace(xmin, xmax, 100)
            p = norm.pdf(x, mu, sigma)
            plt.plot(x, p, 'orange', label=f'Fit: μ={mu:.3f}, σ={sigma:.3f}')
            plt.title(f'Energy Difference Ratio (Separation Bin {bin_idx})\nμ={mu:.3f}, σ={sigma:.3f}, Events={len(bin_data)}')
            plt.xlabel('(Reconstructed Energy - True Energy) / True Energy')
            plt.ylabel('Density')
            plt.legend()
            plt.grid()
            plt.show()

    # Plot σ (sigma) vs Separation
    plt.figure(figsize=(10, 6))
    plt.plot(separation_bin_centers, sigma_values, 'o-', label='Sigma (σ)', color='blue')
    plt.xlabel('Separation')
    plt.ylabel('Sigma (σ)')
    plt.title('Sigma vs Separation')
    plt.grid()
    plt.legend()
    plt.show()

    # Plot μ (mean) vs Separation
    plt.figure(figsize=(10, 6))
    plt.plot(separation_bin_centers, mean_values, 'o-', label='Mean (μ)', color='green')
    plt.xlabel('Separation')
    plt.ylabel('Mean (μ)')
    plt.title('Mean vs Separation')
    plt.grid()
    plt.legend()
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Filter to include only associated events (reco-to-sim score < 0.2)
associated_scores = df_CERN[df_CERN['reco_to_sim_score'] < 0.2]

# Define bins for cp_separation
separation_bins = np.linspace(associated_scores['cp_separation'].min(), associated_scores['cp_separation'].max(), 10)
associated_scores['separation_bin'] = pd.cut(associated_scores['cp_separation'], bins=separation_bins, labels=False, include_lowest=True)

# Initialize lists to store results
separation_bin_centers = []
sigma_values = []
mean_values = []
event_counts = []

# Loop through each separation bin
for bin_idx in range(len(separation_bins) - 1):
    # Select data for the current bin
    bin_data = associated_scores[associated_scores['separation_bin'] == bin_idx]['energy_diff_ratio']
    
    # Skip if no data in this bin
    if bin_data.empty:
        continue
    
    # Fit a Gaussian to the data
    mu, sigma = norm.fit(bin_data)
    
    # Store results
    bin_center = (separation_bins[bin_idx] + separation_bins[bin_idx + 1]) / 2
    separation_bin_centers.append(bin_center)
    sigma_values.append(sigma)
    mean_values.append(mu)
    event_counts.append(len(bin_data))

    # Plot a couple of example histograms for reference
    if bin_idx == 0 or bin_idx == len(separation_bins) // 2:  # Example: First and middle bins
        plt.figure(figsize=(8, 6))
        plt.hist(bin_data, bins=30, density=True, alpha=0.6, color='blue', label='Histogram')
        xmin, xmax = plt.xlim()
        x = np.linspace(xmin, xmax, 100)
        p = norm.pdf(x, mu, sigma)
        plt.plot(x, p, 'orange', label=f'Fit: μ={mu:.3f}, σ={sigma:.3f}')
        plt.title(f'Energy Difference Ratio (Separation Bin {bin_idx})\nμ={mu:.3f}, σ={sigma:.3f}, Events={len(bin_data)}')
        plt.xlabel('(Reconstructed Energy - True Energy) / True Energy')
        plt.ylabel('Density')
        plt.legend()
        plt.grid()
        plt.show()

# Plot σ (sigma) vs Separation
plt.figure(figsize=(10, 6))
plt.plot(separation_bin_centers, sigma_values, 'o-', label='Sigma (σ)', color='blue')
plt.xlabel('Separation')
plt.ylabel('Sigma (σ)')
plt.title('Sigma vs Separation')
plt.grid()
plt.legend()
plt.show()

# Plot μ (mean) vs Separation
plt.figure(figsize=(10, 6))
plt.plot(separation_bin_centers, mean_values, 'o-', label='Mean (μ)', color='green')
plt.xlabel('Separation')
plt.ylabel('Mean (μ)')
plt.title('Mean vs Separation')
plt.grid()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_2766516/3855021492.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   associated_scores['separation_bin'] = pd.cut(associated_scores['cp_separation'], bins=separation_bins, labels=False, include_lowest=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming df_scores is your DataFrame with all the relevant data
# Filter the DataFrame for reco-to-sim scores < 0.2
filtered_df = df_scores[df_scores['reco_to_sim_score'] < 0.2]

# Calculate the (pred - true) / true for energy_diff_ratio (or adjust the column name as needed)
# Assuming 'energy_diff_ratio' is the column of interest for (pred - true) / true
values = filtered_df['energy_diff_ratio']

# Plot the histogram
plt.figure(figsize=(8, 6))
counts, bins, patches = plt.hist(values, bins=50, density=True, alpha=0.7, label='Histogram')

# Fit a Gaussian distribution to the data
mu, sigma = np.mean(values), np.std(values)
x = np.linspace(bins[0], bins[-1], 1000)
pdf = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma)**2)
plt.plot(x, pdf, label=f'Fit: $\mu={mu:.3f}$, $\sigma={sigma:.3f}$', color='orange')

# Add labels and title
plt.title('(pred - true) / true for Reco-to-Sim Score < 0.2', fontsize=14)
plt.xlabel('(pred - true) / true', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend(fontsize=12)
plt.grid(alpha=0.3)

# Save or show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Assuming df_scores is your DataFrame with all the relevant data
# Filter the DataFrame for tracksters that have been reconstructed (reco_to_sim_score < 0.2)
reconstructed_df = df_scores[df_scores['reco_to_sim_score'] < 0.2]

# Group the data into energy bins
energy_bins = np.linspace(reconstructed_df['trackster_energy'].min(), reconstructed_df['trackster_energy'].max(), 10)
reconstructed_df['energy_bin'] = pd.cut(reconstructed_df['trackster_energy'], bins=energy_bins)

# Initialize lists to store results
bin_centers = []
sigmas = []
means = []

# Loop over each bin
for energy_bin, group in reconstructed_df.groupby('energy_bin'):
    if group.empty:
        continue

    # Calculate the bin center
    bin_center = (energy_bin.left + energy_bin.right) / 2
    bin_centers.append(bin_center)

    # Fit a Gaussian to the (pred - true) / true values
    values = group['energy_diff_ratio']
    mu, sigma = norm.fit(values)

    # Store the mean and sigma
    means.append(mu)
    sigmas.append(sigma)

# Plot sigma vs. energy
plt.figure(figsize=(8, 6))
plt.plot(bin_centers, sigmas, 'o-', label='Sigma')
plt.title('Resolution: Stochastic and Constant Terms')
plt.xlabel('Energy')
plt.ylabel('Sigma')
plt.grid(alpha=0.3)
plt.legend(fontsize=12)
plt.show()

# Plot mean vs. energy
plt.figure(figsize=(8, 6))
plt.plot(bin_centers, means, 'o-', label='Mean')
plt.title('Mean vs. Energy')
plt.xlabel('Energy')
plt.ylabel('Mean')
plt.grid(alpha=0.3)
plt.legend(fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_2766516/776054542.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reconstructed_df['energy_bin'] = pd.cut(reconstructed_df['trackster_energy'], bins=energy_bins)

# %% [markdown]
# # ROC curve

# %%
print()

# %%
from itertools import combinations
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

separation_thresholds = np.arange(0, df_scores['cp_separation'].max() + 10, 10)


# Initialize lists for ROC points
tpr_list = []
fpr_list = []

# Loop over separation thresholds
for threshold in separation_thresholds:
    global_TP = 0  # True Positives
    global_FP = 0  # False Positives
    global_FN = 0  # False Negatives
    global_TN = 0  # True Negatives

    # Filter events by separation threshold
    valid_events = df_scores[df_scores['cp_separation'] <= threshold]['event_index'].unique()

    for event_idx in valid_events:
        try:
            # Extract event data
            event = data_test[event_idx]
            true_labels_event = event.assoc[:, 0]  # Ground truth cluster labels
            pred_trackster_labels = np.array(all_cluster_labels[event_idx])  # Predicted labels

            # Generate all possible pairs of tracksters
            trackster_pairs = list(combinations(range(len(true_labels_event)), 2))

            # Initialize sets
            P_V = set()  # Ground truth pairs
            P_U = set()  # Predicted pairs
            P_X = set(trackster_pairs)  # All pairs

            for i, j in trackster_pairs:
                if true_labels_event[i] == true_labels_event[j]:
                    P_V.add((i, j))  # Ground truth edge
                if pred_trackster_labels[i] == pred_trackster_labels[j]:
                    P_U.add((i, j))  # Predicted edge

            # Calculate Confusion Matrix
            TP = len(P_V & P_U)  # True Positive
            FN = len(P_V - P_U)  # False Negative
            FP = len(P_U - P_V)  # False Positive
            TN = len(P_X - (P_V | P_U))  # True Negative

            # Update global counts
            global_TP += TP
            global_FP += FP
            global_FN += FN
            global_TN += TN

        except Exception as e:
            print(f"Error processing event {event_idx}: {e}")
            continue

    # Calculate TPR and FPR for the current threshold
    global_TPR = global_TP / (global_TP + global_FN) if (global_TP + global_FN) > 0 else 0
    global_FPR = global_FP / (global_FP + global_TN) if (global_FP + global_TN) > 0 else 0

    # Append to lists
    tpr_list.append(global_TPR)
    fpr_list.append(global_FPR)
    
# Check conditions for removing the first point
if len(fpr_list) > 1 and len(tpr_list) > 1:
    if (fpr_list[1] > fpr_list[0]) or (tpr_list[1] <= tpr_list[0]):
        print("Removing the first point from fpr_list and tpr_list due to conditions.")
        fpr_list.pop(0)
        tpr_list.pop(0)
        




# Plot ROC Curve
roc_auc = auc(fpr_list, tpr_list)
plt.figure(figsize=(10, 6))
plt.plot(fpr_list, tpr_list, lw=2, color='blue', label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')  # Random guessing baseline
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Using cp_separation as Threshold')
plt.legend(loc="lower right")
plt.show()

# %%
fpr_list.sort()
tpr_list.sort()

# Plot ROC Curve
roc_auc = auc(fpr_list, tpr_list)
plt.figure(figsize=(10, 6))
plt.plot(fpr_list, tpr_list, lw=2, color='blue', label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')  # Random guessing baseline
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Using cp_separation as Threshold')
plt.legend(loc="lower right")
plt.show()
print(roc_auc)

# %%
from sklearn.metrics import auc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Define separation thresholds (e.g., 0, 5, 10, ..., max separation in dataset)
separation_thresholds = np.arange(0, df_scores['cp_separation'].max() + 10, 10)
score_threshold = 0.2  # Fixed threshold for both scores

# Initialize lists for ROC points
tpr_list = []
fpr_list = []

# Loop over separation thresholds
for separation in separation_thresholds:
    global_TP = 0  # True Positives
    global_FP = 0  # False Positives
    global_FN = 0  # False Negatives
    global_TN = 0  # True Negatives

    # Filter events by cp_separation threshold
    valid_events = df_CERN[df_CERN['cp_separation'] <= separation]['event_index'].unique()

    for event_idx in valid_events:
        try:
            # Filter pairs for this event
            event_pairs = df_CERN[df_CERN['event_index'] == event_idx]
            
            # Extract scores
            sim_to_reco_scores = event_pairs['sim_to_reco_score'].values
            reco_to_sim_scores = event_pairs['reco_to_sim_score'].values

            # Loop through each pair
            for sim_score, reco_score in zip(sim_to_reco_scores, reco_to_sim_scores):
                if sim_score < score_threshold and reco_score < score_threshold:
                    global_TP += 1  # True Positive
                elif reco_score < score_threshold and sim_score > score_threshold:
                    global_FP += 1  # False Positive
                elif sim_score < score_threshold and reco_score > score_threshold:
                    global_FN += 1  # False Negative
                elif sim_score > score_threshold and reco_score > score_threshold:
                    global_TN += 1  # True Negative

        except Exception as e:
            print(f"Error processing event {event_idx}: {e}")
            continue

    # Calculate TPR and FPR for the current separation threshold
    global_TPR = global_TP / (global_TP + global_FN) if (global_TP + global_FN) > 0 else 0
    global_FPR = global_FP / (global_FP + global_TN) if (global_FP + global_TN) > 0 else 0

    # Append to lists
    tpr_list.append(global_TPR)
    fpr_list.append(global_FPR)

# Pair FPR and TPR together
roc_points = list(zip(fpr_list, tpr_list))

# Sort by FPR in descending order
roc_points.sort(key=lambda x: x[0], reverse=True)

# Remove non-monotonic points
filtered_points = []
prev_fpr = float('inf')  # Start with a very large value for FPR

for fpr, tpr in roc_points:
    if fpr <= prev_fpr:
        filtered_points.append((fpr, tpr))
        prev_fpr = fpr

# Unzip into FPR and TPR lists
fpr_list, tpr_list = zip(*filtered_points)

# Convert back to lists
fpr_list = list(fpr_list)
tpr_list = list(tpr_list)

# Ensure (0,0) and (1,1) are included
if (0.0, 0.0) not in filtered_points:
    fpr_list.insert(0, 1.0)
    tpr_list.insert(0, 1.0)
if (1.0, 1.0) not in filtered_points:
    fpr_list.append(0.0)
    tpr_list.append(0.0)



# Plot ROC Curve
roc_auc = auc(fpr_list, tpr_list)
plt.figure(figsize=(10, 6))
plt.plot(fpr_list, tpr_list, lw=2, color='blue', label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')  # Random guessing baseline
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Using Fixed Threshold (0.2) and Varying Separation')
plt.legend(loc="lower right")
plt.show()

# %%
print(fpr_list)

# %%
print(tpr_list)

# %%
# Ensure (0,0) and (1,1) are included
if (0.0, 0.0) not in filtered_points:
    fpr_list.insert(0, 1.0)
    tpr_list.insert(0, 1.0)
if (1.0, 1.0) not in filtered_points:
    fpr_list.append(0.0)
    tpr_list.append(0.0)

# %%
print(tpr_list)

# %% [markdown]
# # Test

# %%
import torch
import numpy as np
from tqdm import tqdm  # For progress visualization
import pandas as pd
import logging

# Setup Logging
logging.basicConfig(filename='processing_errors.log', level=logging.ERROR,
                    format='%(asctime)s %(levelname)s:%(message)s')

# Define a simple Event class
class Event:
    def __init__(self, x, assoc):
        self.x = x  # Tensor or numpy array
        self.assoc = assoc  # Tensor or numpy array

# %%
# Define particles as per the numerical example
# Columns: x, y, z, energy, eta
# Particle 0: (0,0,0), 10, 1.0, cp=0, tst=0
# Particle 1: (1,0,0), 20, 1.1, cp=0, tst=0
# Particle 2: (0,1,0), 30, 2.0, cp=1, tst=1
# Particle 3: (1,1,0), 40, 2.1, cp=1, tst=1

# Create x: shape (num_particles, 5)
x = np.array([
    [0, 0, 0, 10, 1.0],
    [1, 0, 0, 20, 1.1],
    [0, 1, 0, 30, 2.0],
    [1, 1, 0, 40, 2.1],
])

# Create assoc: shape (num_particles, 1)
assoc = np.array([
    [0],
    [0],
    [1],
    [1],
])

# Create a single event
event = Event(x=x, assoc=assoc)

# data_test contains one event
data_test = [event]

# Define all_cluster_labels: list of lists, one per event
# For event 0: Trackster 0 contains particles 0 and 1, Trackster 1 contains 2 and 3
all_cluster_labels = [
    [0, 0, 1, 1]
]

# %%
# Initialize a list to store scores for all events
all_scores = []

# Determine the number of events
num_events = len(data_test)

# Iterate over all events with a progress bar
for event_idx in tqdm(range(num_events), desc="Processing Events"):
    try:
        event = data_test[event_idx]

        # Extract x, y, z, energy, and eta
        if isinstance(event.x, torch.Tensor):
            positions = event.x[:, :3].numpy()  # Extract x, y, z
            energies = event.x[:, 3].numpy()
            etas = event.x[:, 4].numpy()
        else:
            positions = event.x[:, :3]
            energies = event.x[:, 3]
            etas = event.x[:, 4]

        positions = np.array(positions)
        energies = np.array(energies)
        etas = np.array(etas)

        # Extract true labels and predicted labels
        true_labels_event = event.assoc[:, 0]
        true_cp_labels = true_labels_event.astype(int) if isinstance(true_labels_event, np.ndarray) else true_labels_event.int().numpy()
        pred_trackster_labels = np.array(all_cluster_labels[event_idx])

        # Identify unique CP IDs and Trackster IDs
        cp_ids = np.unique(true_cp_labels)
        trackster_ids = np.unique(pred_trackster_labels)

        if len(cp_ids) == 0 or len(trackster_ids) == 0:
            # Handle empty associations
            all_scores.append({
                'event_index': event_idx,
                'cp_id': None,
                'trackster_id': None,
                'sim_to_reco_score': 0.0,
                'reco_to_sim_score': 1.0,
                'cp_energy': 0.0,
                'trackster_energy': 0.0,
                'cp_avg_eta': 0.0,
                'cp_separation': 0.0,
                'energy_diff_ratio': None
            })
            continue

        # Create dictionaries mapping cluster IDs to their particle indices
        cp_clusters = {cp: np.where(true_cp_labels == cp)[0] for cp in cp_ids}
        tst_clusters = {t: np.where(pred_trackster_labels == t)[0] for t in trackster_ids}

        # Compute average positions for each true CP cluster
        cp_avg_positions = {cp: np.mean(positions[indices], axis=0) for cp, indices in cp_clusters.items()}

        # Compute separation between two CP clusters if at least 2 exist
        if len(cp_ids) >= 2:
            cp_separation = np.linalg.norm(cp_avg_positions[cp_ids[0]] - cp_avg_positions[cp_ids[1]])
        else:
            cp_separation = 0.0

        # Compute total energy and average eta for each CP cluster
        cp_total_energy = {cp: np.sum(energies[indices]) for cp, indices in cp_clusters.items()}
        cp_avg_eta = {cp: np.mean(etas[indices]) for cp, indices in cp_clusters.items()}

        # Compute total energy for each Trackster cluster
        tst_total_energy = {t: np.sum(energies[indices]) for t, indices in tst_clusters.items()}

        # Initialize dictionaries to store scores for this event
        sim_to_reco_scores = {}
        reco_to_sim_scores = {}

        # Compute Sim-to-Reco and Reco-to-Sim Scores
        for cp in cp_ids:
            for tst in trackster_ids:
                cp_indices = cp_clusters[cp]
                tst_indices = tst_clusters[tst]

                if cp_total_energy[cp] == 0 or np.sum(energies[tst_indices]) == 0:
                    sim_to_reco_scores[(cp, tst)] = 0.0
                    reco_to_sim_scores[(tst, cp)] = 1.0
                    # Append to all_scores
                    all_scores.append({
                        'event_index': event_idx,
                        'cp_id': cp,
                        'trackster_id': tst,
                        'sim_to_reco_score': 0.0,
                        'reco_to_sim_score': 1.0,
                        'cp_energy': cp_total_energy[cp],
                        'trackster_energy': tst_total_energy[tst],
                        'cp_avg_eta': cp_avg_eta[cp],
                        'cp_separation': cp_separation,
                        'energy_diff_ratio': (tst_total_energy[tst] - cp_total_energy[cp]) / cp_total_energy[cp]
                    })
                    continue

                # Sim-to-Reco Score
                fr_sc_i_mc = {k: energies[k] / cp_total_energy[cp] for k in cp_indices}
                fr_tst_j_reco = {
                    k: (energies[k] / np.sum(energies[tst_indices]) if k in tst_indices else 0.0)
                    for k in cp_indices
                }
                numerator = sum((fr_tst_j_reco[k] - fr_sc_i_mc[k]) ** 2 * energies[k] ** 2 for k in cp_indices)
                denominator = (sum(fr_sc_i_mc[h] * energies[h] for h in cp_indices)) ** 2
                sim_score = numerator / denominator if denominator != 0 else 0.0

                # Reco-to-Sim Score
                fr_tst_i_reco = {k: energies[k] / np.sum(energies[tst_indices]) for k in tst_indices}
                fr_sc_j_mc = {k: energies[k] / cp_total_energy[cp] if k in cp_indices else 0.0 for k in tst_indices}
                numerator_reco = sum((fr_tst_i_reco[k] - fr_sc_j_mc[k]) ** 2 * energies[k] ** 2 for k in tst_indices)
                denominator_reco = (sum(fr_tst_i_reco[h] * energies[h] for h in tst_indices)) ** 2
                reco_score = numerator_reco / denominator_reco if denominator_reco != 0 else 0.0

                # Calculate energy difference ratio
                energy_diff_ratio = (tst_total_energy[tst] - cp_total_energy[cp]) / cp_total_energy[cp]

                # Append to all_scores
                all_scores.append({
                    'event_index': event_idx,
                    'cp_id': cp,
                    'trackster_id': tst,
                    'sim_to_reco_score': sim_score,
                    'reco_to_sim_score': reco_score,
                    'cp_energy': cp_total_energy[cp],
                    'trackster_energy': tst_total_energy[tst],
                    'cp_avg_eta': cp_avg_eta[cp],
                    'cp_separation': cp_separation,
                    'energy_diff_ratio': energy_diff_ratio
                })

    except Exception as e:
        logging.error(f"Error processing event {event_idx}: {e}")
        all_scores.append({
            'event_index': event_idx,
            'cp_id': None,
            'trackster_id': None,
            'sim_to_reco_score': 0.0,
            'reco_to_sim_score': 1.0,
            'cp_energy': 0.0,
            'trackster_energy': 0.0,
            'cp_avg_eta': 0.0,
            'cp_separation': 0.0,
            'energy_diff_ratio': None
        })

# %%
# Convert all_scores to a DataFrame
df_scores = pd.DataFrame(all_scores, columns=[
    'event_index',
    'cp_id',
    'trackster_id',
    'sim_to_reco_score',
    'reco_to_sim_score',
    'cp_energy',
    'trackster_energy',
    'cp_avg_eta',
    'cp_separation',
    'energy_diff_ratio'
])

# Display the DataFrame
print(df_scores)

# %%
print('yay')

# %% [markdown]
# # Check other data

# %%
import uproot

# %%
file = uproot.open('/vols/cms/bmaier/hgcal/data/20230701_multi_particles/test/raw/particles_10_8373759_ntuple.root')

# %%
print(file.keys())

# %%
track = file['ticlNtuplizer/tracksters;1']

# %%
print(track.keys())

# %%
v_x = track['barycenter_x'].array()

# %%
print(len(v_x[0]))
